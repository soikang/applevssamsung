# %% [markdown]
# # iPhone X vs Galaxy S9
# <img src="A_logo.JPG" width="20%" style = "float:left">
# <br><br>
# <img src="S_logo.JPG" width="30%" style = "float:right">
# <br><br><br><br><br><br><br><br><br><br><br><br>
# > Apple iPhone and Samsung Galaxy are known to be top two competitors in the smartphone market. Our team wanted to know what the consumers think of these two companies' products. Our team determined that iPhone X and Galaxy S9 will be a fair comparison because the release dates were only 4 months apart.
#
# >iPhone X Release Date: **November 3, 2017**
#
# >Galaxy S9 Release Date: **March 16, 2018**
#
# >These two products have different features and functions. We will explore these reviews to extract insigts that can help with business decisions.

# %%
# load necessary libraries
import re
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import statsmodels.formula.api as smf 
import statsmodels.api as sm
import matplotlib.pyplot as plt
from textblob import TextBlob
import nltk
from nltk.corpus import stopwords
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk.stem import WordNetLemmatizer
from collections import Counter
import gensim
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_lg')

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
import ipywidgets as widgets
# Out:
# C:\Users\thdms\Anaconda3\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')

# %% [markdown]
# ## Review of Data Acquisition and Processing
#
# We scraped the 6 websites below using BeautifulSoup and Selenium. More websites were considered, but not every website had both phone reviews or have 5-star rating system or review system. For the sake of this analysis, we scraped only basic model of both phones (e.g. S9 rather than S9+). Scraping codes are included in the folder 'scrapers' and the dataframes extracted from these websites are also saved separately in 'scraped-data' folder.
#
# Scraped websites :
# 1. Best-Buy(Electronic and Product Sale)
# 2. Verizon(Telecommunication)
# 3. AT&T(Telecommunication)
# 4. influenster.com(E-Commerce for Daily Products)
# 5. ProductReview.au(Electronic Sale/Purchase company in Australia)
# 6. very.co.uk(Electronic Sale/Purchase company in the United Kingdom)
#
# #### We have saved the scraped data as 'final_data.csv' and EDA starts from this

# %%
# read the data in
df = pd.read_csv('data/final_data.csv')

# count by source and type of phone
pd.pivot_table(df, index='source', columns='phone', aggfunc='size')
# Out:
# phone                 galaxy  iphone
# source
# BestBuy                 1596      39
# Productreview.com.au     111     660
# Very.co.uk              7602     500
# att.com                  267    1116
# influenster               95     988
# vw                        74     170

# %%
# count by rating and type of phone
pd.pivot_table(df, index='phone', columns='rating', aggfunc='size')
# Out:
# rating    1    2    3     4     5
# phone
# galaxy  277  252  535  1673  7037
# iphone  127   97  179   501  2572

# %% [markdown]
# We labeled rating 1, 2 as negative sentiment (N) and 4, 5 as positive sentiment (P). We went through all the rating 3 reviews and labeled it manually. We indicated some reviews as '?' which do not express any sentiment such as the reviews written in foreign language and very neutral sentiment. There were 32 reviews of those out of 13250 total observations and we eventually dropped all the '?'s and ended up with 13218 rows.
#
# #### After labeling, it is saved as 'final_data_labeld.csv'

# %%
df = pd.read_csv("data/final_data_labeled.csv", index_col = False)

pd.pivot_table(df, index='phone', columns='sentiment',aggfunc='size',fill_value='0')
# Out:
# sentiment   ?    N     P
# phone
# galaxy     29  895  8850
# iphone      3  353  3120

# %%
df = df[df['sentiment'] != '?'].reset_index(drop=True)
print("total rows : " +str(len(df)))

pd.pivot_table(df, index='phone', aggfunc='size')
# Out:
# total rows : 13218
# phone
# galaxy    9745
# iphone    3473
# dtype: int64

# %% [markdown]
# ## Adding features
#
# As above table depcts, iPhone X and Samsung S9 reviews were scraped 6 different product review websites. Count of Galaxy reivews are three times as much as iPhone reivews (very.co.uk had a significantly more Galaxy S9 reviews.) After cleaning, total of 13218 reviews are used in this analysis.
#
#
# 1. **cleaned** : special characters and non ASCII characters removed
#
# + **filtered** : stopwords removed from "cleaned"
#
# + **len_adj** : number of adjectives appeared in each review
#
#        spaCy tagger will indentify all of adjectives as 'ADJ'
#
# + **len_ch** : number of characters in each review (e.g. 'I love Apple' would be 10 characters)
#
# + **len_org** : number of organization mentioned in each review (e.g. 'Samsung' in the review will be counted as one.)
#
#        spaCy correctly identifys comnany names. 'Samsung', 'Apple' 'Sony' will be tagged as 'ORG'.
#
# + **num_pos** : number of positive words
#
#        each word in reviews was quantified (semtiment > 0) via Textblob
#
# + **num_neg** : number of negative words
#
#        each word in reviews was quantified (semtiment < 0) via Textblob
#
# + **sentiment** : 5 and 4 stars are 'P' meaning positive reviews. 1 and 2 stars are 'N'. 3 stars were manually labels after reading the reviews.
#
# + **positivity** : Used SentimentIntensityAnalyzer in nltk.vader library. The positivity score is calculated based on a dictionay of words and associated positive scores. Cool thing about this function is that special characters are taken into consideration when the scores are calculated.
#
#         e.g. I love this phone. vs I love this phone!
#
#         SentimentIntensityAnalyzer will assign higher positivity to second sentence.
#
# + **negativity** : Used SentimentIntensityAnalyzer in nltk.vader. The negativity score is calculated based on a dictionay of words and associated negative scores. Cool thing about this function is that special characters are taken into consideration when the scores are calculated.
#
#         e.g. I hate this phone. vs I hate this phone!
#
#         SentimentIntensityAnalyzer will assign higher negativity to second sentence.
#
#     <u>\* one review can have both non-zero positivity and negativity scores</u>
#
# + **compound** : both posivitiy and negativity score was taken into consideration and normalized to calculate compound score
#
# + **polarity** : Polarity is float which lies in the range of [-1,1] where 1 means positive statement and -1 means a negative statement.
#
# + **rating** : 1 - 5 stars
#
# + **review** : actual reviews scraped
#
# + **source** : productreview.com.au, very.co.uk, bestbuy.com, att.com, verizon.com, influenster.com
#
# + **phone** : iphone and galaxy

# %%
# 1) Adding "cleaned" review as a feature
reviews = df['review']
stopwords = nltk.corpus.stopwords.words('english')

# df with one column
data = reviews.to_frame()
# remove non ASCII characters & special characters
df['cleaned'] = data['review'].apply(lambda x : ' '.join(e for e in x.split(" ") if e.isalnum()))

# 2) Adding "filtered" review as a feature : this is to remove stopwords
word_tokens = []

for review in df['cleaned'] :
    tokens = word_tokenize(str(review))
    word_tokens.append(tokens)

filtered_sentence = []
for tokens in word_tokens :
    filtered_review = [w for w in tokens if not w in stopwords] 
    filtered_sentence.append(filtered_review)

filtered = pd.DataFrame({'filtered' : filtered_sentence})
df['filtered'] = filtered
df['filtered'] = df['filtered'].apply(' '.join)

# %%
# 3) count of adjectives in each review 
# 4) count of brand name(s) mentioned in each review
# 5) count of characters in each review
leng =[]
len_org = []
len_char = []
for i in range(len(df)):
    
    k = len(df['review'][i]) #count of chars
    len_char.append(k)
    
    text = nlp(df['review'][i])
    len_org.append(len(text.ents)) #count of brand names
    
    for token in text:
        if token.pos_ == "ADJ":
            tk=len(token)
    leng.append(tk) #count of adj
    
df['len_org'] = len_org # freq of organiztion mentioned
df['len_adj'] = leng # freq of adjectives
df['len_ch'] = len_char # count of character

# %%
# 6) adding negativity, positivity, and compound scores

negativity=[]
positivity=[]
compound=[]

sid = SentimentIntensityAnalyzer()
for i in range(len(df)):
    score=sid.polarity_scores(df['review'][i])
    score.keys()
    neg=list(score.values())[0]
    pos=list(score.values())[2]
    comp=list(score.values())[3]
    
    negativity.append(neg)
    positivity.append(pos)
    compound.append(comp)

df['negativity'] = negativity
df['positivity'] = positivity
df['compound'] = compound

# %%
# 7) adding number of positive words and negative words

num_pos = []
num_neg = []

# 'filtered' is already without stopwords and special characters. we will use filtered column
# filter it once more to make sure it's clean
filtered = df['filtered'].map(lambda x: re.sub(r'\W+', ' ', str(x)))

for review in filtered :
    pos_counter = 0
    neg_counter = 0
    for word in word_tokenize(review):
        if(TextBlob(word).sentiment[0] > 0) :
            pos_counter = pos_counter+1
            #print(TextBlob(word).sentiment[0])
            
        elif (TextBlob(word).sentiment[0] < 0) :
            neg_counter = neg_counter+1
            #print(TextBlob(word).sentiment[0])
        
        else :
            pass
        
    num_pos.append(pos_counter)
    num_neg.append(neg_counter)

df['num_pos'] = num_pos
df['num_neg'] = num_neg

# %%
# 8) adding polarity scores based on the original review. polarity score is from textblob library

df['polarity'] = df['review'].apply(lambda x : TextBlob(x).sentiment[0])

# %% [markdown]
# ####  The below is what our master_data looks like and we have saved the file as 'master_data.csv' so that we do not have to run the above code again.

# %%
# we have saved the file after adding the necessary features as 'master_data.csv'
df.to_csv('data/master_data.csv')

# split the dataframe by phone
df_a = df[df['phone']=='iphone'].reset_index(drop=True)
df_s = df[df['phone']=='galaxy'].reset_index(drop=True)

# %%
df.head()
# Out:
#     phone  rating sentiment  \
# 0  galaxy       5         P
# 1  galaxy       5         P
# 2  galaxy       4         P
# 3  galaxy       3         P
# 4  galaxy       4         P
#
#                                               review                source  \
# 0  The Samsung Galaxy s9 is arguably the most bea...  Productreview.com.au
# 1  great  phone smart features easy to use ,, , p...  Productreview.com.au
# 2  I really liked the phone. It has good camera w...  Productreview.com.au
# 3  First of all the camera quality does not disap...  Productreview.com.au
# 4  As a flagship phone goes, everything is pretty...  Productreview.com.au
#
#                                              cleaned  \
# 0  The Samsung Galaxy s9 is arguably the most bea...
# 1  great phone smart features easy to use plenty ...
# 2  I really liked the It has good camera which is...
# 3  First of all the camera quality does not as ar...
# 4  As a flagship phone everything is pretty Speed...
#
#                                             filtered  len_org  len_adj  \
# 0  The Samsung Galaxy s9 arguably beautiful phone...        5        7
# 1  great phone smart features easy use plenty goo...        0        4
# 2  I really liked It good camera best feature goo...        1        4
# 3  First camera quality samsung cameras excellent...        4        5
# 4  As flagship phone everything pretty Speed touc...        3        2
#
#    len_ch  negativity  positivity  compound  num_pos  num_neg  polarity
# 0     395       0.025       0.227    0.9476        4        0  0.558333
# 1     224       0.000       0.424    0.9590        6        0  0.624603
# 2     155       0.000       0.419    0.9421        6        0  0.640000
# 3     382       0.033       0.109    0.7317        4        1  0.185625
# 4     605       0.056       0.111    0.7269        7        1  0.158333

# %% [markdown]
# ## Analysis
# ### Exploratory Data Analysis
#
# We started with the correlation matrix based on the numeric variables we created.

# %%
# the correlation between the numeric variables which we created

df = pd.read_csv('data/master_data.csv')
df.corr()
# Out:
#               rating   len_org   len_adj    len_ch  negativity  positivity  \
# rating      1.000000 -0.105748 -0.005873 -0.139275   -0.402382    0.405379
# len_org    -0.105748  1.000000 -0.007423  0.766154    0.055621   -0.256843
# len_adj    -0.005873 -0.007423  1.000000  0.006928    0.054394    0.025038
# len_ch     -0.139275  0.766154  0.006928  1.000000    0.090068   -0.269292
# negativity -0.402382  0.055621  0.054394  0.090068    1.000000   -0.393010
# positivity  0.405379 -0.256843  0.025038 -0.269292   -0.393010    1.000000
# compound    0.498301  0.020958 -0.006904  0.078011   -0.639257    0.665689
# num_pos     0.078437  0.488181 -0.009267  0.729313   -0.054689    0.120520
# num_neg    -0.257825  0.472831  0.043388  0.645547    0.266803   -0.281646
# polarity    0.438611 -0.187685 -0.005497 -0.220018   -0.415312    0.641672
#
#             compound   num_pos   num_neg  polarity
# rating      0.498301  0.078437 -0.257825  0.438611
# len_org     0.020958  0.488181  0.472831 -0.187685
# len_adj    -0.006904 -0.009267  0.043388 -0.005497
# len_ch      0.078011  0.729313  0.645547 -0.220018
# negativity -0.639257 -0.054689  0.266803 -0.415312
# positivity  0.665689  0.120520 -0.281646  0.641672
# compound    1.000000  0.383247 -0.141040  0.545530
# num_pos     0.383247  1.000000  0.403786  0.053114
# num_neg    -0.141040  0.403786  1.000000 -0.394409
# polarity    0.545530  0.053114 -0.394409  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(11, 11), diagonal='kde')
plt.show()

# %% [markdown]
# ### Exploratory Data Analysis continued
#
# After examining the scatter plot matrix, we decided to closely look at the feature variables and the association with the rating by creating the plots and compare them one another.

# %%
f = plt.figure(figsize=(14,4))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax.set_title("compound scores associated with rating")
ax.plot(df['compound'], df['rating'], 'o')
ax2.plot(df['polarity'], df['rating'], 'o')
ax2.set_title("polarity scores associated with rating")
plt.show()

# %% [markdown]
# > Compoud scores don't makes sense. You should be able to see steps rising toward northweast corner. It is minimally resembling the true polarity. In the perfect world, again, you should be able to see steps rising toward northweast corner.

# %%
f = plt.figure(figsize=(14,4))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax.set_title("length of review with rating")
ax.plot(df['len_ch'], df['rating'], 'o')
ax2.plot(df['len_adj'], df['rating'], 'o')
ax2.set_title("number of adjectives with rating")
plt.show()

# %% [markdown]
# > The trend is that the higher the ratings are the longer the reviews are. With count of adjectives, our team expected to see $\huge\subset$ shape. 5 and 1 star will have more adjectives. It seems to agree with 5 stars, but not 1 stars.

# %%
f = plt.figure(figsize=(14,4))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax.set_title("positivity associated with rating")
ax.plot(df['positivity'], df['rating'], 'o')
ax2.plot(df['negativity'], df['rating'], 'o')
ax2.set_title("negativity associated with rating")
plt.show()

# %% [markdown]
# > Above plots are interesting because postivity is resembling the true shape of rating distribution (the higher the ratings, the higher the positivity scores are). Similarly, we would expect the lower the ratings, the lower the negativity scores are.

# %%
f = plt.figure(figsize=(14,4))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
ax.set_title("number of positive words with rating")
ax.plot(df['num_pos'], df['rating'], 'o')
ax2.plot(df['num_neg'], df['rating'], 'o')
ax2.set_title("number of negative words with rating")
plt.show()

# %% [markdown]
# > We decided to count positive and negative words to confirm. The results were consistent as above psotivity and negativity plots. Number of positive words mostly agree with ratings, but again, number of negative words are messy. Let's see if we can fix this by treating double negations. We highly suspect that this is because of "double negations" as the example in the next code chunk. We will cover this topic extensively in "Treating Double Negated Phrases" below.

# %% [markdown]
# ## Treating double negated phrases
#
# As the example below (legit phone not bad aspects : rating 5), we want to take care of the double negations which might be messing with our data. We decided to create a list of double negated phrases from our dataset. Using bigrams, we will sift double negatives and create a list in order to nullify the double negatives.
#
# 1. go through the list from ratings 4 and 5 and retrieve double nagated words
# 2. we defined double negative phrases as whatever contains "no" as the first word and the following word should be a negative adjective. For example, "not bad" should be in our list. The reason why we defined the first word to be explicitly "no" is because both nltk and textblob library consider "no" doesn't contain any sentiment. Polarity score of "no" from textblob is 0.0 and the negativity score from nltk was also 0.0
#
# 3. Once the phrase is found, add it to the list.

# %%
### double negation example ###

# This is a 5-star review, but negativity score is 0.655 when positive score is 0.
n=13201
print(sid.polarity_scores(df['review'][n]))
print('rating: ', df['rating'][n])
print(df['num_neg'][n])
df['review'][n]

# %%
# use cleaned review
filtered = df['cleaned']

#Lemmatization before sifting double negations
lemmatizer=WordNetLemmatizer()
tok = filtered.apply(lambda x : word_tokenize(x))
lem = tok.apply(lambda x : [lemmatizer.lemmatize(_) for _ in x])
lem_rat = pd.concat([lem, df['rating']], axis=1)

#list for bigrams of all the reviews
# also added rating next to each bigram
bigrams =[]
for i in range(len(lem_rat['cleaned'])) :
    for ngram in (ngrams(lem_rat['cleaned'][i], 2)) :
        bigrams.append(' '.join(str(i) for i in ngram))
        bigrams.append(lem_rat['rating'][i])
        
#list for possible double negatives
double_negatives = []

for i in range(0, len(bigrams), 2):
    tokens = word_tokenize(bigrams[i])
    #if both words are negative
    if(("no" in tokens[0]) & (TextBlob(tokens[1]).sentiment[0]<0)):
        double_negatives.append(bigrams[i])
        double_negatives.append(bigrams[i+1])
    
    
# let's separate the list and make it as a dataframe
d_neg = []
d_rat = []

i = 0
while(i < len(double_negatives)):
    d_neg.append(double_negatives[i])
    i=i+1
    d_rat.append(double_negatives[i])
    i=i+1

# list to a dataframe
d_neg_rat = pd.DataFrame({'negative bigrams' : d_neg, 'associated rating' : d_rat})

# export
d_neg_rat.to_csv('data/doub_neg.csv', index=False)

# %% [markdown]
# #### From the code above, we have acquired a list of double negatives out of our dataset. The list looks like below and we also have saved it as "doub_neg.csv" file so this code chunk doesn't have to be run.

# %%
d_neg_rat.head(10)
# Out:
#        negative bigrams  associated rating
# 0              now down                  3
# 1               no mean                  5
# 2               not bad                  5
# 3          nothing Less                  2
# 4            not broken                  5
# 5  technology difficult                  5
# 6          no complaint                  5
# 7           not serious                  1
# 8        annoying worst                  2
# 9             not tough                  3

# %%
d_neg_rat = pd.read_csv('data/doub_neg.csv')
pd.pivot_table(d_neg_rat, columns='associated rating', aggfunc='size')
# Out:
# associated rating
# 1      4
# 2      5
# 3     21
# 4     29
# 5    142
# dtype: int64

# %% [markdown]
# > We can see there are way more 4s and 5s in the rating that are associated with double negated phrases.

# %% [markdown]
# ## Plotting after removing double negated phrases
#
# ### Part1. Getting the list ready
# <br>
#
# **Trimming the list**
#
# Out of the list we have created, we observed that there are phrases that are not double negated such as "technology difficult". We manually went through the list and deleted non-double negated phrases. We have saved the file as "doub_deg_edited.csv".
#
# **Updating the list**
#
# We wanted to look into the negativity score even more closely and see if there is any more phrases we want to include. Using our double negated phrase list, we created a subset which is rating 5s and the negativity score above 0.2. There were 146 occurrences in the subset. After we examine the subset, we figured out that there are actually more double negations in the reviews which we did not include in our double negation lists such as
#
# - no regret
# - no fault
# - no problem
# - coudn't be happier
# - no complain
#
# We added these phrases in to our double negation list and updated it.

# %%
d_list = pd.read_csv('data/doub_neg_edited.csv') #this is the trimmed list
d_list = d_list.dropna()
d_list = list(d_list['negative bigrams'])

unique = list(set(d_list))
print("length of our trimmed list : " +str(len(unique)))
# Out:
# length of our trimmed list : 32

# %%
# examine the review with negativity score and rating to update our doube negative list.

test = df[['review','negativity','rating']]
liars = test[(test['rating']==5) & (test['negativity']>0.30)].sort_values(by='negativity', ascending=False)
liars['review'].values
# Out:
# array(['Legit phone no bad aspects',
#        'This does everything I need. Absolutely no disappointments!',
#        'Bought phone a few weeks ago absolutely no regrets',
#        'Brill phone no faults couldnt ask for a better phone :)',
#        'Apps are difficult to find. Start-up was difficult',
#        'Flawless had it for 3 months so far. No problems or negative comments',
#        'Great phone no fault yet............................',
#        "Had phone one week couldn't be happier best phone ever",
#        'I love it I got no complain',
#        'I bought this phone a week ago still learning but no regrets',
#        "I have it less than 14 days and don't like it, I LOVE my phone!!!",
#        'Bit disappointed no built-in radio like my old phone',
#        'Got this as an upgrade, had no problems with it transferred everything over from my old s7 with no problems.',
#        "I've had this phone for one month now. No complaints",
#        "Got this phone a month ago and I've got no complaints",
#        "A pure love ae mad phone it's mad ting belter man b",
#        'Had a couple of weeks & no faults found at all with the phone',
#        'I got this phone for my few months ago absolutely wicked love it no problems at all',
#        'This is a great phone, you get what you pay for, no complaints.',
#        'Bought it 3 weeks ago, and no regrets!! Totally love it!!',
#        'Bought just over a week ago, so far no problems good features',
#        'Brilliant phone slightly big but no faults what so ever brought it a month ago',
#        'Great phone, samsung pay does not support my bank and a lot of other big banks though. Im now using google pay but this has no security which it worrying. Sick phone though',
#        'Good except no good screen protectors and bad ar emoji',
#        'Had the Samsung s9 Duo sim over a month and no happy with it no problems',
#        'Galaxy killers lol Best phones',
#        'Loving the new screen and features - no problems so far!',
#        'My phone arrived as expected, no damage or scratches on phone, just as new!',
#        'The galaxy s9, has been ok. I was very sad to lose my Individualized ringtones As oreo does not support it.',
#        'Really happy, no complaints at all, would highly recommend.',
#        'Was told I’d have problems getting used to the X. No problems at all. Really like the phone.',
#        'This phone is Amaze-balls!! I have never loved a phone so much!',
#        'Swapped from and iPhone a month ago and no regretting a single second of it.',
#        'Bought this for my wife and she loves it, no complaints!',
#        'Had no choice. needed a new phone to replace an S8 that I cracked the screen on. It works. No complaints.',
#        'Was struggling with a dying W10 mobile.. what a change!',
#        'Great phone. Very fast and reliable. No complaints so far.',
#        'I love this phone but hate Bixby & cant get rid of it.',
#        'Phone is faster than note 8, less ram however no lag issues.',
#        'Phone is faster than note 8, less ram however no lag issues.'],
#       dtype=object)

# %%
d_list = pd.read_csv('data/doub_neg_edited.csv')
d_list = d_list.dropna()
d_list = list(d_list['negative bigrams'])

#add more double negated phrases and the associated ratings into our double negation lists
more = ["no regret", "no fault", "no problem", 'couldn\'t be happier', "no complain"]

for word in more :
    d_list.append(word)

unique = list(set(d_list))
print("length of our updated list : " +str(len(unique)))
# Out:
# length of our updated list : 37

# %% [markdown]
# > After updating the list, we ended up having 37 double negation phrases.

# %% [markdown]
# ### Part 2. Removing double negated phrases from the review
#
# Now that we have a list of double negations extracted from our dataset, we decided to see if that would change the negativity plots. We will nullify the double negated phrases using our double negative list and create the plots again to see any difference.

# %%
# let's try to remove only those phrases above in the reviews

mylist = list(map(str.lower, unique))

#create a copy of the dataframe
data = df[['review','rating']]

#list of strings to be removed from
review = data['review']
rating = data['rating']
zipped = list(zip(review, rating))

test = zipped
mylist = list(unique)

tup1 = []
tup2 = []
for i in range(len(test)) :
    current = test[i][0]
    current_rating = test[i][1]
    for word in mylist :
        if word in current.lower():
            #print(word)
            current = current.replace(word, '') #remove it?
    
    tup1.append(current)
    tup2.append(current_rating)
    
test_d = pd.DataFrame({'treated' : tup1, 'rating' :tup2})
test_d.head(10)
# Out:
#                                              treated  rating
# 0  The Samsung Galaxy s9 is arguably the most bea...       5
# 1  great  phone smart features easy to use ,, , p...       5
# 2  I really liked the phone. It has good camera w...       4
# 3  First of all the camera quality does not disap...       3
# 4  As a flagship phone goes, everything is pretty...       4
# 5  Had Samsung S9 for just over 1 month, battery ...       2
# 6  The camera quality is very good with this phon...       5
# 7  Fantastic phone. The camera is great and the s...       5
# 8  Camera quality is decent, occasionally plays u...       4
# 9  My New Samsung S9 is my go to girl . I simply ...       5

# %%
# now that we have removed the double negative phrases from the review, let's get the negativity score and compare the plots.

negativity=[]
positivity=[]
compound=[]
sid = SentimentIntensityAnalyzer()

for i in range(len(data)):
    score=sid.polarity_scores(test_d['treated'][i])
    score.keys()
    neg=list(score.values())[0]
    pos=list(score.values())[2]
    comp=list(score.values())[3]
    
    negativity.append(neg)
    positivity.append(pos)
    compound.append(comp)

print("negativity length : " +str(len(negativity)))
print("positivity length : " +str(len(positivity)))
print("compound length : " +str(len(compound)))

test_d['treated_negativity'] = negativity
test_d['treated_positivity'] = positivity
test_d['treated_compound'] = compound
# Out:
# negativity length : 13218
# positivity length : 13218
# compound length : 13218

# %%
plt.figure(figsize=(12,3))
plt.title("negativity plot AFTER removing double negative phrases from the review")
plt.plot(test_d['treated_negativity'], test_d['rating'], 'x')
plt.show()
print(len(test_d)) #13218

plt.figure(figsize=(12,3))
plt.title("negativity plot BEFORE removing double negative phrases from the review")
plt.plot(df['negativity'], df['rating'], 'x')
plt.show()
print(len(df)) #13218
# Out:
# 13218
# 13218

# %% [markdown]
# > After removing the double negated phrases, we saw some changes in our plot. It removed some of the outliers that had higher negativity scores with higher rating. We now know that treating double negative was one thing to improve our model accuracy based on our dataset.

# %% [markdown]
# ## Most common words within negative reviews

# %%
# iPhone X negative reviews
df_a_n = df_a[df_a['sentiment']== 'N']

apple_neg =[]

for y in range(len(df_a_n)):
    kk=re.sub('[^A-Za-z0-9 ]+', '', df_a_n['review'].iloc[y]).lower()
    jj=[i for i in word_tokenize(kk) if i not in stopwords]
    apple_neg = apple_neg+jj
    
Counter(apple_neg).most_common()
# Out:
# [('phone', 480),
#  ('iphone', 280),
#  ('screen', 184),
#  ('x', 159),
#  ('apple', 146),
#  ('like', 101),
#  ('plus', 86),
#  ('dont', 80),
#  ('good', 75),
#  ('use', 75),
#  ('get', 72),
#  ('im', 70),
#  ('would', 70),
#  ('new', 69),
#  ('face', 67),
#  ('really', 65),
#  ('8', 65),
#  ('camera', 59),
#  ('7', 59),
#  ('time', 58),
#  ('much', 57),
#  ('button', 57),
#  ('back', 57),
#  ('apps', 53),
#  ('id', 53),
#  ('one', 52),
#  ('home', 51),
#  ('better', 50),
#  ('price', 50),
#  ('great', 48),
#  ('even', 47),
#  ('doesnt', 46),
#  ('size', 42),
#  ('money', 41),
#  ('ive', 41),
#  ('work', 40),
#  ('also', 40),
#  ('cant', 39),
#  ('worth', 39),
#  ('since', 38),
#  ('battery', 38),
#  ('first', 38),
#  ('recognition', 36),
#  ('way', 35),
#  ('bought', 35),
#  ('phones', 35),
#  ('6', 33),
#  ('still', 32),
#  ('lot', 32),
#  ('could', 32),
#  ('got', 32),
#  ('2', 31),
#  ('glass', 31),
#  ('iphones', 30),
#  ('think', 30),
#  ('using', 30),
#  ('without', 30),
#  ('features', 30),
#  ('buy', 29),
#  ('old', 29),
#  ('months', 28),
#  ('user', 27),
#  ('getting', 26),
#  ('many', 26),
#  ('day', 26),
#  ('used', 25),
#  ('people', 25),
#  ('go', 25),
#  ('say', 25),
#  ('disappointed', 25),
#  ('3', 25),
#  ('days', 24),
#  ('device', 24),
#  ('well', 24),
#  ('know', 24),
#  ('touch', 24),
#  ('android', 24),
#  ('recommend', 24),
#  ('samsung', 23),
#  ('previous', 23),
#  ('love', 23),
#  ('expensive', 23),
#  ('quality', 23),
#  ('charging', 23),
#  ('never', 22),
#  ('purchase', 22),
#  ('times', 22),
#  ('big', 22),
#  ('life', 22),
#  ('top', 22),
#  ('make', 22),
#  ('ever', 21),
#  ('works', 21),
#  ('issues', 21),
#  ('smaller', 21),
#  ('thing', 21),
#  ('isnt', 21),
#  ('however', 21),
#  ('full', 21),
#  ('last', 20),
#  ('years', 20),
#  ('small', 20),
#  ('nice', 20),
#  ('going', 20),
#  ('nothing', 20),
#  ('take', 19),
#  ('made', 19),
#  ('case', 19),
#  ('hold', 19),
#  ('need', 19),
#  ('every', 19),
#  ('store', 19),
#  ('see', 19),
#  ('year', 18),
#  ('slow', 18),
#  ('product', 18),
#  ('thats', 18),
#  ('wish', 18),
#  ('hate', 18),
#  ('freezes', 18),
#  ('difficult', 18),
#  ('return', 18),
#  ('close', 18),
#  ('right', 18),
#  ('sure', 17),
#  ('week', 17),
#  ('another', 17),
#  ('always', 17),
#  ('design', 17),
#  ('everything', 17),
#  ('bit', 17),
#  ('upgrade', 17),
#  ('open', 17),
#  ('two', 17),
#  ('facial', 17),
#  ('app', 17),
#  ('next', 16),
#  ('worst', 16),
#  ('10', 16),
#  ('took', 16),
#  ('least', 16),
#  ('water', 16),
#  ('bad', 16),
#  ('want', 16),
#  ('definitely', 16),
#  ('display', 16),
#  ('annoying', 16),
#  ('sometimes', 16),
#  ('something', 16),
#  ('happy', 16),
#  ('att', 16),
#  ('came', 15),
#  ('things', 15),
#  ('didnt', 15),
#  ('especially', 15),
#  ('looking', 15),
#  ('hard', 15),
#  ('bigger', 15),
#  ('6s', 15),
#  ('miss', 15),
#  ('horrible', 15),
#  ('find', 14),
#  ('photos', 14),
#  ('takes', 14),
#  ('problem', 14),
#  ('larger', 14),
#  ('cost', 14),
#  ('less', 14),
#  ('returned', 14),
#  ('ok', 14),
#  ('wouldnt', 14),
#  ('though', 14),
#  ('working', 14),
#  ('month', 14),
#  ('purchased', 14),
#  ('feature', 14),
#  ('far', 14),
#  ('quite', 14),
#  ('ill', 14),
#  ('products', 13),
#  ('software', 13),
#  ('keep', 13),
#  ('half', 13),
#  ('ago', 13),
#  ('paying', 13),
#  ('anyone', 13),
#  ('longer', 13),
#  ('give', 13),
#  ('overall', 13),
#  ('went', 13),
#  ('wireless', 13),
#  ('compared', 13),
#  ('instead', 13),
#  ('impressed', 13),
#  ('hours', 12),
#  ('models', 12),
#  ('hear', 12),
#  ('wait', 12),
#  ('makes', 12),
#  ('almost', 12),
#  ('heavy', 12),
#  ('buying', 12),
#  ('front', 12),
#  ('fine', 12),
#  ('replace', 12),
#  ('weeks', 12),
#  ('hype', 12),
#  ('issue', 12),
#  ('whole', 12),
#  ('calls', 12),
#  ('fast', 12),
#  ('extremely', 12),
#  ('else', 12),
#  ('lack', 12),
#  ('pretty', 12),
#  ('long', 12),
#  ('buttons', 12),
#  ('actually', 11),
#  ('excited', 11),
#  ('terrible', 11),
#  ('easy', 11),
#  ('high', 11),
#  ('etc', 11),
#  ('soon', 11),
#  ('ridiculous', 11),
#  ('5', 11),
#  ('point', 11),
#  ('said', 11),
#  ('amazing', 11),
#  ('photo', 11),
#  ('enough', 11),
#  ('brand', 11),
#  ('gone', 11),
#  ('anything', 11),
#  ('considering', 11),
#  ('already', 11),
#  ('4', 11),
#  ('overpriced', 11),
#  ('headphone', 11),
#  ('super', 11),
#  ('extra', 11),
#  ('little', 11),
#  ('finger', 11),
#  ('difference', 11),
#  ('huge', 11),
#  ('fix', 10),
#  ('owned', 10),
#  ('trying', 10),
#  ('speed', 10),
#  ('wont', 10),
#  ('different', 10),
#  ('feel', 10),
#  ('galaxy', 10),
#  ('edge', 10),
#  ('version', 10),
#  ('service', 10),
#  ('turn', 10),
#  ('put', 10),
#  ('customer', 10),
#  ('look', 10),
#  ('around', 10),
#  ('replacement', 10),
#  ('wasnt', 10),
#  ('thought', 10),
#  ('friendly', 10),
#  ('bottom', 10),
#  ('fan', 10),
#  ('charge', 10),
#  ('real', 10),
#  ('received', 10),
#  ('seems', 10),
#  ('iphonex', 10),
#  ('option', 10),
#  ('best', 10),
#  ('speaker', 10),
#  ('swipe', 10),
#  ('video', 10),
#  ('upgraded', 10),
#  ('siri', 10),
#  ('reason', 9),
#  ('model', 9),
#  ('seem', 9),
#  ('worse', 9),
#  ('end', 9),
#  ('call', 9),
#  ('tech', 9),
#  ('screens', 9),
#  ('repair', 9),
#  ('mode', 9),
#  ('within', 9),
#  ('release', 9),
#  ('able', 9),
#  ('everyone', 9),
#  ('1000', 9),
#  ('told', 9),
#  ('hand', 9),
#  ('watch', 9),
#  ('come', 9),
#  ('experience', 9),
#  ('easily', 9),
#  ('fingerprint', 9),
#  ('faceid', 9),
#  ('protector', 9),
#  ('change', 9),
#  ('switching', 9),
#  ('wrong', 9),
#  ('print', 9),
#  ('comes', 9),
#  ('power', 9),
#  ('youre', 9),
#  ('videos', 9),
#  ('simply', 9),
#  ('due', 9),
#  ('text', 9),
#  ('7plus', 9),
#  ('goes', 9),
#  ('yet', 8),
#  ('away', 8),
#  ('constantly', 8),
#  ('fragile', 8),
#  ('damage', 8),
#  ('feels', 8),
#  ('absolutely', 8),
#  ('finally', 8),
#  ('gets', 8),
#  ('rather', 8),
#  ('tag', 8),
#  ('keeps', 8),
#  ('disappointment', 8),
#  ('older', 8),
#  ('picture', 8),
#  ('care', 8),
#  ('reset', 8),
#  ('cracked', 8),
#  ('average', 8),
#  ('closing', 8),
#  ('jack', 8),
#  ('box', 8),
#  ('theres', 8),
#  ('scratches', 8),
#  ('hands', 8),
#  ('maybe', 8),
#  ('notch', 8),
#  ('missing', 8),
#  ('unlock', 8),
#  ('either', 8),
#  ('returning', 8),
#  ('paid', 7),
#  ('honestly', 7),
#  ('probably', 7),
#  ('needs', 7),
#  ('dropped', 7),
#  ('literally', 7),
#  ('making', 7),
#  ('drop', 7),
#  ('expect', 7),
#  ('large', 7),
#  ('resistant', 7),
#  ('improvement', 7),
#  ('disappointing', 7),
#  ('often', 7),
#  ('three', 7),
#  ('bring', 7),
#  ('reception', 7),
#  ('pay', 7),
#  ('side', 7),
#  ('couple', 7),
#  ('restart', 7),
#  ('stupid', 7),
#  ('order', 7),
#  ('volume', 7),
#  ('later', 7),
#  ('save', 7),
#  ('kept', 7),
#  ('freezing', 7),
#  ('line', 7),
#  ('help', 7),
#  ('fact', 7),
#  ('spend', 7),
#  ('okay', 7),
#  ('opinion', 7),
#  ('try', 7),
#  ('function', 7),
#  ('looks', 7),
#  ('lock', 7),
#  ('turned', 7),
#  ('sucks', 7),
#  ('steps', 7),
#  ('support', 6),
#  ('useless', 6),
#  ('deal', 6),
#  ('bluetooth', 6),
#  ('mine', 6),
#  ('let', 6),
#  ('proof', 6),
#  ('justify', 6),
#  ('heavier', 6),
#  ('plan', 6),
#  ('fell', 6),
#  ('hour', 6),
#  ('waste', 6),
#  ('understand', 6),
#  ('night', 6),
#  ('twice', 6),
#  ('replaced', 6),
#  ('us', 6),
#  ('company', 6),
#  ('special', 6),
#  ('sound', 6),
#  ('someone', 6),
#  ('faulty', 6),
#  ('minutes', 6),
#  ('seconds', 6),
#  ('piece', 6),
#  ('pro', 6),
#  ('barely', 6),
#  ('dark', 6),
#  ('glitches', 6),
#  ('read', 6),
#  ('step', 6),
#  ('s8', 6),
#  ('found', 6),
#  ('sales', 6),
#  ('music', 6),
#  ('hope', 6),
#  ('lower', 6),
#  ('coming', 6),
#  ('set', 6),
#  ('access', 6),
#  ('technology', 6),
#  ('switch', 6),
#  ('beautiful', 6),
#  ('delete', 6),
#  ('scratched', 6),
#  ('note', 6),
#  ('review', 6),
#  ('speakers', 6),
#  ('google', 6),
#  ('stick', 6),
#  ('online', 6),
#  ('past', 6),
#  ('system', 6),
#  ('taking', 6),
#  ('send', 6),
#  ('randomly', 6),
#  ('stop', 6),
#  ('may', 5),
#  ('value', 5),
#  ('designed', 5),
#  ('black', 5),
#  ('clunky', 5),
#  ('along', 5),
#  ('feeling', 5),
#  ('smooth', 5),
#  ('emails', 5),
#  ('drops', 5),
#  ('part', 5),
#  ('cases', 5),
#  ('sim', 5),
#  ('job', 5),
#  ('apart', 5),
#  ('warranty', 5),
#  ('matter', 5),
#  ('means', 5),
#  ('portrait', 5),
#  ('data', 5),
#  ('left', 5),
#  ('poor', 5),
#  ('helped', 5),
#  ('might', 5),
#  ('control', 5),
#  ('please', 5),
#  ('whats', 5),
#  ('costs', 5),
#  ('premium', 5),
#  ('options', 5),
#  ('green', 5),
#  ('light', 5),
#  ('started', 5),
#  ('connect', 5),
#  ('major', 5),
#  ('short', 5),
#  ('gotten', 5),
#  ('expected', 5),
#  ('example', 5),
#  ('called', 5),
#  ('problems', 5),
#  ('processor', 5),
#  ('required', 5),
#  ('arent', 5),
#  ('percentage', 5),
#  ('glitchy', 5),
#  ('completely', 5),
#  ('decided', 5),
#  ('frustrating', 5),
#  ('code', 5),
#  ('reality', 5),
#  ('unlocking', 5),
#  ('done', 5),
#  ('faster', 5),
#  ('ios', 5),
#  ('touchid', 5),
#  ('play', 5),
#  ('game', 5),
#  ('start', 5),
#  ('although', 5),
#  ('cool', 5),
#  ('stuck', 5),
#  ('scanner', 5),
#  ('oh', 5),
#  ('slide', 5),
#  ('settings', 5),
#  ('everytime', 5),
#  ('fit', 5),
#  ('ordered', 5),
#  ('1', 5),
#  ('must', 5),
#  ('wanted', 5),
#  ('recognize', 5),
#  ('needed', 5),
#  ('others', 5),
#  ('idea', 5),
#  ('watching', 5),
#  ('multiple', 5),
#  ('cell', 5),
#  ('switched', 5),
#  ('highly', 5),
#  ('exchange', 5),
#  ('mention', 5),
#  ('regret', 5),
#  ('awesome', 5),
#  ('expectations', 4),
#  ('via', 4),
#  ('fall', 4),
#  ('media', 4),
#  ('advertising', 4),
#  ('standard', 4),
#  ('certainly', 4),
#  ('3rd', 4),
#  ('fault', 4),
#  ('interface', 4),
#  ('accidentally', 4),
#  ('wired', 4),
#  ('saying', 4),
#  ('liquid', 4),
#  ('covered', 4),
#  ('rating', 4),
#  ('unless', 4),
#  ('cover', 4),
#  ('multitasking', 4),
#  ('six', 4),
#  ('clear', 4),
#  ('build', 4),
#  ('optus', 4),
#  ('port', 4),
#  ('changed', 4),
#  ('felt', 4),
#  ('wide', 4),
#  ('launch', 4),
#  ('crap', 4),
#  ('similar', 4),
#  ('sad', 4),
#  ('wants', 4),
#  ('brought', 4),
#  ('overheating', 4),
#  ('basically', 4),
#  ('choice', 4),
#  ('freeze', 4),
#  ('frozen', 4),
#  ('itunes', 4),
#  ('hardware', 4),
#  ('devices', 4),
#  ('original', 4),
#  ('pick', 4),
#  ('quickly', 4),
#  ('microphone', 4),
#  ('biggest', 4),
#  ('floor', 4),
#  ('recommended', 4),
#  ('slowed', 4),
#  ('stand', 4),
#  ('friend', 4),
#  ('oled', 4),
#  ('ones', 4),
#  ('across', 4),
#  ('typing', 4),
#  ('broke', 4),
#  ('husband', 4),
#  ('name', 4),
#  ('ipad', 4),
#  ('sides', 4),
#  ('s9', 4),
#  ('reader', 4),
#  ('seriously', 4),
#  ('sensor', 4),
#  ('tried', 4),
#  ('compare', 4),
#  ('quick', 4),
#  ('amount', 4),
#  ('convenient', 4),
#  ('couldnt', 4),
#  ('cheaper', 4),
#  ('focus', 4),
#  ('tv', 4),
#  ('perfect', 4),
#  ('despite', 4),
#  ('waiting', 4),
#  ('8plus', 4),
#  ('easier', 4),
#  ('otherwise', 4),
#  ('wasted', 4),
#  ('shame', 4),
#  ('running', 4),
#  ('changes', 4),
#  ('rumours', 4),
#  ('nightmare', 4),
#  ('forward', 4),
#  ('operating', 4),
#  ('useful', 4),
#  ('charger', 4),
#  ('tap', 4),
#  ('activate', 4),
#  ('guy', 4),
#  ('nope', 4),
#  ('apples', 4),
#  ('slower', 4),
#  ('pain', 4),
#  ('viewing', 4),
#  ('mean', 4),
#  ('messages', 4),
#  ('latest', 4),
#  ('awful', 4),
#  ('mistake', 4),
#  ('available', 4),
#  ('added', 4),
#  ('heard', 4),
#  ('liked', 4),
#  ('family', 4),
#  ('lots', 4),
#  ('performance', 4),
#  ('map', 4),
#  ('message', 4),
#  ('consider', 4),
#  ('ratio', 4),
#  ('wifi', 4),
#  ('bugs', 4),
#  ('several', 4),
#  ('space', 4),
#  ('allow', 4),
#  ('width', 4),
#  ('holding', 4),
#  ('moving', 4),
#  ('defective', 4),
#  ('turning', 4),
#  ('sent', 4),
#  ('becoming', 3),
#  ('spent', 3),
#  ('known', 3),
#  ('versions', 3),
#  ('earphones', 3),
#  ('friends', 3),
#  ('personal', 3),
#  ('breakable', 3),
#  ('break', 3),
#  ('item', 3),
#  ('refuse', 3),
#  ('30', 3),
#  ('ip', 3),
#  ('knows', 3),
#  ('knock', 3),
#  ('instantly', 3),
#  ('rain', 3),
#  ('actual', 3),
#  ('incredibly', 3),
#  ('run', 3),
#  ('runs', 3),
#  ('ie', 3),
#  ('worked', 3),
#  ('properly', 3),
#  ('second', 3),
#  ('stay', 3),
#  ('cable', 3),
#  ('refund', 3),
#  ('lemon', 3),
#  ('yellow', 3),
#  ('white', 3),
#  ('priced', 3),
#  ('failed', 3),
#  ('australia', 3),
#  ('installed', 3),
#  ('shock', 3),
#  ('blue', 3),
#  ('given', 3),
#  ('date', 3),
#  ('limited', 3),
#  ('area', 3),
#  ('wanting', 3),
#  ('iti', 3),
#  ('believe', 3),
#  ('recently', 3),
#  ('15', 3),
#  ('logo', 3),
#  ('enjoyed', 3),
#  ('lags', 3),
#  ('normal', 3),
#  ('social', 3),
#  ('breaking', 3),
#  ('broken', 3),
#  ('simple', 3),
#  ('laggy', 3),
#  ('users', 3),
#  ('flagship', 3),
#  ('60', 3),
#  ('recent', 3),
#  ('air', 3),
#  ('confusing', 3),
#  ('person', 3),
#  ('yes', 3),
#  ('reboot', 3),
#  ('kind', 3),
#  ('reading', 3),
#  ('glasses', 3),
#  ('verizon', 3),
#  ('traded', 3),
#  ('missed', 3),
#  ('walked', 3),
#  ('happen', 3),
#  ('becomes', 3),
#  ('unresponsive', 3),
#  ('contract', 3),
#  ('self', 3),
#  ('adjust', 3),
#  ('launched', 3),
#  ('table', 3),
#  ('durable', 3),
#  ('shut', 3),
#  ('rid', 3),
#  ('innovation', 3),
#  ('immediately', 3),
#  ('random', 3),
#  ('avoid', 3),
#  ('itthe', 3),
#  ('storage', 3),
#  ('included', 3),
#  ('looked', 3),
#  ('gorilla', 3),
#  ('chance', 3),
#  ('alarm', 3),
#  ('stopped', 3),
#  ('giving', 3),
#  ('experiencing', 3),
#  ('checked', 3),
#  ('password', 3),
#  ('slippery', 3),
#  ('improvements', 3),
#  ('apparently', 3),
#  ('entire', 3),
#  ('tell', 3),
#  ('become', 3),
#  ('building', 3),
#  ('12', 3),
#  ('pieces', 3),
#  ('check', 3),
#  ('customers', 3),
#  ('spending', 3),
#  ('setting', 3),
#  ('usage', 3),
#  ('enter', 3),
#  ('crazy', 3),
#  ('specially', 3),
#  ('terms', 3),
#  ('transfer', 3),
#  ('wow', 3),
#  ('except', 3),
#  ('hoping', 3),
#  ('likely', 3),
#  ('2017', 3),
#  ('morning', 3),
#  ('comfortable', 3),
#  ('everyday', 3),
#  ('lag', 3),
#  ('pocket', 3),
#  ('carefully', 3),
#  ('selling', 3),
#  ('fee', 3),
#  ('facing', 3),
#  ('emergency', 3),
#  ('show', 3),
#  ('nah', 3),
#  ('macbook', 3),
#  ('honest', 3),
#  ('hot', 3),
#  ('fully', 3),
#  ('4k', 3),
#  ('inscreen', 3),
#  ('proximity', 3),
#  ('true', 3),
#  ('list', 3),
#  ('weird', 3),
#  ('september', 3),
#  ('preordered', 3),
#  ('gestures', 3),
#  ('improved', 3),
#  ('virtually', 3),
#  ('truly', 3),
#  ('taken', 3),
#  ('functions', 3),
#  ('opening', 3),
#  ('double', 3),
#  ('screenshot', 3),
#  ('course', 3),
#  ('youll', 3),
#  ('sensitive', 3),
#  ('secure', 3),
#  ('body', 3),
#  ('stainless', 3),
#  ('airpods', 3),
#  ('andor', 3),
#  ('functionality', 3),
#  ('important', 3),
#  ('daily', 3),
#  ('havent', 3),
#  ('sunglasses', 3),
#  ('gimmick', 3),
#  ('bar', 3),
#  ('requires', 3),
#  ('loyal', 3),
#  ('complicated', 3),
#  ('aware', 3),
#  ('download', 3),
#  ('filling', 3),
#  ('application', 3),
#  ('greatest', 3),
#  ('dollars', 3),
#  ('guess', 3),
#  ('decision', 3),
#  ('refurbished', 3),
#  ('trade', 3),
#  ('specs', 3),
#  ('wonderful', 3),
#  ('discontinue', 3),
#  ('crack', 3),
#  ('significant', 3),
#  ('learn', 3),
#  ('unfortunately', 3),
#  ('headphones', 3),
#  ('personally', 3),
#  ('luckily', 3),
#  ('tricky', 3),
#  ('youtube', 3),
#  ('future', 3),
#  ('pictures', 3),
#  ('today', 3),
#  ('animoji', 3),
#  ('opened', 3),
#  ('sounds', 3),
#  ('knew', 3),
#  ('email', 3),
#  ('accounts', 3),
#  ('unhappy', 3),
#  ('overrated', 3),
#  ('drive', 3),
#  ('seeing', 3),
#  ('weight', 3),
#  ('main', 3),
#  ('regretting', 3),
#  ('leaves', 3),
#  ('thicker', 3),
#  ('internet', 3),
#  ('outside', 3),
#  ('entirely', 3),
#  ('speak', 3),
#  ('landscape', 3),
#  ('upper', 3),
#  ('keyboard', 3),
#  ('wider', 3),
#  ('loved', 3),
#  ('programs', 3),
#  ('appears', 3),
#  ('press', 3),
#  ('luck', 3),
#  ('brightness', 3),
#  ('texts', 3),
#  ('locked', 3),
#  ('place', 3),
#  ('gps', 3),
#  ('lg', 3),
#  ('swiping', 3),
#  ('hang', 3),
#  ('jump', 3),
#  ('bc', 3),
#  ('thin', 2),
#  ('meh', 2),
#  ('marketing', 2),
#  ('happier', 2),
#  ('centre', 2),
#  ('genius', 2),
#  ('fancy', 2),
#  ('operate', 2),
#  ('harder', 2),
#  ('whatsapp', 2),
#  ('failure', 2),
#  ('whether', 2),
#  ('basic', 2),
#  ('everybody', 2),
#  ('sometime', 2),
#  ('materials', 2),
#  ('carry', 2),
#  ('purpose', 2),
#  ('style', 2),
#  ('blowing', 2),
#  ('false', 2),
#  ('splash', 2),
#  ('son', 2),
#  ('damaged', 2),
#  ('blank', 2),
#  ('min', 2),
#  ('load', 2),
#  ('representative', 2),
#  ('68', 2),
#  ('falling', 2),
#  ('misleading', 2),
#  ('seen', 2),
#  ('positives', 2),
#  ('1700', 2),
#  ('dry', 2),
#  ('hangs', 2),
#  ('lightning', 2),
#  ('talking', 2),
#  ('ripped', 2),
#  ('colours', 2),
#  ('interesting', 2),
#  ('add', 2),
#  ('apply', 2),
#  ('duel', 2),
#  ('telcos', 2),
#  ('tick', 2),
#  ('telstra', 2),
#  ('rural', 2),
#  ('country', 2),
#  ('areas', 2),
#  ('city', 2),
#  ('gives', 2),
#  ('carrier', 2),
#  ('items', 2),
#  ('based', 2),
#  ('happening', 2),
#  ('ripping', 2),
#  ('newest', 2),
#  ('sleek', 2),
#  ('shine', 2),
#  ('256gb', 2),
#  ('sd', 2),
#  ('card', 2),
#  ('temperature', 2),
#  ('advertise', 2),
#  ('prior', 2),
#  ('resolve', 2),
#  ('lying', 2),
#  ('repaired', 2),
#  ('usual', 2),
#  ('information', 2),
#  ('positive', 2),
#  ('force', 2),
#  ('laptop', 2),
#  ('adelaide', 2),
#  ('massive', 2),
#  ('noticeable', 2),
#  ('sucked', 2),
#  ('higher', 2),
#  ('complete', 2),
#  ('crashing', 2),
#  ('warn', 2),
#  ('happened', 2),
#  ('1800', 2),
#  ('images', 2),
#  ('supposedly', 2),
#  ('1m', 2),
#  ('ip67', 2),
#  ('payment', 2),
#  ('frustration', 2),
#  ('16', 2),
#  ('period', 2),
#  ('post', 2),
#  ('sold', 2),
#  ('huawei', 2),
#  ('perform', 2),
#  ('beyond', 2),
#  ('suddenly', 2),
#  ('machine', 2),
#  ('damn', 2),
#  ('imagine', 2),
#  ('annoys', 2),
#  ('wall', 2),
#  ('breaks', 2),
#  ('loads', 2),
#  ('forever', 2),
#  ('sunnies', 2),
#  ('trash', 2),
#  ('bars', 2),
#  ...]

# %%
# Galaxy S9 negative reviews
df_s_n = df_s[df_s['sentiment']=='N']

samsung_neg =[]

for y in range(len(df_s_n)):
    kk=re.sub('[^A-Za-z0-9 ]+', '', df_s_n['review'].iloc[y]).lower()
    jj=[i for i in word_tokenize(kk) if i not in stopwords]
    samsung_neg = samsung_neg+jj
    
Counter(samsung_neg).most_common()
# Out:
# [('phone', 766),
#  ('samsung', 268),
#  ('s9', 223),
#  ('battery', 196),
#  ('s7', 187),
#  ('screen', 187),
#  ('use', 138),
#  ('good', 133),
#  ('bought', 129),
#  ('get', 125),
#  ('back', 122),
#  ('camera', 121),
#  ('like', 119),
#  ('im', 119),
#  ('dont', 118),
#  ('iphone', 115),
#  ('ago', 115),
#  ('week', 106),
#  ('cant', 101),
#  ('ive', 101),
#  ('got', 100),
#  ('life', 98),
#  ('better', 98),
#  ('new', 96),
#  ('really', 96),
#  ('one', 95),
#  ('apps', 90),
#  ('bixby', 89),
#  ('weeks', 89),
#  ('would', 89),
#  ('last', 88),
#  ('work', 87),
#  ('much', 86),
#  ('doesnt', 86),
#  ('even', 84),
#  ('edge', 83),
#  ('2', 82),
#  ('s8', 77),
#  ('galaxy', 76),
#  ('old', 73),
#  ('great', 72),
#  ('features', 71),
#  ('day', 69),
#  ('still', 69),
#  ('also', 68),
#  ('time', 68),
#  ('phones', 66),
#  ('disappointed', 65),
#  ('wish', 60),
#  ('button', 58),
#  ('3', 56),
#  ('using', 52),
#  ('years', 52),
#  ('days', 51),
#  ('go', 51),
#  ('poor', 51),
#  ('app', 49),
#  ('never', 48),
#  ('used', 48),
#  ('many', 47),
#  ('want', 47),
#  ('annoying', 47),
#  ('upgraded', 46),
#  ('nothing', 44),
#  ('always', 43),
#  ('different', 41),
#  ('everything', 39),
#  ('upgrade', 39),
#  ('text', 39),
#  ('find', 38),
#  ('lot', 38),
#  ('happy', 37),
#  ('s6', 37),
#  ('two', 36),
#  ('things', 36),
#  ('make', 36),
#  ('need', 36),
#  ('slow', 36),
#  ('thought', 36),
#  ('month', 35),
#  ('well', 35),
#  ('could', 34),
#  ('see', 34),
#  ('charge', 33),
#  ('quality', 33),
#  ('way', 32),
#  ('first', 31),
#  ('software', 31),
#  ('seems', 31),
#  ('money', 31),
#  ('7', 30),
#  ('keep', 30),
#  ('thing', 30),
#  ('apple', 30),
#  ('change', 30),
#  ('far', 30),
#  ('getting', 30),
#  ('difference', 30),
#  ('call', 30),
#  ('problems', 29),
#  ('bad', 29),
#  ('without', 29),
#  ('think', 29),
#  ('another', 28),
#  ('sometimes', 28),
#  ('ever', 28),
#  ('ok', 28),
#  ('android', 28),
#  ('easy', 28),
#  ('calls', 28),
#  ('4', 27),
#  ('buy', 27),
#  ('settings', 27),
#  ('feature', 27),
#  ('less', 27),
#  ('keeps', 27),
#  ('say', 27),
#  ('half', 27),
#  ('months', 26),
#  ('working', 26),
#  ('hours', 26),
#  ('hate', 26),
#  ('id', 26),
#  ('going', 26),
#  ('know', 25),
#  ('previous', 25),
#  ('big', 25),
#  ('constantly', 25),
#  ('however', 25),
#  ('update', 25),
#  ('takes', 24),
#  ('home', 24),
#  ('data', 24),
#  ('problem', 24),
#  ('issues', 24),
#  ('messages', 24),
#  ('able', 24),
#  ('isnt', 24),
#  ('take', 24),
#  ('took', 23),
#  ('best', 23),
#  ('kept', 23),
#  ('loved', 23),
#  ('6', 23),
#  ('message', 23),
#  ('trying', 23),
#  ('bit', 23),
#  ('long', 23),
#  ('terrible', 22),
#  ('anything', 22),
#  ('price', 22),
#  ('year', 22),
#  ('user', 22),
#  ('touch', 22),
#  ('bluetooth', 22),
#  ('etc', 22),
#  ('wouldnt', 22),
#  ('love', 22),
#  ('issue', 21),
#  ('pretty', 21),
#  ('glass', 21),
#  ('wont', 21),
#  ('note', 21),
#  ('times', 21),
#  ('side', 21),
#  ('every', 21),
#  ('hear', 21),
#  ('gone', 21),
#  ('let', 20),
#  ('done', 20),
#  ('worth', 20),
#  ('face', 20),
#  ('rubbish', 20),
#  ('pictures', 20),
#  ('charging', 20),
#  ('little', 20),
#  ('around', 19),
#  ('made', 19),
#  ('stuck', 19),
#  ('case', 19),
#  ('went', 19),
#  ('people', 19),
#  ('keyboard', 19),
#  ('device', 19),
#  ('needs', 19),
#  ('hand', 19),
#  ('since', 19),
#  ('right', 19),
#  ('notifications', 19),
#  ('sound', 19),
#  ('didnt', 18),
#  ('recommend', 18),
#  ('switch', 18),
#  ('recognition', 18),
#  ('several', 18),
#  ('contacts', 18),
#  ('google', 18),
#  ('look', 18),
#  ('feel', 18),
#  ('already', 18),
#  ('due', 17),
#  ('curved', 17),
#  ('hard', 17),
#  ('yet', 17),
#  ('something', 17),
#  ('next', 17),
#  ('plus', 17),
#  ('impressed', 17),
#  ('nice', 17),
#  ('pay', 17),
#  ('9', 17),
#  ('difficult', 17),
#  ('signal', 17),
#  ('useless', 17),
#  ('1', 16),
#  ('told', 16),
#  ('set', 16),
#  ('waste', 16),
#  ('photos', 16),
#  ('works', 16),
#  ('properly', 16),
#  ('tried', 16),
#  ('couple', 16),
#  ('small', 16),
#  ('sure', 16),
#  ('awful', 16),
#  ('gets', 15),
#  ('goes', 15),
#  ('changing', 15),
#  ('frustrating', 15),
#  ('buttons', 15),
#  ('makes', 15),
#  ('put', 15),
#  ('may', 15),
#  ('adverts', 15),
#  ('att', 15),
#  ('compared', 15),
#  ('design', 15),
#  ('theres', 15),
#  ('dropped', 14),
#  ('shop', 14),
#  ('worse', 14),
#  ('voice', 14),
#  ('try', 14),
#  ('decided', 14),
#  ('press', 14),
#  ('finger', 14),
#  ('fingerprint', 14),
#  ('looks', 14),
#  ('basic', 14),
#  ('notification', 14),
#  ('either', 14),
#  ('recently', 14),
#  ('access', 14),
#  ('store', 14),
#  ('s5', 14),
#  ('found', 14),
#  ('option', 14),
#  ('speaker', 14),
#  ('volume', 14),
#  ('miss', 14),
#  ('prefer', 14),
#  ('seem', 14),
#  ('else', 14),
#  ('fix', 13),
#  ('cracked', 13),
#  ('turn', 13),
#  ('smart', 13),
#  ('8', 13),
#  ('hold', 13),
#  ('purchased', 13),
#  ('sim', 13),
#  ('faster', 13),
#  ('tone', 13),
#  ('couldnt', 13),
#  ('full', 13),
#  ('send', 13),
#  ('worst', 13),
#  ('extra', 13),
#  ('fact', 13),
#  ('5', 13),
#  ('hot', 13),
#  ('low', 13),
#  ('music', 13),
#  ('power', 12),
#  ('havent', 12),
#  ('brought', 12),
#  ('brand', 12),
#  ('friendly', 12),
#  ('system', 12),
#  ('easily', 12),
#  ('functions', 12),
#  ('car', 12),
#  ('product', 12),
#  ('tones', 12),
#  ('download', 12),
#  ('add', 12),
#  ('texting', 12),
#  ('give', 12),
#  ('wait', 12),
#  ('mode', 12),
#  ('fast', 12),
#  ('play', 12),
#  ('unlocked', 12),
#  ('unlock', 12),
#  ('unless', 12),
#  ('performance', 12),
#  ('thats', 12),
#  ('second', 12),
#  ('move', 12),
#  ('honest', 12),
#  ('ads', 12),
#  ('front', 12),
#  ('expecting', 12),
#  ('fan', 12),
#  ('memory', 12),
#  ('predictive', 12),
#  ('least', 11),
#  ('service', 11),
#  ('cost', 11),
#  ('horrible', 11),
#  ('taking', 11),
#  ('updates', 11),
#  ('quickly', 11),
#  ('end', 11),
#  ('regret', 11),
#  ('transfer', 11),
#  ('probably', 11),
#  ('super', 11),
#  ('function', 11),
#  ('control', 11),
#  ('video', 11),
#  ('quite', 11),
#  ('unfortunately', 11),
#  ('calling', 11),
#  ('wasnt', 11),
#  ('disappointing', 11),
#  ('though', 11),
#  ('amazing', 11),
#  ('expected', 11),
#  ('apart', 11),
#  ('scanner', 11),
#  ('wanted', 11),
#  ('finding', 11),
#  ('thinking', 11),
#  ('often', 11),
#  ('feels', 11),
#  ('expensive', 10),
#  ('help', 10),
#  ('model', 10),
#  ('type', 10),
#  ('lost', 10),
#  ('important', 10),
#  ('returned', 10),
#  ('nightmare', 10),
#  ('background', 10),
#  ('hope', 10),
#  ('changes', 10),
#  ('taken', 10),
#  ('extremely', 10),
#  ('wifi', 10),
#  ('experience', 10),
#  ('radio', 10),
#  ('connect', 10),
#  ('worked', 10),
#  ('changed', 10),
#  ('pop', 10),
#  ('overall', 10),
#  ('size', 10),
#  ('drop', 10),
#  ('10', 10),
#  ('broke', 10),
#  ('enough', 10),
#  ('charger', 10),
#  ('slightly', 10),
#  ('review', 10),
#  ('person', 10),
#  ('instead', 10),
#  ('hadnt', 10),
#  ('stop', 10),
#  ('internet', 10),
#  ('contract', 10),
#  ('replaced', 10),
#  ('understand', 10),
#  ('ill', 10),
#  ('away', 10),
#  ('basically', 10),
#  ('preferred', 10),
#  ('smaller', 10),
#  ('start', 10),
#  ('faulty', 10),
#  ('barely', 9),
#  ('pressing', 9),
#  ('protector', 9),
#  ('typing', 9),
#  ('mistake', 9),
#  ('display', 9),
#  ('friends', 9),
#  ('close', 9),
#  ('switched', 9),
#  ('ring', 9),
#  ('sending', 9),
#  ('playing', 9),
#  ('certain', 9),
#  ('options', 9),
#  ('simple', 9),
#  ('dissapointed', 9),
#  ('point', 9),
#  ('sent', 9),
#  ('stopped', 9),
#  ('main', 9),
#  ('mine', 9),
#  ('bigger', 9),
#  ('bottom', 9),
#  ('facebook', 9),
#  ('rather', 9),
#  ('must', 9),
#  ('whole', 9),
#  ('pocket', 9),
#  ('replace', 9),
#  ('u', 9),
#  ('handset', 9),
#  ('almost', 8),
#  ('edges', 8),
#  ('started', 8),
#  ('although', 8),
#  ('connecting', 8),
#  ('samsungs', 8),
#  ('version', 8),
#  ('sucks', 8),
#  ('games', 8),
#  ('number', 8),
#  ('looking', 8),
#  ('came', 8),
#  ('come', 8),
#  ('onto', 8),
#  ('tell', 8),
#  ('swipe', 8),
#  ('videos', 8),
#  ('youre', 8),
#  ('card', 8),
#  ('excited', 8),
#  ('short', 8),
#  ('crack', 8),
#  ('gave', 8),
#  ('asked', 8),
#  ('freezes', 8),
#  ('light', 8),
#  ('yes', 8),
#  ('alot', 8),
#  ('lasts', 8),
#  ('running', 8),
#  ('fixed', 8),
#  ('port', 8),
#  ('none', 8),
#  ('buying', 8),
#  ('actually', 8),
#  ('place', 8),
#  ('picture', 8),
#  ('network', 8),
#  ('struggling', 8),
#  ('part', 8),
#  ('print', 8),
#  ('making', 8),
#  ('otherwise', 8),
#  ('improved', 8),
#  ('turns', 8),
#  ('removed', 8),
#  ('bar', 8),
#  ('correct', 8),
#  ('wrong', 7),
#  ('photo', 7),
#  ('nearly', 7),
#  ('sides', 7),
#  ('stupid', 7),
#  ('iphones', 7),
#  ('protectors', 7),
#  ('coming', 7),
#  ('expectations', 7),
#  ('similar', 7),
#  ('mobile', 7),
#  ('stay', 7),
#  ('despite', 7),
#  ('sounds', 7),
#  ('runs', 7),
#  ('3rd', 7),
#  ('words', 7),
#  ('choice', 7),
#  ('special', 7),
#  ('tap', 7),
#  ('check', 7),
#  ('unhappy', 7),
#  ('happens', 7),
#  ('including', 7),
#  ('please', 7),
#  ('disappointment', 7),
#  ('twice', 7),
#  ('absolutely', 7),
#  ('hype', 7),
#  ('contact', 7),
#  ('deal', 7),
#  ('tech', 7),
#  ('support', 7),
#  ('charged', 7),
#  ('paid', 7),
#  ('missing', 7),
#  ('screens', 7),
#  ('fine', 7),
#  ('someone', 7),
#  ('click', 7),
#  ('moved', 7),
#  ('youtube', 7),
#  ('ios', 7),
#  ('constant', 7),
#  ('anyone', 7),
#  ('100', 7),
#  ('maybe', 7),
#  ('s10', 7),
#  ('top', 7),
#  ('audio', 7),
#  ('fault', 7),
#  ('ones', 7),
#  ('uses', 7),
#  ('texts', 7),
#  ('harder', 7),
#  ('order', 7),
#  ('quick', 7),
#  ('hands', 7),
#  ('sensor', 7),
#  ('owned', 7),
#  ('reason', 7),
#  ('idea', 7),
#  ('huge', 7),
#  ('available', 7),
#  ('lots', 7),
#  ('sorry', 7),
#  ('longer', 7),
#  ('known', 7),
#  ('black', 7),
#  ('assistant', 7),
#  ('near', 7),
#  ('three', 7),
#  ('considering', 7),
#  ('iris', 7),
#  ('saving', 6),
#  ('focus', 6),
#  ('stayed', 6),
#  ('crap', 6),
#  ('cheap', 6),
#  ('smashed', 6),
#  ('repair', 6),
#  ('pain', 6),
#  ('run', 6),
#  ('definitely', 6),
#  ('soon', 6),
#  ('selling', 6),
#  ('tv', 6),
#  ('except', 6),
#  ('expect', 6),
#  ('later', 6),
#  ('box', 6),
#  ('stars', 6),
#  ('turning', 6),
#  ('icon', 6),
#  ('slower', 6),
#  ('online', 6),
#  ('real', 6),
#  ('amount', 6),
#  ('hardly', 6),
#  ('putting', 6),
#  ('left', 6),
#  ('attempts', 6),
#  ('checked', 6),
#  ('compatible', 6),
#  ('ups', 6),
#  ('mo', 6),
#  ('speed', 6),
#  ('upgrading', 6),
#  ('sold', 6),
#  ('locked', 6),
#  ('key', 6),
#  ('broken', 6),
#  ('night', 6),
#  ('within', 6),
#  ('unable', 6),
#  ('opinion', 6),
#  ('read', 6),
#  ('reset', 6),
#  ('today', 6),
#  ('job', 6),
#  ('dropping', 6),
#  ('scratches', 6),
#  ('honestly', 6),
#  ('previously', 6),
#  ('numerous', 6),
#  ('ad', 6),
#  ('perfect', 6),
#  ('headphones', 6),
#  ('everyone', 6),
#  ('third', 6),
#  ('received', 6),
#  ('exactly', 6),
#  ('responsive', 6),
#  ('emoji', 6),
#  ('ee', 6),
#  ('dead', 6),
#  ('regretting', 6),
#  ('especially', 6),
#  ('1st', 6),
#  ('means', 6),
#  ('decent', 6),
#  ('auto', 6),
#  ('unresponsive', 6),
#  ('sad', 6),
#  ('noticed', 6),
#  ('force', 6),
#  ('complicated', 6),
#  ('devices', 6),
#  ('shocking', 6),
#  ('brilliant', 6),
#  ('save', 6),
#  ('via', 6),
#  ('bothered', 6),
#  ('quiet', 6),
#  ('middle', 6),
#  ('live', 6),
#  ('fit', 6),
#  ('space', 6),
#  ('account', 6),
#  ('slipped', 6),
#  ('crashing', 6),
#  ('cell', 6),
#  ('setting', 5),
#  ('says', 5),
#  ('husband', 5),
#  ('open', 5),
#  ('sadly', 5),
#  ('mind', 5),
#  ('points', 5),
#  ('meaning', 5),
#  ('speakers', 5),
#  ('figure', 5),
#  ('operating', 5),
#  ('sell', 5),
#  ('everyday', 5),
#  ('total', 5),
#  ('respond', 5),
#  ('connected', 5),
#  ('called', 5),
#  ('customize', 5),
#  ('hardware', 5),
#  ('bloatware', 5),
#  ('mean', 5),
#  ('thanks', 5),
#  ('party', 5),
#  ('knew', 5),
#  ('example', 5),
#  ('accidentally', 5),
#  ('trouble', 5),
#  ('instagram', 5),
#  ('pick', 5),
#  ('straight', 5),
#  ('turned', 5),
#  ('area', 5),
#  ('intuitive', 5),
#  ('provider', 5),
#  ('normal', 5),
#  ('improvement', 5),
#  ('voicemail', 5),
#  ('push', 5),
#  ('mad', 5),
#  ('highly', 5),
#  ('carrier', 5),
#  ('curve', 5),
#  ('bring', 5),
#  ('easier', 5),
#  ('navigation', 5),
#  ('till', 5),
#  ('driving', 5),
#  ('disable', 5),
#  ('process', 5),
#  ('connection', 5),
#  ('weak', 5),
#  ('placed', 5),
#  ('whatsapp', 5),
#  ('drive', 5),
#  ('supposed', 5),
#  ('motion', 5),
#  ('glitchy', 5),
#  ('keeping', 5),
#  ('24', 5),
#  ('lasted', 5),
#  ('boring', 5),
#  ('moment', 5),
#  ('shot', 5),
#  ('needed', 5),
#  ('said', 5),
#  ('sony', 5),
#  ('whilst', 5),
#  ('talking', 5),
#  ('completely', 5),
#  ('cutting', 5),
#  ('windows', 5),
#  ('huawei', 5),
#  ('impossible', 5),
#  ('swapped', 5),
#  ('irritating', 5),
#  ('sort', 5),
#  ('freezing', 5),
#  ('clunky', 5),
#  ('hoping', 5),
#  ('shame', 5),
#  ('spots', 5),
#  ('drains', 5),
#  ('keen', 5),
#  ('multiple', 5),
#  ('ram', 5),
#  ('white', 5),
#  ('wants', 5),
#  ('heard', 5),
#  ('excellent', 5),
#  ('adjust', 5),
#  ('others', 5),
#  ('messenger', 5),
#  ('select', 5),
#  ('quicker', 5),
#  ('usage', 5),
#  ('pressed', 5),
#  ('replacement', 5),
#  ('email', 5),
#  ('dedicated', 5),
#  ('given', 5),
#  ('personal', 5),
#  ('handle', 5),
#  ('return', 5),
#  ('security', 5),
#  ('lovely', 5),
#  ('wife', 5),
#  ('cool', 5),
#  ('older', 5),
#  ('whenever', 4),
#  ('customer', 4),
#  ('protect', 4),
#  ('freeze', 4),
#  ('functionality', 4),
#  ('beautiful', 4),
#  ('smooth', 4),
#  ('files', 4),
#  ('major', 4),
#  ('biggest', 4),
#  ('latest', 4),
#  ('remote', 4),
#  ('water', 4),
#  ('choose', 4),
#  ('literally', 4),
#  ('rest', 4),
#  ('friend', 4),
#  ('retina', 4),
#  ('failed', 4),
#  ('across', 4),
#  ('shouldnt', 4),
#  ('fantastic', 4),
#  ('annoyed', 4),
#  ('market', 4),
#  ('opens', 4),
#  ('garbage', 4),
#  ('15', 4),
#  ('minutes', 4),
#  ('touched', 4),
#  ('cast', 4),
#  ('originally', 4),
#  ('yesterday', 4),
#  ('numbers', 4),
#  ('absolute', 4),
#  ('deleted', 4),
#  ('ringtone', 4),
#  ('lack', 4),
#  ('talk', 4),
#  ('clearly', 4),
#  ('models', 4),
#  ('emails', 4),
#  ('notice', 4),
#  ('slick', 4),
#  ('facial', 4),
#  ('fitbit', 4),
#  ('wireless', 4),
#  ('insurance', 4),
#  ('high', 4),
#  ('arrive', 4),
#  ('waiting', 4),
#  ('show', 4),
#  ('unbelievable', 4),
#  ('address', 4),
#  ('microphone', 4),
#  ('fall', 4),
#  ('inches', 4),
#  ('break', 4),
#  ('clumsy', 4),
#  ('interface', 4),
#  ('verizon', 4),
#  ('max', 4),
#  ('oh', 4),
#  ('disappeared', 4),
#  ('perfectly', 4),
#  ('pro', 4),
#  ('disabled', 4),
#  ('fingers', 4),
#  ('eg', 4),
#  ('whats', 4),
#  ('randomly', 4),
#  ('listen', 4),
#  ('forward', 4),
#  ('n', 4),
#  ('colour', 4),
#  ('remove', 4),
#  ('gutted', 4),
#  ('nokia', 4),
#  ('forever', 4),
#  ('fully', 4),
#  ('stuff', 4),
#  ('saying', 4),
#  ('ages', 4),
#  ('slowly', 4),
#  ('p20', 4),
#  ('sleek', 4),
#  ('protective', 4),
#  ('totally', 4),
#  ('rid', 4),
#  ('past', 4),
#  ('looked', 4),
#  ('shots', 4),
#  ('losing', 4),
#  ('view', 4),
#  ('floor', 4),
#  ('updated', 4),
#  ('letters', 4),
#  ('facing', 4),
#  ('6s', 4),
#  ('backwards', 4),
#  ('alarm', 4),
#  ('20', 4),
#  ('fed', 4),
#  ('hasnt', 4),
#  ('built', 4),
#  ('watching', 4),
#  ('become', 4),
#  ('fails', 4),
#  ('e', 4),
#  ('individual', 4),
#  ('stands', 4),
#  ('range', 4),
#  ('correctly', 4),
#  ('standard', 4),
#  ('happen', 4),
#  ('prefered', 4),
#  ('ability', 4),
#  ('weather', 4),
#  ('frame', 4),
#  ('therefore', 4),
#  ('bank', 4),
#  ('traded', 4),
#  ('enjoy', 4),
#  ('loud', 4),
#  ('hi', 4),
#  ('happened', 4),
#  ('whether', 4),
#  ('wake', 4),
#  ('exchanging', 4),
#  ('enjoying', 4),
#  ('sensitivity', 4),
#  ('age', 4),
#  ('coverage', 4),
#  ('heating', 4),
#  ('value', 4),
#  ('touching', 4),
#  ('ridiculous', 4),
#  ('choices', 4),
#  ('spell', 4),
#  ('g7', 4),
#  ('worry', 4),
#  ('messaging', 4),
#  ('record', 4),
#  ('assist', 4),
#  ('medium', 3),
#  ('hour', 3),
#  ('wonder', 3),
#  ('30', 3),
#  ('dollars', 3),
#  ('cover', 3),
#  ('joke', 3),
#  ('smash', 3),
#  ('actual', 3),
#  ('kind', 3),
#  ('family', 3),
#  ('personally', 3),
#  ('brightness', 3),
#  ('complaint', 3),
#  ('bixbie', 3),
#  ('everytime', 3),
#  ('siri', 3),
#  ('delayed', 3),
#  ('transferred', 3),
#  ('guess', 3),
#  ('arent', 3),
#  ('name', 3),
#  ('newer', 3),
#  ('write', 3),
#  ('confusing', 3),
#  ('ringtones', 3),
#  ('visual', 3),
#  ('clean', 3),
#  ('privacy', 3),
#  ('ahead', 3),
#  ('research', 3),
#  ('anywhere', 3),
#  ('opening', 3),
#  ('random', 3),
#  ('receive', 3),
#  ('media', 3),
#  ('connectivity', 3),
#  ('instantly', 3),
#  ('desk', 3),
#  ('encountered', 3),
#  ('suggested', 3),
#  ('watch', 3),
#  ('finally', 3),
#  ('added', 3),
#  ('90', 3),
#  ('seemed', 3),
#  ('msg', 3),
#  ('recording', 3),
#  ('bother', 3),
#  ('800', 3),
#  ('delay', 3),
#  ('future', 3),
#  ('plenty', 3),
#  ('14', 3),
#  ('behind', 3),
#  ('believe', 3),
#  ('cause', 3),
#  ('clear', 3),
#  ('tiny', 3),
#  ('forget', 3),
#  ('factory', 3),
#  ('cumbersome', 3),
#  ('lock', 3),
#  ('justify', 3),
#  ('apparently', 3),
#  ('viber', 3),
#  ('helpful', 3),
#  ('nuts', 3),
#  ('careful', 3),
#  ('spent', 3),
#  ('resolved', 3),
#  ('fail', 3),
#  ('offering', 3),
#  ('8s', 3),
#  ('reliable', 3),
#  ('lol', 3),
#  ('leaving', 3),
#  ('j6', 3),
#  ('offered', 3),
#  ('regards', 3),
#  ('popping', 3),
#  ('us', 3),
#  ('immediately', 3),
#  ('waited', 3),
#  ('sitting', 3),
#  ('restarting', 3),
#  ('fiddly', 3),
#  ('corner', 3),
#  ('page', 3),
#  ('chips', 3),
#  ('restart', 3),
#  ('frustrated', 3),
#  ('disaster', 3),
#  ('picked', 3),
#  ('self', 3),
#  ('leave', 3),
#  ('house', 3),
#  ('accent', 3),
#  ('react', 3),
#  ('writing', 3),
#  ('saturday', 3),
#  ('muffled', 3),
#  ('minimal', 3),
#  ('purple', 3),
#  ('sign', 3),
#  ('receiving', 3),
#  ('comfortable', 3),
#  ('fragile', 3),
#  ('appears', 3),
#  ('lacking', 3),
#  ('pair', 3),
#  ('improvements', 3),
#  ('interested', 3),
#  ('thumb', 3),
#  ('7edge', 3),
#  ('places', 3),
#  ('foot', 3),
#  ...]

# %% [markdown]
# #### iPhone X
#
# - Our team was curious what "screen" meant in the review. After a simple Google search, we found out that there was touch issues and Apple ended up replacing the display module at no cost.
#
#         https://www.apple.com/support/iphone-x-display-module-replacement-program/
#
# - "face" is probably stating face recognition problem.
#
# - "price" is a concern in Apple's review. This make senses because iPhone was released at \$999, and Galaxy S9 was released at \$719.99.
#
# #### Gaalxy S9
#
# - "battery" and "camera" are most common words. These two are known problems of Galaxy S series.
# <br>
# <br>
#
# We have to keep in mind this is only looking at frequencies of single words. We can guess what these words mean to consumers, but there is no way we will know for sure unless more research is done.
#
#     e.g.
#     1. we can't automatically assume 'camera' here mean 'bad camera' just beacause we are looking at negative reviews. There could be positive sentences in a low rated reviews.
#
#     2. we don't know what 'screen' exactly means in iphone's common words.
#
# Our next analysis takes care of this problem.

# %%
# following review is a positive review (5 star). BUT negativity score is high and positivity score is 0.

# This is due to 'double negation'. 

n=13201

sid = SentimentIntensityAnalyzer()
score=sid.polarity_scores(df['review'][n])
score.keys()
list(score.values())
print('rating: ', df['rating'][n])
print(df['sentiment'][n])
print(df['review'][n])
score
# Out:
# rating:  5
# P
# Legit phone no bad aspects
# {'neg': 0.655, 'neu': 0.345, 'pos': 0.0, 'compound': -0.6908}

# %% [markdown]
# ## n-grams
#
# n-gram will output every combination of n sequencial words in a review. Here, I'm adding all of tokenized words into a list and getting the frequencies of n-grams. Since I'm creating n-grams with "N" sentiment for each product, this will give us **clearer ideas of what customers are NOT happy about**.

# %%
# iphone negative review 2-gram

master_2grams_a =[]

df_a_n = df_a[df_a['sentiment'] == 'N']

for y in range(len(df_a_n)):
    kk=re.sub('[^A-Za-z0-9 ]+', '', df_a_n['review'].iloc[y]).lower()
    jj=[i for i in word_tokenize(kk) if i not in stopwords]

    n_grams=ngrams(jj, 2)
    qq=[ ' '.join(grams) for grams in n_grams]

    master_2grams_a = master_2grams_a + qq

# %%
Counter(master_2grams_a).most_common()
# Out:
# [('iphone x', 98),
#  ('home button', 41),
#  ('face id', 28),
#  ('iphone 7', 28),
#  ('7 plus', 23),
#  ('iphone 8', 22),
#  ('face recognition', 19),
#  ('8 plus', 19),
#  ('iphone 6', 18),
#  ('battery life', 16),
#  ('facial recognition', 16),
#  ('doesnt work', 13),
#  ('full screen', 12),
#  ('phone x', 10),
#  ('new phone', 10),
#  ('worth money', 10),
#  ('much better', 9),
#  ('wireless charging', 9),
#  ('dont think', 9),
#  ('iphone 6s', 9),
#  ('screen protector', 9),
#  ('price tag', 8),
#  ('dont know', 8),
#  ('user friendly', 8),
#  ('headphone jack', 8),
#  ('finger print', 8),
#  ('apple products', 7),
#  ('bought iphone', 7),
#  ('much money', 7),
#  ('apple store', 7),
#  ('like iphone', 7),
#  ('screen size', 7),
#  ('old iphone', 7),
#  ('brand new', 6),
#  ('think worth', 6),
#  ('use phone', 6),
#  ('top bottom', 6),
#  ('phone would', 6),
#  ('6 plus', 6),
#  ('good phone', 6),
#  ('phone 2', 6),
#  ('get phone', 6),
#  ('bigger screen', 6),
#  ('dont like', 6),
#  ('old phone', 6),
#  ('dont get', 6),
#  ('note 8', 6),
#  ('close apps', 6),
#  ('iphone user', 6),
#  ('get used', 6),
#  ('great phone', 6),
#  ('phone freezes', 6),
#  ('phone im', 6),
#  ('work well', 5),
#  ('hold phone', 5),
#  ('phone also', 5),
#  ('better phone', 5),
#  ('got iphone', 5),
#  ('apple product', 5),
#  ('phone ever', 5),
#  ('worth price', 5),
#  ('bottom screen', 5),
#  ('previous iphone', 5),
#  ('would recommend', 5),
#  ('battery percentage', 5),
#  ('got phone', 5),
#  ('last iphone', 5),
#  ('phone good', 5),
#  ('previous iphones', 5),
#  ('2 months', 5),
#  ('getting used', 5),
#  ('3 months', 5),
#  ('half time', 5),
#  ('every iphone', 5),
#  ('happy phone', 5),
#  ('im really', 5),
#  ('bought phone', 5),
#  ('im sure', 5),
#  ('screen goes', 5),
#  ('really excited', 5),
#  ('ive phone', 5),
#  ('phone user', 5),
#  ('price point', 5),
#  ('plus size', 5),
#  ('phone week', 4),
#  ('ever owned', 4),
#  ('bought one', 4),
#  ('water proof', 4),
#  ('since iphone', 4),
#  ('portrait mode', 4),
#  ('feel like', 4),
#  ('samsung galaxy', 4),
#  ('camera better', 4),
#  ('like phone', 4),
#  ('quality phone', 4),
#  ('really like', 4),
#  ('back apple', 4),
#  ('purchase phone', 4),
#  ('many issues', 4),
#  ('apple iphone', 4),
#  ('water resistant', 4),
#  ('phone ive', 4),
#  ('good camera', 4),
#  ('camera quality', 4),
#  ('phone works', 4),
#  ('purchased phone', 4),
#  ('phone screen', 4),
#  ('worst phone', 4),
#  ('glass screen', 4),
#  ('apple fan', 4),
#  ('recommend phone', 4),
#  ('closing apps', 4),
#  ('galaxy s8', 4),
#  ('phone really', 4),
#  ('2 weeks', 4),
#  ('home screen', 4),
#  ('wouldnt recommend', 4),
#  ('open phone', 4),
#  ('lower price', 4),
#  ('cant even', 4),
#  ('really worth', 4),
#  ('screen smaller', 4),
#  ('extra money', 4),
#  ('money phone', 4),
#  ('save money', 4),
#  ('charge phone', 4),
#  ('lack home', 4),
#  ('edge edge', 4),
#  ('get wrong', 4),
#  ('wrong phone', 4),
#  ('unlock phone', 4),
#  ('way better', 4),
#  ('touch id', 4),
#  ('screen would', 4),
#  ('first time', 4),
#  ('first iphone', 4),
#  ('phone worth', 4),
#  ('missing home', 4),
#  ('since first', 4),
#  ('phone dont', 4),
#  ('returning phone', 4),
#  ('customer service', 4),
#  ('every time', 4),
#  ('phone doesnt', 4),
#  ('cell phone', 4),
#  ('im disappointed', 4),
#  ('open apps', 4),
#  ('phone great', 4),
#  ('phone phone', 4),
#  ('iphones since', 4),
#  ('x plus', 4),
#  ('x size', 4),
#  ('plus x', 4),
#  ('im impressed', 4),
#  ('next phone', 3),
#  ('apple support', 3),
#  ('phone useless', 3),
#  ('value money', 3),
#  ('ive always', 3),
#  ('excited get', 3),
#  ('high tech', 3),
#  ('camera good', 3),
#  ('dropped phone', 3),
#  ('took apple', 3),
#  ('liquid damage', 3),
#  ('phone amazing', 3),
#  ('justify price', 3),
#  ('like apple', 3),
#  ('waste money', 3),
#  ('charging cable', 3),
#  ('doesnt even', 3),
#  ('sim could', 3),
#  ('using 2', 3),
#  ('got brand', 3),
#  ('used phone', 3),
#  ('previous phone', 3),
#  ('much much', 3),
#  ('phone keeps', 3),
#  ('4 months', 3),
#  ('apple id', 3),
#  ('everything phone', 3),
#  ('wish could', 3),
#  ('apple care', 3),
#  ('2 days', 3),
#  ('x apple', 3),
#  ('three months', 3),
#  ('hard reset', 3),
#  ('reset phone', 3),
#  ('times day', 3),
#  ('apple said', 3),
#  ('older models', 3),
#  ('like face', 3),
#  ('iphone 3', 3),
#  ('gorilla glass', 3),
#  ('new one', 3),
#  ('really bad', 3),
#  ('bad phone', 3),
#  ('upgrade iphone', 3),
#  ('touch screen', 3),
#  ('compare iphone', 3),
#  ('get 8', 3),
#  ('back glass', 3),
#  ('half price', 3),
#  ('back phone', 3),
#  ('previous models', 3),
#  ('apple apple', 3),
#  ('easy use', 3),
#  ('whole day', 3),
#  ('even worse', 3),
#  ('x last', 3),
#  ('smaller phone', 3),
#  ('unlocking phone', 3),
#  ('buy screen', 3),
#  ('still use', 3),
#  ('using phone', 3),
#  ('switching apps', 3),
#  ('life good', 3),
#  ('id doesnt', 3),
#  ('get use', 3),
#  ('iphone 5', 3),
#  ('size screen', 3),
#  ('7 8', 3),
#  ('screen screen', 3),
#  ('power phone', 3),
#  ('apps like', 3),
#  ('x phone', 3),
#  ('larger phone', 3),
#  ('2 years', 3),
#  ('user since', 3),
#  ('ive owned', 3),
#  ('lot better', 3),
#  ('dont use', 3),
#  ('front back', 3),
#  ('android device', 3),
#  ('upgraded iphone', 3),
#  ('would probably', 3),
#  ('screen great', 3),
#  ('nothing special', 3),
#  ('faceid works', 3),
#  ('next year', 3),
#  ('phone iphone', 3),
#  ('disappointed phone', 3),
#  ('hate phone', 3),
#  ('refurbished phone', 3),
#  ('iphone 7plus', 3),
#  ('phone lot', 3),
#  ('user experience', 3),
#  ('apple definitely', 3),
#  ('first came', 3),
#  ('isnt even', 3),
#  ('everything else', 3),
#  ('buy 8', 3),
#  ('phone calls', 3),
#  ('days ago', 3),
#  ('new phones', 3),
#  ('plus phone', 3),
#  ('dont buy', 3),
#  ('text message', 3),
#  ('screen also', 3),
#  ('phone nice', 3),
#  ('extra steps', 3),
#  ('ive iphone', 3),
#  ('still dont', 3),
#  ('freezes doesnt', 3),
#  ('small compared', 3),
#  ('iphone since', 3),
#  ('new features', 3),
#  ('right box', 3),
#  ('new iphone', 3),
#  ('landscape video', 3),
#  ('app app', 3),
#  ('size plus', 3),
#  ('back iphone', 3),
#  ('two years', 3),
#  ('time phone', 3),
#  ('version phone', 3),
#  ('plus would', 3),
#  ('phone less', 3),
#  ('return phone', 3),
#  ('gone 8', 3),
#  ('dont waste', 3),
#  ('way much', 3),
#  ('didnt like', 3),
#  ('purchase another', 2),
#  ('another apple', 2),
#  ('apple device', 2),
#  ('previous versions', 2),
#  ('versions iphone', 2),
#  ('worst iphone', 2),
#  ('iphone ever', 2),
#  ('dont even', 2),
#  ('much happier', 2),
#  ('always apple', 2),
#  ('apple phone', 2),
#  ('get iphone', 2),
#  ('10 months', 2),
#  ('months im', 2),
#  ('cant hear', 2),
#  ('way easy', 2),
#  ('great camera', 2),
#  ('well phone', 2),
#  ('using bluetooth', 2),
#  ('earphones wired', 2),
#  ('wired earphones', 2),
#  ('friends problem', 2),
#  ('new screen', 2),
#  ('large screen', 2),
#  ('camera phone', 2),
#  ('false advertising', 2),
#  ('love portrait', 2),
#  ('everything runs', 2),
#  ('heavy really', 2),
#  ('really disappointing', 2),
#  ('build quality', 2),
#  ('id never', 2),
#  ('back samsung', 2),
#  ('issues screen', 2),
#  ('lemon phone', 2),
#  ('phone thats', 2),
#  ('dont understand', 2),
#  ('lot changed', 2),
#  ('three times', 2),
#  ('years ago', 2),
#  ('smaller version', 2),
#  ('screen big', 2),
#  ('take phone', 2),
#  ('phone back', 2),
#  ('took back', 2),
#  ('could hear', 2),
#  ('bring back', 2),
#  ('got lemon', 2),
#  ('phones good', 2),
#  ('blue tick', 2),
#  ('new model', 2),
#  ('helped people', 2),
#  ('put another', 2),
#  ('ripping people', 2),
#  ('paying premium', 2),
#  ('apple logo', 2),
#  ('phone 8', 2),
#  ('sound quality', 2),
#  ('definitely worth', 2),
#  ('absolutely worth', 2),
#  ('nice design', 2),
#  ('phone faulty', 2),
#  ('phone working', 2),
#  ('make phone', 2),
#  ('phone cant', 2),
#  ('phone wasnt', 2),
#  ('cant give', 2),
#  ('another month', 2),
#  ('screen touch', 2),
#  ('didnt work', 2),
#  ('connect itunes', 2),
#  ('8 much', 2),
#  ('phone upgrade', 2),
#  ('worse phone', 2),
#  ('already iphone', 2),
#  ('keeps crashing', 2),
#  ('ive 4', 2),
#  ('going back', 2),
#  ('apple cant', 2),
#  ('8 x', 2),
#  ('need warn', 2),
#  ('phone water', 2),
#  ('30 minutes', 2),
#  ('phone take', 2),
#  ('piece hardware', 2),
#  ('never buy', 2),
#  ('would like', 2),
#  ('apps everything', 2),
#  ('money im', 2),
#  ('work phone', 2),
#  ('ive ever', 2),
#  ('recognition doesnt', 2),
#  ('take back', 2),
#  ('phone ok', 2),
#  ('phone camera', 2),
#  ('quality good', 2),
#  ('ok phone', 2),
#  ('traded iphone', 2),
#  ('7 phone', 2),
#  ('works great', 2),
#  ('week later', 2),
#  ('case recommended', 2),
#  ('8 top', 2),
#  ('purchased x', 2),
#  ('phone three', 2),
#  ('last year', 2),
#  ('id cant', 2),
#  ('cant really', 2),
#  ('ever used', 2),
#  ('phone least', 2),
#  ('3 times', 2),
#  ('day phone', 2),
#  ('screen becomes', 2),
#  ('becomes unresponsive', 2),
#  ('dropped carpet', 2),
#  ('cracked screen', 2),
#  ('green line', 2),
#  ('phone average', 2),
#  ('compared previous', 2),
#  ('compared older', 2),
#  ('purchased iphone', 2),
#  ('bad experience', 2),
#  ('recommend friend', 2),
#  ('something else', 2),
#  ('disappointed iphone', 2),
#  ('fan since', 2),
#  ('1000 phone', 2),
#  ('screen cracked', 2),
#  ('fix screen', 2),
#  ('6 would', 2),
#  ('want charge', 2),
#  ('id love', 2),
#  ('quite heavy', 2),
#  ('much recommend', 2),
#  ('display good', 2),
#  ('get galaxy', 2),
#  ('fingerprint reader', 2),
#  ('company made', 2),
#  ('screen lot', 2),
#  ('lot people', 2),
#  ('apple im', 2),
#  ('happy iphone', 2),
#  ('phone fast', 2),
#  ('new camera', 2),
#  ('really good', 2),
#  ('x worst', 2),
#  ('received replacement', 2),
#  ('phone returned', 2),
#  ('samsung s9', 2),
#  ('anyone else', 2),
#  ('6s really', 2),
#  ('care much', 2),
#  ('found phone', 2),
#  ('phone call', 2),
#  ('screen almost', 2),
#  ('phone many', 2),
#  ('hope helps', 2),
#  ('otter box', 2),
#  ('phone fell', 2),
#  ('glass phone', 2),
#  ('dont apple', 2),
#  ('phone half', 2),
#  ('working phone', 2),
#  ('phone apple', 2),
#  ('recommend iphone', 2),
#  ('whole phone', 2),
#  ('around month', 2),
#  ('pieces glass', 2),
#  ('paying 1000', 2),
#  ('much new', 2),
#  ('phone however', 2),
#  ('slow like', 2),
#  ('dont want', 2),
#  ('want change', 2),
#  ('even set', 2),
#  ('x easy', 2),
#  ('apple need', 2),
#  ('reality check', 2),
#  ('switching samsung', 2),
#  ('okay phone', 2),
#  ('price id', 2),
#  ('id recommend', 2),
#  ('apple phones', 2),
#  ('also like', 2),
#  ('charging phone', 2),
#  ('battery lift', 2),
#  ('last whole', 2),
#  ('problem battery', 2),
#  ('would better', 2),
#  ('face detection', 2),
#  ('would purchase', 2),
#  ('8 instead', 2),
#  ('used iphone', 2),
#  ('great bigger', 2),
#  ('button frustrating', 2),
#  ('looking phone', 2),
#  ('miss home', 2),
#  ('phone unlocked', 2),
#  ('screen aniemoji', 2),
#  ('waiting iphone', 2),
#  ('long time', 2),
#  ('spend extra', 2),
#  ('little bit', 2),
#  ('falls short', 2),
#  ('screen definitely', 2),
#  ('day like', 2),
#  ('like previous', 2),
#  ('using iphone', 2),
#  ('screen better', 2),
#  ('difference price', 2),
#  ('good samsung', 2),
#  ('switch back', 2),
#  ('set alarm', 2),
#  ('new product', 2),
#  ('fast charging', 2),
#  ('make sure', 2),
#  ('smaller iphone', 2),
#  ('phone find', 2),
#  ('without screen', 2),
#  ('one day', 2),
#  ('looking carefully', 2),
#  ('screen scratched', 2),
#  ('nothing really', 2),
#  ('print reader', 2),
#  ('pretty good', 2),
#  ('phone need', 2),
#  ('nah nah', 2),
#  ('apps even', 2),
#  ('x worth', 2),
#  ('macbook pro', 2),
#  ('7 battery', 2),
#  ('looks feels', 2),
#  ('overall would', 2),
#  ('device would', 2),
#  ('inscreen touchid', 2),
#  ('proximity charging', 2),
#  ('within 2', 2),
#  ('couple days', 2),
#  ('owned iphone', 2),
#  ('bit old', 2),
#  ('without home', 2),
#  ('great size', 2),
#  ('top screen', 2),
#  ('huge step', 2),
#  ('removal home', 2),
#  ('activate applepay', 2),
#  ('use siri', 2),
#  ('screen however', 2),
#  ('time works', 2),
#  ('phone due', 2),
#  ('thought would', 2),
#  ('glass front', 2),
#  ('iphone yet', 2),
#  ('price phone', 2),
#  ('phone isnt', 2),
#  ('iphone nothing', 2),
#  ('last apple', 2),
#  ('however price', 2),
#  ('sure worth', 2),
#  ('older phones', 2),
#  ('years ive', 2),
#  ('also great', 2),
#  ('recognition works', 2),
#  ('takes longer', 2),
#  ('longer get', 2),
#  ('phone using', 2),
#  ('runs smoothly', 2),
#  ('old one', 2),
#  ('apple intentionally', 2),
#  ('slowed old', 2),
#  ('overpriced especially', 2),
#  ('especially considering', 2),
#  ('getting iphone', 2),
#  ('use faceid', 2),
#  ('phone instead', 2),
#  ('apps big', 2),
#  ('seconds bring', 2),
#  ('turn phone', 2),
#  ('hear like', 2),
#  ('id say', 2),
#  ('wait next', 2),
#  ('price new', 2),
#  ('button annoying', 2),
#  ('annoying first', 2),
#  ('x user', 2),
#  ('user must', 2),
#  ('slide bottom', 2),
#  ('app close', 2),
#  ('screen nice', 2),
#  ('getting use', 2),
#  ('even know', 2),
#  ('back forth', 2),
#  ('thing phone', 2),
#  ('text messages', 2),
#  ('considering returning', 2),
#  ('phone getting', 2),
#  ('latest greatest', 2),
#  ('comes price', 2),
#  ('bells whistles', 2),
#  ('youre paying', 2),
#  ('time cant', 2),
#  ('doesnt headphone', 2),
#  ('since day', 2),
#  ('speaker phone', 2),
#  ('connect bluetooth', 2),
#  ('big mistake', 2),
#  ('thing like', 2),
#  ('recommend getting', 2),
#  ('something new', 2),
#  ('user always', 2),
#  ('fell love', 2),
#  ('pick phone', 2),
#  ('worth hype', 2),
#  ('iphone 10', 2),
#  ('listening music', 2),
#  ('use touch', 2),
#  ('id isnt', 2),
#  ('doesnt home', 2),
#  ('like every', 2),
#  ('things could', 2),
#  ('phone cost', 2),
#  ('much also', 2),
#  ('pretty much', 2),
#  ('give refurbished', 2),
#  ('really miss', 2),
#  ('love size', 2),
#  ('fingerprint scanner', 2),
#  ('phone first', 2),
#  ('wish would', 2),
#  ('would kept', 2),
#  ('kept iphone', 2),
#  ('like took', 2),
#  ('charging port', 2),
#  ('phone use', 2),
#  ('difference face', 2),
#  ('phone could', 2),
#  ('first one', 2),
#  ('many times', 2),
#  ('pretty phone', 2),
#  ('camera amazing', 2),
#  ('tricky use', 2),
#  ('phone smaller', 2),
#  ('whole lot', 2),
#  ('edition iphones', 2),
#  ('older iphones', 2),
#  ('fan phone', 2),
#  ('recommend anyone', 2),
#  ('10 days', 2),
#  ('week ago', 2),
#  ('isnt much', 2),
#  ('recognition handy', 2),
#  ('worth extra', 2),
#  ('scratches screen', 2),
#  ('screen since', 2),
#  ('since bought', 2),
#  ('times times', 2),
#  ('use switching', 2),
#  ('phone 6', 2),
#  ('come back', 2),
#  ('spending much', 2),
#  ('use 6', 2),
#  ('cant say', 2),
#  ('wish id', 2),
#  ('like camera', 2),
#  ('ago already', 2),
#  ('phones x', 2),
#  ('problem phone', 2),
#  ('nice screen', 2),
#  ('get im', 2),
#  ('could send', 2),
#  ('send back', 2),
#  ('phone huge', 2),
#  ('huge disappointment', 2),
#  ('10 times', 2),
#  ('randomly open', 2),
#  ('phone terrible', 2),
#  ('terrible horrible', 2),
#  ('horrible clunky', 2),
#  ('clunky high', 2),
#  ('tech worth', 2),
#  ('worth month', 2),
#  ('month picking', 2),
#  ('picking s10', 2),
#  ('s10 stop', 2),
#  ('stop pain', 2),
#  ('pain android', 2),
#  ('android apple', 2),
#  ('definitely android', 2),
#  ('goes fritz', 2),
#  ('fritz drops', 2),
#  ('drops email', 2),
#  ('email accounts', 2),
#  ('accounts randomly', 2),
#  ('randomly microphone', 2),
#  ('microphone doesnt', 2),
#  ('work im', 2),
#  ('im 3rd', 2),
#  ('3rd replacement', 2),
#  ('replacement since', 2),
#  ('since september', 2),
#  ('september extremely', 2),
#  ('extremely unhappy', 2),
#  ('unhappy verizon', 2),
#  ('verizon support', 2),
#  ('support customer', 2),
#  ('customer 20years', 2),
#  ('20years horrible', 2),
#  ('use google', 2),
#  ('photos text', 2),
#  ('x screen', 2),
#  ('also facial', 2),
#  ('work dark', 2),
#  ('speed camera', 2),
#  ('phone design', 2),
#  ('way close', 2),
#  ('big thing', 2),
#  ('small phone', 2),
#  ('notch battery', 2),
#  ('felt like', 2),
#  ('like extra', 2),
#  ('phone small', 2),
#  ('screen larger', 2),
#  ('months really', 2),
#  ('phone annoying', 2),
#  ('must say', 2),
#  ('yeah right', 2),
#  ('ive iphones', 2),
#  ('recognition absolutely', 2),
#  ('aspect ratio', 2),
#  ('doesnt use', 2),
#  ('going apple', 2),
#  ('days phone', 2),
#  ('3 days', 2),
#  ('phone took', 2),
#  ('received phone', 2),
#  ('new design', 2),
#  ('reset well', 2),
#  ('getting im', 2),
#  ('back store', 2),
#  ('screen dont', 2),
#  ('operating system', 2),
#  ('sometimes doesnt', 2),
#  ('home key', 2),
#  ('work correctly', 2),
#  ('fingerprint sensor', 2),
#  ('apps difficult', 2),
#  ('phone beautiful', 2),
#  ('features also', 2),
#  ('ive issues', 2),
#  ('getting phone', 2),
#  ('leaves lot', 2),
#  ('lot desired', 2),
#  ('apps dont', 2),
#  ('camera isnt', 2),
#  ('watching video', 2),
#  ('att store', 2),
#  ('upgraded 7', 2),
#  ('7 iphone', 2),
#  ('impressed new', 2),
#  ('like size', 2),
#  ('seriously considering', 2),
#  ('anything else', 2),
#  ('used plus', 2),
#  ('id animojis', 2),
#  ('8 iphone', 2),
#  ('fan new', 2),
#  ('plus sized', 2),
#  ('sized iphone', 2),
#  ('x next', 2),
#  ('hits top', 2),
#  ('size old', 2),
#  ('something really', 2),
#  ('difficult use', 2),
#  ('x back', 2),
#  ('review screen', 2),
#  ('size iphone', 2),
#  ('got x', 2),
#  ('experience iphone', 2),
#  ('screen without', 2),
#  ('days upgrading', 2),
#  ('upgrading iphone', 2),
#  ('6 x', 2),
#  ('stainless steel', 2),
#  ('screen im', 2),
#  ('next notch', 2),
#  ('making calls', 2),
#  ('two days', 2),
#  ('least 6', 2),
#  ('defective phones', 2),
#  ('never heard', 2),
#  ('heard anyone', 2),
#  ('everything takes', 2),
#  ('open close', 2),
#  ('apps get', 2),
#  ('new operating', 2),
#  ('looks like', 2),
#  ('go back', 2),
#  ('thats good', 2),
#  ('use screen', 2),
#  ('store get', 2),
#  ('get replaced', 2),
#  ('work properly', 2),
#  ('keeps freezing', 2),
#  ('phone nothing', 2),
#  ('enough justify', 2),
#  ('phone way', 2),
#  ('difficult get', 2),
#  ('double click', 2),
#  ('else get', 2),
#  ('delete button', 2),
#  ('power button', 2),
#  ('loved iphone', 2),
#  ('actually received', 2),
#  ('im trying', 2),
#  ('sure im', 2),
#  ('coming plus', 2),
#  ('phones one', 2),
#  ('good luck', 2),
#  ('issues phone', 2),
#  ('high price', 2),
#  ('new dont', 2),
#  ('dont really', 2),
#  ('less week', 2),
#  ('ordered phone', 2),
#  ('really glitchy', 2),
#  ('phone face', 2),
#  ('buttons directly', 2),
#  ('best iphone', 2),
#  ('could lot', 2),
#  ('anything freezes', 2),
#  ('x small', 2),
#  ('screen bigger', 2),
#  ('steps closing', 2),
#  ('expensive phone', 2),
#  ('isnt great', 2),
#  ('pass code', 2),
#  ('extremely difficult', 2),
#  ('phone fine', 2),
#  ('iphone im', 2),
#  ('two weeks', 2),
#  ('stop working', 2),
#  ('way overpriced', 2),
#  ('7 7', 2),
#  ('usable screen', 2),
#  ('compared iphone', 2),
#  ('better features', 2),
#  ('cant stand', 2),
#  ('love iphone', 2),
#  ('would expect', 2),
#  ('glass back', 2),
#  ('new feature', 2),
#  ('theres nothing', 2),
#  ('much different', 2),
#  ('right corner', 2),
#  ('upgrade 7', 2),
#  ('lg v30', 2),
#  ('returned got', 2),
#  ('taking screen', 2),
#  ('iphone far', 2),
#  ('phone hour', 2),
#  ('phone within', 2),
#  ('wish gone', 2),
#  ('need go', 2),
#  ('phone slow', 2),
#  ('screen full', 2),
#  ('go att', 2),
#  ('closing programs', 2),
#  ('awesome phone', 2),
#  ('button gone', 2),
#  ('quick charging', 2),
#  ('money get', 2),
#  ('trying get', 2),
#  ('x simply', 2),
#  ('upper right', 2),
#  ('time im', 2),
#  ('x im', 2),
#  ('thing good', 2),
#  ('horrible phone', 2),
#  ('infinity screen', 2),
#  ('3 stars', 2),
#  ('comfortable size', 2),
#  ('back get', 2),
#  ('feels like', 2),
#  ('youre looking', 2),
#  ('nothing wrong', 2),
#  ('money iphone', 2),
#  ('x get', 2),
#  ('phone home', 2),
#  ('phone much', 2),
#  ('sent back', 2),
#  ('6s plus', 2),
#  ('could trade', 2),
#  ('would help', 2),
#  ('without slipping', 2),
#  ('days apple', 1),
#  ('apple leader', 1),
#  ('leader becoming', 1),
#  ('becoming thin', 1),
#  ('thin next', 1),
#  ('phone may', 1),
#  ('may samsung', 1),
#  ('samsung oppo', 1),
#  ('oppo sure', 1),
#  ('sure yet', 1),
#  ('yet phone', 1),
#  ('week meh', 1),
#  ('phone met', 1),
#  ('met expectations', 1),
#  ('expectations unreliable', 1),
#  ('unreliable apple', 1),
#  ('support via', 1),
#  ('via phone', 1),
#  ('useless spent', 1),
#  ('spent hours', 1),
#  ('hours attempting', 1),
#  ('attempting fix', 1),
#  ('fix faults', 1),
#  ('faults never', 1),
#  ('never purchase', 1),
#  ('device value', 1),
#  ('money dt', 1),
#  ('dont sucker', 1),
#  ('sucker fall', 1),
#  ('fall marketing', 1),
#  ('marketing strategies', 1),
#  ('strategies reason', 1),
#  ('reason iphones', 1),
#  ('iphones known', 1),
#  ('known media', 1),
#  ('media corporate', 1),
#  ('corporate advertising', 1),
#  ('advertising batteries', 1),
#  ('batteries designed', 1),
#  ('designed last', 1),
#  ('last model', 1),
#  ('model actually', 1),
#  ('actually seem', 1),
#  ('seem worse', 1),
#  ('worse previous', 1),
#  ('x year', 1),
#  ('year clearly', 1),
#  ('clearly worst', 1),
#  ('owned screen', 1),
#  ('screen dull', 1),
#  ('dull dont', 1),
#  ('even think', 1),
#  ('think using', 1),
#  ('using direct', 1),
#  ('direct sunlight', 1),
#  ('sunlight turns', 1),
#  ('turns black', 1),
#  ('black face', 1),
#  ('recognition slow', 1),
#  ('slow clunky', 1),
#  ('clunky hardly', 1),
#  ('hardly ever', 1),
#  ('ever works', 1),
#  ('works much', 1),
#  ('happier standard', 1),
#  ('standard models', 1),
#  ('models certainly', 1),
#  ('certainly much', 1),
#  ('better value', 1),
#  ('phone excited', 1),
#  ('x 10', 1),
#  ('im wits', 1),
#  ('wits end', 1),
#  ('end itpeople', 1),
#  ('itpeople cant', 1),
#  ('hear call', 1),
#  ('call call', 1),
#  ('call themhave', 1),
#  ('themhave trying', 1),
#  ('trying deal', 1),
#  ('deal apple', 1),
#  ('apple well', 1),
#  ('well weektook', 1),
#  ('weektook 3rd', 1),
#  ('3rd party', 1),
#  ('party apple', 1),
#  ('support centre', 1),
#  ('centre find', 1),
#  ('find fault', 1),
#  ('fault take', 1),
#  ('take genius', 1),
#  ('genius barso', 1),
#  ('barso fed', 1),
#  ('really used', 1),
#  ('used love', 1),
#  ('love apple', 1),
#  ('products phone', 1),
#  ('phone came', 1),
#  ('came along', 1),
#  ('along cant', 1),
#  ('cant wait', 1),
#  ('wait paid', 1),
#  ('paid terrible', 1),
#  ('terrible clunky', 1),
#  ('clunky feeling', 1),
#  ('feeling interface', 1),
#  ('interface way', 1),
#  ('easy accidentally', 1),
#  ('accidentally take', 1),
#  ('take photos', 1),
#  ('photos home', 1),
#  ('button fancy', 1),
#  ('fancy high', 1),
#  ('tech may', 1),
#  ('may seem', 1),
#  ('seem honestly', 1),
#  ('honestly takes', 1),
#  ('takes away', 1),
#  ('away smooth', 1),
#  ('smooth operate', 1),
#  ('operate product', 1),
#  ('product probably', 1),
#  ('probably makes', 1),
#  ...]

# %%
# galaxy negative review 2-gram

master_2grams_s =[]

df_s_n = df_s[df_s['sentiment'] == 'N']

for y in range(len(df_s_n)):
    kk=re.sub('[^A-Za-z0-9 ]+', '', df_s_n['review'].iloc[y]).lower()
    jj=[i for i in word_tokenize(kk) if i not in stopwords]

    n_grams=ngrams(jj, 2)
    qq=[ ' '.join(grams) for grams in n_grams]

    master_2grams_s = master_2grams_s+qq

# %%
Counter(master_2grams_s).most_common()
# Out:
# [('battery life', 89),
#  ('s7 edge', 50),
#  ('bought phone', 39),
#  ('week ago', 38),
#  ('phone week', 38),
#  ('weeks ago', 35),
#  ('2 weeks', 27),
#  ('samsung galaxy', 27),
#  ('got phone', 27),
#  ('galaxy s9', 26),
#  ('old phone', 24),
#  ('new phone', 21),
#  ('month ago', 21),
#  ('dont like', 20),
#  ('doesnt work', 19),
#  ('2 years', 17),
#  ('3 weeks', 16),
#  ('go back', 16),
#  ('good phone', 16),
#  ('samsung s9', 15),
#  ('samsung s7', 15),
#  ('two weeks', 15),
#  ('phone last', 15),
#  ('upgraded s7', 15),
#  ('use phone', 14),
#  ('dont want', 14),
#  ('cant get', 14),
#  ('3 days', 13),
#  ('ive phone', 13),
#  ('much better', 12),
#  ('samsung phones', 12),
#  ('last day', 12),
#  ('battery doesnt', 12),
#  ('predictive text', 12),
#  ('dont work', 11),
#  ('user friendly', 11),
#  ('dont know', 11),
#  ('bixby button', 11),
#  ('bought 2', 11),
#  ('half day', 11),
#  ('phone 2', 11),
#  ('back iphone', 10),
#  ('like phone', 10),
#  ('new samsung', 10),
#  ('would recommend', 10),
#  ('camera good', 10),
#  ('much difference', 10),
#  ('phone month', 10),
#  ('doesnt last', 10),
#  ('im disappointed', 10),
#  ('using phone', 9),
#  ('phone good', 9),
#  ('going back', 9),
#  ('easy use', 9),
#  ('curved screen', 9),
#  ('couple weeks', 9),
#  ('ive ever', 9),
#  ('last week', 9),
#  ('life poor', 9),
#  ('much different', 9),
#  ('touch screen', 9),
#  ('ive week', 9),
#  ('2 days', 8),
#  ('iphone 7', 8),
#  ('pretty much', 8),
#  ('new s9', 8),
#  ('phone cant', 8),
#  ('best phone', 8),
#  ('phone dont', 8),
#  ('days ago', 8),
#  ('old s7', 8),
#  ('phone call', 8),
#  ('wish id', 8),
#  ('s8 s9', 8),
#  ('new features', 8),
#  ('really bad', 8),
#  ('new one', 8),
#  ('edge s9', 8),
#  ('phone really', 8),
#  ('previous phone', 8),
#  ('even last', 8),
#  ('phone 3', 8),
#  ('poor battery', 8),
#  ('screen protector', 7),
#  ('screen protectors', 7),
#  ('iphone 6', 7),
#  ('phone would', 7),
#  ('phone one', 7),
#  ('get used', 7),
#  ('got new', 7),
#  ('great phone', 7),
#  ('phone samsung', 7),
#  ('face recognition', 7),
#  ('phone doesnt', 7),
#  ('waste money', 7),
#  ('even though', 7),
#  ('disappointed battery', 7),
#  ('better s7', 7),
#  ('wish kept', 7),
#  ('phone ive', 7),
#  ('s7 battery', 7),
#  ('wish hadnt', 7),
#  ('phone upgrade', 7),
#  ('s8 plus', 7),
#  ('s7 s9', 7),
#  ('bought month', 7),
#  ('bought s9', 7),
#  ('phone two', 7),
#  ('s9 battery', 7),
#  ('everything else', 7),
#  ('bought week', 7),
#  ('thought would', 7),
#  ('camera quality', 6),
#  ('brand new', 6),
#  ('note 8', 6),
#  ('always samsung', 6),
#  ('cant even', 6),
#  ('home screen', 6),
#  ('old iphone', 6),
#  ('dont see', 6),
#  ('every time', 6),
#  ('slow mo', 6),
#  ('last long', 6),
#  ('difference s8', 6),
#  ('s9 3', 6),
#  ('galaxy 9', 6),
#  ('getting phone', 6),
#  ('phone gets', 6),
#  ('gets hot', 6),
#  ('phone even', 6),
#  ('year old', 6),
#  ('months ago', 6),
#  ('features phone', 6),
#  ('battery last', 6),
#  ('sent back', 6),
#  ('cant use', 6),
#  ('different s8', 6),
#  ('ago im', 6),
#  ('wish never', 6),
#  ('make phone', 6),
#  ('better camera', 6),
#  ('isnt good', 6),
#  ('got s9', 6),
#  ('old samsung', 6),
#  ('bad phone', 6),
#  ('finger print', 6),
#  ('worth money', 6),
#  ('previous s7', 6),
#  ('im stuck', 6),
#  ('back phone', 6),
#  ('week im', 6),
#  ('preferred s7', 6),
#  ('look phone', 6),
#  ('doesnt even', 6),
#  ('dont think', 6),
#  ('better battery', 5),
#  ('brought phone', 5),
#  ('edge dont', 5),
#  ('stuck s7', 5),
#  ('phone battery', 5),
#  ('decided upgrade', 5),
#  ('edge screen', 5),
#  ('great camera', 5),
#  ('seems like', 5),
#  ('ive tried', 5),
#  ('car radio', 5),
#  ('pop ups', 5),
#  ('things dont', 5),
#  ('phone 1', 5),
#  ('text messages', 5),
#  ('last samsung', 5),
#  ('stopped working', 5),
#  ('im really', 5),
#  ('phone freezes', 5),
#  ('terrible phone', 5),
#  ('slightly better', 5),
#  ('slow motion', 5),
#  ('better samsung', 5),
#  ('battery lasts', 5),
#  ('see much', 5),
#  ('cant hear', 5),
#  ('kept old', 5),
#  ('back s7', 5),
#  ('7 edge', 5),
#  ('dont use', 5),
#  ('havent able', 5),
#  ('nothing problems', 5),
#  ('less month', 5),
#  ('loved samsung', 5),
#  ('many apps', 5),
#  ('cant see', 5),
#  ('bought 3', 5),
#  ('life phone', 5),
#  ('far better', 5),
#  ('say im', 5),
#  ('3 months', 5),
#  ('picture quality', 5),
#  ('feels like', 5),
#  ('two years', 5),
#  ('samsung pay', 5),
#  ('would better', 5),
#  ('home button', 5),
#  ('1 week', 5),
#  ('old s6', 5),
#  ('good thing', 5),
#  ('phone s9', 5),
#  ('work properly', 5),
#  ('upgrade s8', 5),
#  ('phone couple', 5),
#  ('camera screen', 5),
#  ('half time', 5),
#  ('great battery', 5),
#  ('phone screen', 5),
#  ('last 2', 4),
#  ('power saving', 4),
#  ('work phone', 4),
#  ('life terrible', 4),
#  ('days phone', 4),
#  ('phone get', 4),
#  ('screen goes', 4),
#  ('using iphone', 4),
#  ('screen sometimes', 4),
#  ('phone want', 4),
#  ('im used', 4),
#  ('phone great', 4),
#  ('cant change', 4),
#  ('note 4', 4),
#  ('nothing special', 4),
#  ('waste time', 4),
#  ('iphone samsung', 4),
#  ('phone seems', 4),
#  ('camera great', 4),
#  ('bixby feature', 4),
#  ('software update', 4),
#  ('galaxy s5', 4),
#  ('wifi calling', 4),
#  ('unlock phone', 4),
#  ('screen size', 4),
#  ('galaxy s7', 4),
#  ('s7 much', 4),
#  ('get work', 4),
#  ('took back', 4),
#  ('cant wait', 4),
#  ('even use', 4),
#  ('phone 4', 4),
#  ('next phone', 4),
#  ('still getting', 4),
#  ('getting used', 4),
#  ('galaxy s6', 4),
#  ('make calls', 4),
#  ('features great', 4),
#  ('fingerprint scanner', 4),
#  ('got last', 4),
#  ('10 days', 4),
#  ('notification tone', 4),
#  ('upgrade samsung', 4),
#  ('never got', 4),
#  ('get phone', 4),
#  ('im still', 4),
#  ('bought samsung', 4),
#  ('ago already', 4),
#  ('years never', 4),
#  ('kept s7', 4),
#  ('takes ages', 4),
#  ('used samsung', 4),
#  ('taking back', 4),
#  ('samsung phone', 4),
#  ('really disappointed', 4),
#  ('screen cracked', 4),
#  ('sound quality', 4),
#  ('s9 really', 4),
#  ('purchased phone', 4),
#  ('ago disappointed', 4),
#  ('must say', 4),
#  ('many years', 4),
#  ('samsung fan', 4),
#  ('samsung android', 4),
#  ('battery drains', 4),
#  ('upgraded s9', 4),
#  ('difference s7', 4),
#  ('thought id', 4),
#  ('dont find', 4),
#  ('would thought', 4),
#  ('good battery', 4),
#  ('phone nothing', 4),
#  ('google assistant', 4),
#  ('phone less', 4),
#  ('prefer old', 4),
#  ('took phone', 4),
#  ('one day', 4),
#  ('front camera', 4),
#  ('dont really', 4),
#  ('great features', 4),
#  ('upgrade s7', 4),
#  ('phone wont', 4),
#  ('seem get', 4),
#  ('galaxy 6', 4),
#  ('s9 nice', 4),
#  ('difficult use', 4),
#  ('isnt great', 4),
#  ('first time', 4),
#  ('never problem', 4),
#  ('bixby app', 4),
#  ('phone ok', 4),
#  ('cracked screen', 4),
#  ('wish stuck', 4),
#  ('new update', 4),
#  ('rubbish battery', 4),
#  ('like s8', 4),
#  ('much easier', 4),
#  ('im impressed', 4),
#  ('apps dont', 4),
#  ('phone everything', 4),
#  ('one thing', 4),
#  ('keeps freezing', 4),
#  ('text tones', 4),
#  ('phone weeks', 4),
#  ('bluetooth devices', 4),
#  ('recommend anyone', 4),
#  ('edge far', 4),
#  ('ago wish', 4),
#  ('1 month', 3),
#  ('told phone', 3),
#  ('two days', 3),
#  ('phone always', 3),
#  ('customer service', 3),
#  ('case screen', 3),
#  ('work well', 3),
#  ('hate bixby', 3),
#  ('want use', 3),
#  ('4 months', 3),
#  ('get back', 3),
#  ('iphone user', 3),
#  ('find hard', 3),
#  ('buy phone', 3),
#  ('phone far', 3),
#  ('phone iphone', 3),
#  ('operating system', 3),
#  ('battery sucks', 3),
#  ('s9 im', 3),
#  ('phone day', 3),
#  ('s9 big', 3),
#  ('rest phone', 3),
#  ('3 hours', 3),
#  ('wont work', 3),
#  ('stay connected', 3),
#  ('buy another', 3),
#  ('another samsung', 3),
#  ('looks good', 3),
#  ('much phone', 3),
#  ('ring tones', 3),
#  ('notification sounds', 3),
#  ('3rd party', 3),
#  ('camera battery', 3),
#  ('good nothing', 3),
#  ('would kept', 3),
#  ('next time', 3),
#  ('tap tap', 3),
#  ('im extremely', 3),
#  ('3 years', 3),
#  ('sim card', 3),
#  ('impressed phone', 3),
#  ('unlocked version', 3),
#  ('never broke', 3),
#  ('14 days', 3),
#  ('due fact', 3),
#  ('recently upgraded', 3),
#  ('easier use', 3),
#  ('screen phone', 3),
#  ('battery would', 3),
#  ('never samsung', 3),
#  ('facial recognition', 3),
#  ('compared iphone', 3),
#  ('phone case', 3),
#  ('take back', 3),
#  ('phone nice', 3),
#  ('back camera', 3),
#  ('expensive phone', 3),
#  ('phone ever', 3),
#  ('software way', 3),
#  ('hold charge', 3),
#  ('dont even', 3),
#  ('hate phone', 3),
#  ('side phone', 3),
#  ('phone alot', 3),
#  ('sometimes doesnt', 3),
#  ('still sucks', 3),
#  ('would expect', 3),
#  ('bought couple', 3),
#  ('phone running', 3),
#  ('2 year', 3),
#  ('loved s7', 3),
#  ('phone keeps', 3),
#  ('samsung would', 3),
#  ('phone calls', 3),
#  ('ago good', 3),
#  ('keep restarting', 3),
#  ('used phone', 3),
#  ('charging port', 3),
#  ('much faster', 3),
#  ('one week', 3),
#  ('use camera', 3),
#  ('really good', 3),
#  ('screen shot', 3),
#  ('good features', 3),
#  ('buy samsung', 3),
#  ('keep phone', 3),
#  ('low light', 3),
#  ('4 weeks', 3),
#  ('camera ok', 3),
#  ('went back', 3),
#  ('back old', 3),
#  ('decided change', 3),
#  ('samsung s8', 3),
#  ('edge much', 3),
#  ('different phone', 3),
#  ('samsung apps', 3),
#  ('takes forever', 3),
#  ('s9 last', 3),
#  ('may well', 3),
#  ('kept s8', 3),
#  ('bought less', 3),
#  ('s7 2', 3),
#  ('phone wish', 3),
#  ('doesnt understand', 3),
#  ('could get', 3),
#  ('even im', 3),
#  ('windows phone', 3),
#  ('phone im', 3),
#  ('im sure', 3),
#  ('phone wouldnt', 3),
#  ('put phone', 3),
#  ('upgraded iphone', 3),
#  ('lot better', 3),
#  ('really slow', 3),
#  ('numerous times', 3),
#  ('s9 got', 3),
#  ('speaker phone', 3),
#  ('screen means', 3),
#  ('half screen', 3),
#  ('get rid', 3),
#  ('phones ive', 3),
#  ('last time', 3),
#  ('phone much', 3),
#  ('isnt much', 3),
#  ('wish bought', 3),
#  ('galaxy edge', 3),
#  ('s7 ive', 3),
#  ('last whole', 3),
#  ('whole day', 3),
#  ('life really', 3),
#  ('sending back', 3),
#  ('quality amazing', 3),
#  ('ago battery', 3),
#  ('6 hours', 3),
#  ('couple months', 3),
#  ('iphone 6s', 3),
#  ('take photos', 3),
#  ('im charge', 3),
#  ('iphone x', 3),
#  ('s9 ive', 3),
#  ('ive s9', 3),
#  ('weeks still', 3),
#  ('prefer s7', 3),
#  ('force stop', 3),
#  ('several times', 3),
#  ('bixby annoying', 3),
#  ('note 3', 3),
#  ('feel like', 3),
#  ('life bad', 3),
#  ('love samsung', 3),
#  ('years old', 3),
#  ('life shocking', 3),
#  ('weeks nothing', 3),
#  ('really wanted', 3),
#  ('life im', 3),
#  ('hadnt upgraded', 3),
#  ('gone back', 3),
#  ('upgraded s8', 3),
#  ('s9 plus', 3),
#  ('save money', 3),
#  ('goes black', 3),
#  ('power button', 3),
#  ('impressed camera', 3),
#  ('s9 week', 3),
#  ('still best', 3),
#  ('back button', 3),
#  ('battery better', 3),
#  ('phone galaxy', 3),
#  ('s9 would', 3),
#  ('hadnt bothered', 3),
#  ('back shop', 3),
#  ('screen doesnt', 3),
#  ('switch iphone', 3),
#  ('ive got', 3),
#  ('playing music', 3),
#  ('ring tone', 3),
#  ('message tones', 3),
#  ('phone around', 3),
#  ('phone pocket', 3),
#  ('play store', 3),
#  ('curved glass', 3),
#  ('samsung 9', 3),
#  ('cant seem', 3),
#  ('week still', 3),
#  ('still trying', 3),
#  ('ive upgraded', 3),
#  ('like ive', 3),
#  ('back home', 3),
#  ('review collected', 3),
#  ('collected part', 3),
#  ('part promotion', 3),
#  ('swapped phone', 3),
#  ('loud speaker', 3),
#  ('really poor', 3),
#  ('keyboard doesnt', 3),
#  ('use samsung', 3),
#  ('different old', 3),
#  ('week battery', 3),
#  ('phone s7', 3),
#  ('dedicated button', 3),
#  ('volume button', 3),
#  ('bixby dont', 3),
#  ('dont need', 3),
#  ('samsung account', 3),
#  ('get samsung', 3),
#  ('new sim', 3),
#  ('edge phone', 3),
#  ('think would', 3),
#  ('wish gone', 3),
#  ('nothing new', 3),
#  ('phone looks', 3),
#  ('make call', 3),
#  ('messages app', 3),
#  ('ive never', 3),
#  ('months old', 3),
#  ('battery really', 3),
#  ('saving mode', 3),
#  ('upgraded s6', 3),
#  ('s6 s9', 3),
#  ('got week', 3),
#  ('love s9', 3),
#  ('s6 edge', 3),
#  ('good either', 3),
#  ('4 days', 3),
#  ('fan edge', 3),
#  ('even half', 3),
#  ('ago still', 3),
#  ('last half', 3),
#  ('im using', 3),
#  ('bixby voice', 3),
#  ('back screen', 3),
#  ('first samsung', 3),
#  ('still cant', 3),
#  ('also battery', 3),
#  ('s9 seems', 3),
#  ('phone overheats', 3),
#  ('impressed battery', 3),
#  ('worst phone', 3),
#  ('couldnt get', 3),
#  ('gave 3', 3),
#  ('keeps turning', 3),
#  ('issue s9', 3),
#  ('edge battery', 3),
#  ('phone first', 3),
#  ('connect bluetooth', 3),
#  ('thought phone', 3),
#  ('charge phone', 3),
#  ('known would', 3),
#  ('auto correct', 3),
#  ('call without', 3),
#  ('another one', 3),
#  ('like s9', 3),
#  ('google assist', 3),
#  ('voice recognition', 3),
#  ('last friday', 3),
#  ('thing super', 3),
#  ('several apps', 3),
#  ('android iphone', 3),
#  ('s9 s9', 3),
#  ('month battery', 2),
#  ('edge better', 2),
#  ('use day', 2),
#  ('last least', 2),
#  ('open apps', 2),
#  ('wish stayed', 2),
#  ('cheap phone', 2),
#  ('phone wonder', 2),
#  ('phone iphones', 2),
#  ('pressing things', 2),
#  ('phone way', 2),
#  ('loved phone', 2),
#  ('find another', 2),
#  ('weeks old', 2),
#  ('phone sadly', 2),
#  ('repair shop', 2),
#  ('protectors dont', 2),
#  ('curved edges', 2),
#  ('cracked s9', 2),
#  ('years battery', 2),
#  ('dont help', 2),
#  ('2 months', 2),
#  ('months screen', 2),
#  ('bixby want', 2),
#  ('annoying also', 2),
#  ('make work', 2),
#  ('turn thing', 2),
#  ('thing get', 2),
#  ('much everything', 2),
#  ('s9 keyboard', 2),
#  ('thing ever', 2),
#  ('ever done', 2),
#  ('phone definitely', 2),
#  ('iphone soon', 2),
#  ('1 year', 2),
#  ('year samsung', 2),
#  ('go samsung', 2),
#  ('quality good', 2),
#  ('apps like', 2),
#  ('tv remote', 2),
#  ('hate hate', 2),
#  ('previous samsungs', 2),
#  ('day everyday', 2),
#  ('s8 decided', 2),
#  ('upgrade s9', 2),
#  ('hours later', 2),
#  ('really regret', 2),
#  ('glass get', 2),
#  ('smart switch', 2),
#  ('going buy', 2),
#  ('samsung product', 2),
#  ('phones good', 2),
#  ('much samsung', 2),
#  ('cant customize', 2),
#  ('next model', 2),
#  ('one runs', 2),
#  ('dialogue box', 2),
#  ('4 stars', 2),
#  ('party app', 2),
#  ('would probably', 2),
#  ('hold onto', 2),
#  ('many times', 2),
#  ('side button', 2),
#  ('phone fast', 2),
#  ('less 2', 2),
#  ('apps phone', 2),
#  ('phone games', 2),
#  ('back store', 2),
#  ('camera takes', 2),
#  ('galaxy 7', 2),
#  ('im trying', 2),
#  ('extremely unhappy', 2),
#  ('plus poor', 2),
#  ('poor quality', 2),
#  ('switched iphone', 2),
#  ('button bixby', 2),
#  ('always accidentally', 2),
#  ('accidentally touched', 2),
#  ('social media', 2),
#  ('extremely annoying', 2),
#  ('also seems', 2),
#  ('seems problem', 2),
#  ('switch back', 2),
#  ('purchased samsung', 2),
#  ('s9 2', 2),
#  ('left hand', 2),
#  ('side also', 2),
#  ('without putting', 2),
#  ('chadstone store', 2),
#  ('data first', 2),
#  ('smart phone', 2),
#  ('intuitive use', 2),
#  ('would know', 2),
#  ('s9 couple', 2),
#  ('couple days', 2),
#  ('previous samsung', 2),
#  ('seek professional', 2),
#  ('also found', 2),
#  ('want app', 2),
#  ('time go', 2),
#  ('go use', 2),
#  ('service provider', 2),
#  ('apple samsung', 2),
#  ('get pop', 2),
#  ('pop adverts', 2),
#  ('dont get', 2),
#  ('s9 pretty', 2),
#  ('super slow', 2),
#  ('really annoying', 2),
#  ('dont bother', 2),
#  ('phone lack', 2),
#  ('deal breaker', 2),
#  ('overall phone', 2),
#  ('features att', 2),
#  ('push talk', 2),
#  ('att phone', 2),
#  ('tech support', 2),
#  ('went store', 2),
#  ('unlocked phones', 2),
#  ('s9 bought', 2),
#  ('features would', 2),
#  ('would work', 2),
#  ('seems last', 2),
#  ('2 samsung', 2),
#  ('normal wear', 2),
#  ('paid full', 2),
#  ('full price', 2),
#  ('couldnt unlock', 2),
#  ('highly recommend', 2),
#  ('google pixel', 2),
#  ('bought unlocked', 2),
#  ('model like', 2),
#  ('features previous', 2),
#  ('phones never', 2),
#  ('broke screen', 2),
#  ('doesnt give', 2),
#  ('phone opinion', 2),
#  ('upgraded samsung', 2),
#  ('better product', 2),
#  ('back samsung', 2),
#  ('samsung 5', 2),
#  ('like apple', 2),
#  ('dont waste', 2),
#  ('many things', 2),
#  ('features performance', 2),
#  ('super fast', 2),
#  ('hard type', 2),
#  ('thing phone', 2),
#  ('work without', 2),
#  ('s9 get', 2),
#  ('chat history', 2),
#  ('android good', 2),
#  ('s9 samsung', 2),
#  ('camera slightly', 2),
#  ('nice back', 2),
#  ('camera easy', 2),
#  ('easy crack', 2),
#  ('crack careful', 2),
#  ('careful refunded', 2),
#  ('refunded covered', 2),
#  ('covered insurance', 2),
#  ('working far', 2),
#  ('phone worth', 2),
#  ('worth price', 2),
#  ('iphone s9', 2),
#  ('s9 difference', 2),
#  ('supposed good', 2),
#  ('new galaxy', 2),
#  ('phone better', 2),
#  ('dropping phone', 2),
#  ('way better', 2),
#  ('scratches really', 2),
#  ('iphone phone', 2),
#  ('hold phone', 2),
#  ('phone hand', 2),
#  ('phone make', 2),
#  ('make sure', 2),
#  ('get 2', 2),
#  ('phone horrible', 2),
#  ('screen pictures', 2),
#  ('s8 screen', 2),
#  ('work camera', 2),
#  ('s7 lasted', 2),
#  ('ago honest', 2),
#  ('hours even', 2),
#  ('send mms', 2),
#  ('battery phone', 2),
#  ('difference old', 2),
#  ('iphone years', 2),
#  ('years without', 2),
#  ('think next', 2),
#  ('one hear', 2),
#  ('hear cant', 2),
#  ('ago took', 2),
#  ('photos disappeared', 2),
#  ('almost immediately', 2),
#  ('good thought', 2),
#  ('years even', 2),
#  ('inches screen', 2),
#  ('like plastic', 2),
#  ('screen glass', 2),
#  ('fingers also', 2),
#  ('also screen', 2),
#  ('bought two', 2),
#  ('eg whats', 2),
#  ('hand corner', 2),
#  ('expected price', 2),
#  ('s6 much', 2),
#  ('week use', 2),
#  ('good design', 2),
#  ('s7 wish', 2),
#  ('s7 screen', 2),
#  ('take screen', 2),
#  ('put speaker', 2),
#  ('use headphones', 2),
#  ('many features', 2),
#  ('looking forward', 2),
#  ('software upgrade', 2),
#  ('many good', 2),
#  ('features wish', 2),
#  ('slightly disappointed', 2),
#  ('better also', 2),
#  ('pictures really', 2),
#  ('everyone around', 2),
#  ('day day', 2),
#  ('scanner front', 2),
#  ('put back', 2),
#  ('unread message', 2),
#  ('best use', 2),
#  ('fingerprint unlock', 2),
#  ('apple iphone', 2),
#  ('lost messages', 2),
#  ('fiddly use', 2),
#  ('need fix', 2),
#  ('s8 much', 2),
#  ('screen responsive', 2),
#  ('use make', 2),
#  ('nothing different', 2),
#  ('phone s8', 2),
#  ('get another', 2),
#  ('got couple', 2),
#  ('get better', 2),
#  ('many samsung', 2),
#  ('apps miss', 2),
#  ('work needs', 2),
#  ('could wait', 2),
#  ('wait get', 2),
#  ('sony phone', 2),
#  ('better new', 2),
#  ('using weeks', 2),
#  ('fully charged', 2),
#  ('good signal', 2),
#  ('last year', 2),
#  ('ever since', 2),
#  ('always loved', 2),
#  ('phone months', 2),
#  ('trying sell', 2),
#  ('camera phone', 2),
#  ('moved iphone', 2),
#  ('charge im', 2),
#  ('phone lost', 2),
#  ('phone apps', 2),
#  ('good good', 2),
#  ('signal could', 2),
#  ('people speak', 2),
#  ('keep cutting', 2),
#  ('ads popping', 2),
#  ('wont get', 2),
#  ('dont go', 2),
#  ('time keep', 2),
#  ('used new', 2),
#  ('driving mad', 2),
#  ('1gb data', 2),
#  ('samsung ive', 2),
#  ('wasnt expecting', 2),
#  ('used moment', 2),
#  ('im regretting', 2),
#  ('see difference', 2),
#  ('wouldnt recommend', 2),
#  ('hear well', 2),
#  ('keep coming', 2),
#  ('even phone', 2),
#  ('problem iphone', 2),
#  ('huawei p20', 2),
#  ('s7 expecting', 2),
#  ('connecting internet', 2),
#  ('still get', 2),
#  ('s9 s7', 2),
#  ('couldnt make', 2),
#  ('calls 1st', 2),
#  ('second one', 2),
#  ('issue im', 2),
#  ('ar emoji', 2),
#  ('cant add', 2),
#  ('life better', 2),
#  ('samsung j6', 2),
#  ('screen stopped', 2),
#  ('also annoying', 2),
#  ('annoying bixby', 2),
#  ('screen resolution', 2),
#  ('camera amazing', 2),
#  ('third party', 2),
#  ('camera sound', 2),
#  ('s7 last', 2),
#  ('contacts could', 2),
#  ('basically phone', 2),
#  ('much old', 2),
#  ('phone useless', 2),
#  ('looked online', 2),
#  ('back cant', 2),
#  ('cant take', 2),
#  ('screen shots', 2),
#  ('apps many', 2),
#  ('really isnt', 2),
#  ('ago s7', 2),
#  ('years really', 2),
#  ('get signal', 2),
#  ('like galaxy', 2),
#  ('dropped phone', 2),
#  ('looks like', 2),
#  ('less week', 2),
#  ('phone least', 2),
#  ('protective screen', 2),
#  ('ago problems', 2),
#  ('bitterly disappointed', 2),
#  ('honestly say', 2),
#  ('miss s7', 2),
#  ('s7 want', 2),
#  ('buttons side', 2),
#  ('phone like', 2),
#  ('quality poor', 2),
#  ('like s7', 2),
#  ('played settings', 2),
#  ('ill keep', 2),
#  ('got say', 2),
#  ('love phone', 2),
#  ('slow unresponsive', 2),
#  ('quality phone', 2),
#  ('phone clunky', 2),
#  ('use extensively', 2),
#  ('phone feel', 2),
#  ('front facing', 2),
#  ('facing camera', 2),
#  ('sad say', 2),
#  ('real shame', 2),
#  ('recommend samsung', 2),
#  ('samsung please', 2),
#  ('weeks back', 2),
#  ('poor phone', 2),
#  ('dead spots', 2),
#  ('spots screen', 2),
#  ('step backwards', 2),
#  ('taking phone', 2),
#  ('improved battery', 2),
#  ('improved camera', 2),
#  ('charge s9', 2),
#  ('s9 daily', 2),
#  ('im thinking', 2),
#  ('ive noticed', 2),
#  ('still good', 2),
#  ('screen idea', 2),
#  ('still prefer', 2),
#  ('battery runs', 2),
#  ('runs quickly', 2),
#  ('apps running', 2),
#  ('running background', 2),
#  ('unless go', 2),
#  ('6 days', 2),
#  ('keen fingerprint', 2),
#  ('awkward use', 2),
#  ('use may', 2),
#  ('used time', 2),
#  ('able access', 2),
#  ('features make', 2),
#  ('easy access', 2),
#  ('home page', 2),
#  ('huge fan', 2),
#  ('fan samsung', 2),
#  ('best samsung', 2),
#  ('simple use', 2),
#  ('app home', 2),
#  ('times day', 2),
#  ('id go', 2),
#  ('poor doesnt', 2),
#  ('also bixby', 2),
#  ('really see', 2),
#  ('feel phone', 2),
#  ('ive samsung', 2),
#  ('15 years', 2),
#  ('would say', 2),
#  ('say preferred', 2),
#  ('screen get', 2),
#  ('phone contacts', 2),
#  ('bought iphone', 2),
#  ('white screen', 2),
#  ('wanted change', 2),
#  ('s9 cant', 2),
#  ('ive done', 2),
#  ('got less', 2),
#  ('two phones', 2),
#  ('smaller s7', 2),
#  ('biggest gripe', 2),
#  ('edge 7', 2),
#  ('check phone', 2),
#  ('phone constantly', 2),
#  ('worst battery', 2),
#  ('lucky get', 2),
#  ('12 hours', 2),
#  ('moderate use', 2),
#  ('around two', 2),
#  ('moved samsung', 2),
#  ('would ok', 2),
#  ('google pay', 2),
#  ('im keen', 2),
#  ('life good', 2),
#  ('standard phone', 2),
#  ('hands free', 2),
#  ('find anything', 2),
#  ('ive loved', 2),
#  ('samsung wish', 2),
#  ...]

# %%
# iphone negative review 3-gram

master_3grams_a =[]

df_a_n = df_a[df_a['sentiment'] == 'N']

for y in range(len(df_a_n)):
    kk=re.sub('[^A-Za-z0-9 ]+', '', df_a_n['review'].iloc[y]).lower()
    jj=[i for i in word_tokenize(kk) if i not in stopwords]

    n_grams=ngrams(jj, 3)
    qq=[ ' '.join(grams) for grams in n_grams]

    master_3grams_a = master_3grams_a + qq

# %%
Counter(master_3grams_a).most_common()
# Out:
# [('iphone 7 plus', 11),
#  ('bought iphone x', 5),
#  ('iphone 6 plus', 5),
#  ('dont think worth', 5),
#  ('phone 2 weeks', 4),
#  ('lack home button', 4),
#  ('dont get wrong', 4),
#  ('iphone 8 plus', 4),
#  ('phone user friendly', 4),
#  ('like iphone x', 4),
#  ('got brand new', 3),
#  ('much much better', 3),
#  ('top bottom screen', 3),
#  ('like face id', 3),
#  ('face id doesnt', 3),
#  ('id doesnt work', 3),
#  ('missing home button', 3),
#  ('get iphone x', 2),
#  ('love portrait mode', 2),
#  ('sound quality phone', 2),
#  ('iphone 8 much', 2),
#  ('much better phone', 2),
#  ('phone keeps crashing', 2),
#  ('ive 4 months', 2),
#  ('got iphone 8', 2),
#  ('apple iphone x', 2),
#  ('phone water resistant', 2),
#  ('ive ever owned', 2),
#  ('camera quality good', 2),
#  ('phone works great', 2),
#  ('bought iphone 8', 2),
#  ('think worth price', 2),
#  ('face id cant', 2),
#  ('worst phone ever', 2),
#  ('hard reset phone', 2),
#  ('screen becomes unresponsive', 2),
#  ('compared previous iphone', 2),
#  ('compared older models', 2),
#  ('purchased iphone x', 2),
#  ('iphone x apple', 2),
#  ('apple fan since', 2),
#  ('since iphone 3', 2),
#  ('iphone 6 would', 2),
#  ('get galaxy s8', 2),
#  ('iphone x worst', 2),
#  ('x worst phone', 2),
#  ('iphone 6s really', 2),
#  ('phone half price', 2),
#  ('cant even set', 2),
#  ('really worth price', 2),
#  ('last whole day', 2),
#  ('doesnt work well', 2),
#  ('screen smaller phone', 2),
#  ('home button frustrating', 2),
#  ('miss home button', 2),
#  ('spend extra money', 2),
#  ('iphone 7 8', 2),
#  ('get wrong phone', 2),
#  ('without screen protector', 2),
#  ('finger print reader', 2),
#  ('iphone x worth', 2),
#  ('iphone 7 battery', 2),
#  ('old iphone 7', 2),
#  ('iphone user since', 2),
#  ('without home button', 2),
#  ('removal home button', 2),
#  ('glass front back', 2),
#  ('battery life good', 2),
#  ('facial recognition works', 2),
#  ('takes longer get', 2),
#  ('overpriced especially considering', 2),
#  ('phone worth money', 2),
#  ('getting iphone 8', 2),
#  ('home button annoying', 2),
#  ('iphone x user', 2),
#  ('returning phone getting', 2),
#  ('doesnt headphone jack', 2),
#  ('would recommend phone', 2),
#  ('got iphone x', 2),
#  ('upgraded iphone 7plus', 2),
#  ('doesnt home button', 2),
#  ('like every iphone', 2),
#  ('brand new phone', 2),
#  ('give refurbished phone', 2),
#  ('size screen screen', 2),
#  ('wish would kept', 2),
#  ('kept iphone 6', 2),
#  ('dont like took', 2),
#  ('im disappointed phone', 2),
#  ('worth extra money', 2),
#  ('use switching apps', 2),
#  ('buy 8 plus', 2),
#  ('8 plus phone', 2),
#  ('10 times day', 2),
#  ('phone terrible horrible', 2),
#  ('terrible horrible clunky', 2),
#  ('horrible clunky high', 2),
#  ('clunky high tech', 2),
#  ('high tech worth', 2),
#  ('tech worth month', 2),
#  ('worth month picking', 2),
#  ('month picking s10', 2),
#  ('picking s10 stop', 2),
#  ('s10 stop pain', 2),
#  ('stop pain android', 2),
#  ('pain android apple', 2),
#  ('android apple definitely', 2),
#  ('apple definitely android', 2),
#  ('dont buy screen', 2),
#  ('buy screen goes', 2),
#  ('screen goes fritz', 2),
#  ('goes fritz drops', 2),
#  ('fritz drops email', 2),
#  ('drops email accounts', 2),
#  ('email accounts randomly', 2),
#  ('accounts randomly microphone', 2),
#  ('randomly microphone doesnt', 2),
#  ('microphone doesnt work', 2),
#  ('doesnt work im', 2),
#  ('work im 3rd', 2),
#  ('im 3rd replacement', 2),
#  ('3rd replacement since', 2),
#  ('replacement since september', 2),
#  ('since september extremely', 2),
#  ('september extremely unhappy', 2),
#  ('extremely unhappy verizon', 2),
#  ('unhappy verizon support', 2),
#  ('verizon support customer', 2),
#  ('support customer 20years', 2),
#  ('customer 20years horrible', 2),
#  ('also facial recognition', 2),
#  ('doesnt work dark', 2),
#  ('really excited get', 2),
#  ('ive iphone x', 2),
#  ('ive iphones since', 2),
#  ('leaves lot desired', 2),
#  ('face id animojis', 2),
#  ('iphone 8 iphone', 2),
#  ('8 iphone x', 2),
#  ('plus sized iphone', 2),
#  ('sized iphone x', 2),
#  ('iphone x next', 2),
#  ('hits top bottom', 2),
#  ('app app app', 2),
#  ('experience iphone x', 2),
#  ('days upgrading iphone', 2),
#  ('upgrading iphone 6', 2),
#  ('never heard anyone', 2),
#  ('could lot better', 2),
#  ('extra steps closing', 2),
#  ('compared iphone 7', 2),
#  ('wish gone 8', 2),
#  ('gone 8 plus', 2),
#  ('home button gone', 2),
#  ('quick charging cable', 2),
#  ('save money get', 2),
#  ('way much money', 2),
#  ('nothing wrong phone', 2),
#  ('iphone x get', 2),
#  ('phone home button', 2),
#  ('days apple leader', 1),
#  ('apple leader becoming', 1),
#  ('leader becoming thin', 1),
#  ('becoming thin next', 1),
#  ('thin next phone', 1),
#  ('next phone may', 1),
#  ('phone may samsung', 1),
#  ('may samsung oppo', 1),
#  ('samsung oppo sure', 1),
#  ('oppo sure yet', 1),
#  ('sure yet phone', 1),
#  ('yet phone week', 1),
#  ('phone week meh', 1),
#  ('phone met expectations', 1),
#  ('met expectations unreliable', 1),
#  ('expectations unreliable apple', 1),
#  ('unreliable apple support', 1),
#  ('apple support via', 1),
#  ('support via phone', 1),
#  ('via phone useless', 1),
#  ('phone useless spent', 1),
#  ('useless spent hours', 1),
#  ('spent hours attempting', 1),
#  ('hours attempting fix', 1),
#  ('attempting fix faults', 1),
#  ('fix faults never', 1),
#  ('faults never purchase', 1),
#  ('never purchase another', 1),
#  ('purchase another apple', 1),
#  ('another apple device', 1),
#  ('apple device value', 1),
#  ('device value money', 1),
#  ('value money dt', 1),
#  ('dont sucker fall', 1),
#  ('sucker fall marketing', 1),
#  ('fall marketing strategies', 1),
#  ('marketing strategies reason', 1),
#  ('strategies reason iphones', 1),
#  ('reason iphones known', 1),
#  ('iphones known media', 1),
#  ('known media corporate', 1),
#  ('media corporate advertising', 1),
#  ('corporate advertising batteries', 1),
#  ('advertising batteries designed', 1),
#  ('batteries designed last', 1),
#  ('designed last model', 1),
#  ('last model actually', 1),
#  ('model actually seem', 1),
#  ('actually seem worse', 1),
#  ('seem worse previous', 1),
#  ('worse previous versions', 1),
#  ('previous versions iphone', 1),
#  ('iphone x year', 1),
#  ('x year clearly', 1),
#  ('year clearly worst', 1),
#  ('clearly worst iphone', 1),
#  ('worst iphone ever', 1),
#  ('iphone ever owned', 1),
#  ('ever owned screen', 1),
#  ('owned screen dull', 1),
#  ('screen dull dont', 1),
#  ('dull dont even', 1),
#  ('dont even think', 1),
#  ('even think using', 1),
#  ('think using direct', 1),
#  ('using direct sunlight', 1),
#  ('direct sunlight turns', 1),
#  ('sunlight turns black', 1),
#  ('turns black face', 1),
#  ('black face recognition', 1),
#  ('face recognition slow', 1),
#  ('recognition slow clunky', 1),
#  ('slow clunky hardly', 1),
#  ('clunky hardly ever', 1),
#  ('hardly ever works', 1),
#  ('ever works much', 1),
#  ('works much happier', 1),
#  ('much happier standard', 1),
#  ('happier standard models', 1),
#  ('standard models certainly', 1),
#  ('models certainly much', 1),
#  ('certainly much better', 1),
#  ('much better value', 1),
#  ('better value money', 1),
#  ('ive always apple', 1),
#  ('always apple phone', 1),
#  ('apple phone excited', 1),
#  ('phone excited get', 1),
#  ('excited get iphone', 1),
#  ('iphone x 10', 1),
#  ('x 10 months', 1),
#  ('10 months im', 1),
#  ('months im wits', 1),
#  ('im wits end', 1),
#  ('wits end itpeople', 1),
#  ('end itpeople cant', 1),
#  ('itpeople cant hear', 1),
#  ('cant hear call', 1),
#  ('hear call call', 1),
#  ('call call themhave', 1),
#  ('call themhave trying', 1),
#  ('themhave trying deal', 1),
#  ('trying deal apple', 1),
#  ('deal apple well', 1),
#  ('apple well weektook', 1),
#  ('well weektook 3rd', 1),
#  ('weektook 3rd party', 1),
#  ('3rd party apple', 1),
#  ('party apple support', 1),
#  ('apple support centre', 1),
#  ('support centre find', 1),
#  ('centre find fault', 1),
#  ('find fault take', 1),
#  ('fault take genius', 1),
#  ('take genius barso', 1),
#  ('genius barso fed', 1),
#  ('really used love', 1),
#  ('used love apple', 1),
#  ('love apple products', 1),
#  ('apple products phone', 1),
#  ('products phone came', 1),
#  ('phone came along', 1),
#  ('came along cant', 1),
#  ('along cant wait', 1),
#  ('cant wait paid', 1),
#  ('wait paid terrible', 1),
#  ('paid terrible clunky', 1),
#  ('terrible clunky feeling', 1),
#  ('clunky feeling interface', 1),
#  ('feeling interface way', 1),
#  ('interface way easy', 1),
#  ('way easy accidentally', 1),
#  ('easy accidentally take', 1),
#  ('accidentally take photos', 1),
#  ('take photos home', 1),
#  ('photos home button', 1),
#  ('home button fancy', 1),
#  ('button fancy high', 1),
#  ('fancy high tech', 1),
#  ('high tech may', 1),
#  ('tech may seem', 1),
#  ('may seem honestly', 1),
#  ('seem honestly takes', 1),
#  ('honestly takes away', 1),
#  ('takes away smooth', 1),
#  ('away smooth operate', 1),
#  ('smooth operate product', 1),
#  ('operate product probably', 1),
#  ('product probably makes', 1),
#  ('probably makes software', 1),
#  ('makes software work', 1),
#  ('software work harder', 1),
#  ('work harder helping', 1),
#  ('harder helping sluggish', 1),
#  ('helping sluggish get', 1),
#  ('sluggish get tech', 1),
#  ('get tech needs', 1),
#  ('tech needs practical', 1),
#  ('needs practical thats', 1),
#  ('practical thats phone', 1),
#  ('great camera good', 1),
#  ('camera good communicator', 1),
#  ('good communicator emails', 1),
#  ('communicator emails sms', 1),
#  ('emails sms whatsapp', 1),
#  ('sms whatsapp etc', 1),
#  ('whatsapp etc apps', 1),
#  ('etc apps work', 1),
#  ('apps work well', 1),
#  ('work well phone', 1),
#  ('well phone failure', 1),
#  ('phone failure people', 1),
#  ('failure people constantly', 1),
#  ('people constantly complaining', 1),
#  ('constantly complaining cant', 1),
#  ('complaining cant hear', 1),
#  ('cant hear whether', 1),
#  ('hear whether using', 1),
#  ('whether using bluetooth', 1),
#  ('using bluetooth earphones', 1),
#  ('bluetooth earphones wired', 1),
#  ('earphones wired earphones', 1),
#  ('wired earphones phone', 1),
#  ('earphones phone friends', 1),
#  ('phone friends problem', 1),
#  ('friends problem great', 1),
#  ('problem great personal', 1),
#  ('great personal device', 1),
#  ('personal device failure', 1),
#  ('device failure basic', 1),
#  ('failure basic phone', 1),
#  ('2 types iphone', 1),
#  ('types iphone x', 1),
#  ('iphone x uses', 1),
#  ('x uses dropped', 1),
#  ('uses dropped phone', 1),
#  ('dropped phone lightened', 1),
#  ('phone lightened wallet', 1),
#  ('lightened wallet soon', 1),
#  ('wallet soon willit', 1),
#  ('soon willit took', 1),
#  ('willit took apple', 1),
#  ('took apple years', 1),
#  ('apple years get', 1),
#  ('years get speed', 1),
#  ('get speed larger', 1),
#  ('speed larger screens', 1),
#  ('larger screens iphone', 1),
#  ('screens iphone literally', 1),
#  ('iphone literally made', 1),
#  ('literally made fragile', 1),
#  ('made fragile glass', 1),
#  ('fragile glass everybody', 1),
#  ('glass everybody drops', 1),
#  ('everybody drops phone', 1),
#  ('drops phone sometime', 1),
#  ('phone sometime making', 1),
#  ('sometime making materials', 1),
#  ('making materials breakable', 1),
#  ('materials breakable ridiculous', 1),
#  ('breakable ridiculous drop', 1),
#  ('ridiculous drop break', 1),
#  ('drop break cost', 1),
#  ('break cost new', 1),
#  ('cost new screen', 1),
#  ('new screen a450i', 1),
#  ('screen a450i use', 1),
#  ('a450i use mine', 1),
#  ('use mine home', 1),
#  ('mine home handset', 1),
#  ('home handset rarely', 1),
#  ('handset rarely carry', 1),
#  ('rarely carry expensive', 1),
#  ('carry expensive item', 1),
#  ('expensive item risk', 1),
#  ('item risk damage', 1),
#  ('risk damage defeats', 1),
#  ('damage defeats purpose', 1),
#  ('defeats purpose almost', 1),
#  ('purpose almost entirelyyou', 1),
#  ('almost entirelyyou buy', 1),
#  ('entirelyyou buy robust', 1),
#  ('buy robust case', 1),
#  ('robust case destroy', 1),
#  ('case destroy aesthetic', 1),
#  ('destroy aesthetic part', 1),
#  ('aesthetic part reason', 1),
#  ('part reason bought', 1),
#  ('reason bought one', 1),
#  ('bought one still', 1),
#  ('one still doesnt', 1),
#  ('still doesnt guarantee', 1),
#  ('doesnt guarantee wont', 1),
#  ('guarantee wont break', 1),
#  ('wont break drop', 1),
#  ('break drop also', 1),
#  ('drop also beware', 1),
#  ('also beware folio', 1),
#  ('beware folio style', 1),
#  ('folio style cases', 1),
#  ('style cases hold', 1),
#  ('cases hold phone', 1),
#  ('hold phone magnets', 1),
#  ('phone magnets small', 1),
#  ('magnets small bump', 1),
#  ('small bump let', 1),
#  ('bump let go', 1),
#  ('let go least', 1),
#  ('go least expect', 1),
#  ('least expect itill', 1),
#  ('expect itill keep', 1),
#  ('itill keep mine', 1),
#  ('keep mine 5g', 1),
#  ('mine 5g rolls', 1),
#  ('5g rolls buy', 1),
#  ('rolls buy large', 1),
#  ('buy large screen', 1),
#  ('large screen phone', 1),
#  ('screen phone competitor', 1),
#  ('phone competitor need', 1),
#  ('competitor need carry', 1),
#  ('need carry phone', 1),
#  ('carry phone old', 1),
#  ('phone old 5', 1),
#  ('old 5 swap', 1),
#  ('5 swap sim', 1),
#  ('swap sim ridiculous', 1),
#  ('sim ridiculous better', 1),
#  ('ridiculous better blowing', 1),
#  ('better blowing cash', 1),
#  ('blowing cash screens', 1),
#  ('cash screens job', 1),
#  ('issues camera phone', 1),
#  ('camera phone apart', 1),
#  ('phone apart false', 1),
#  ('apart false advertising', 1),
#  ('false advertising water', 1),
#  ('advertising water proof', 1),
#  ('water proof splash', 1),
#  ('proof splash proof', 1),
#  ('splash proof son', 1),
#  ('proof son dropped', 1),
#  ('son dropped phone', 1),
#  ('dropped phone x', 1),
#  ('phone x spa', 1),
#  ('x spa approx', 1),
#  ('spa approx 2', 1),
#  ('approx 2 secs', 1),
#  ('2 secs damaged', 1),
#  ('secs damaged took', 1),
#  ('damaged took apple', 1),
#  ('took apple point', 1),
#  ('apple point blank', 1),
#  ('point blank refuse', 1),
#  ('blank refuse fix', 1),
#  ('refuse fix warranty', 1),
#  ('fix warranty saying', 1),
#  ('warranty saying liquid', 1),
#  ('saying liquid damage', 1),
#  ('liquid damage covered', 1),
#  ('damage covered warrantybeware', 1),
#  ('covered warrantybeware buy', 1),
#  ('warrantybeware buy phone', 1),
#  ('buy phone splash', 1),
#  ('phone splash water', 1),
#  ('splash water proof', 1),
#  ('water proof say', 1),
#  ('proof say 2mtrs', 1),
#  ('say 2mtrs 30', 1),
#  ('2mtrs 30 min', 1),
#  ('30 min load', 1),
#  ('min load bull', 1),
#  ('load bull apple', 1),
#  ('bull apple representative', 1),
#  ('apple representative said', 1),
#  ('representative said warranty', 1),
#  ('said warranty iphone', 1),
#  ('warranty iphone liquid', 1),
#  ('iphone liquid damage', 1),
#  ('liquid damage matter', 1),
#  ('damage matter ip', 1),
#  ('matter ip rating', 1),
#  ('ip rating ip', 1),
#  ('rating ip 68', 1),
#  ('ip 68 knows', 1),
#  ('68 knows means', 1),
#  ('knows means unless', 1),
#  ('means unless apple', 1),
#  ('unless apple employeei', 1),
#  ('apple employeei 10', 1),
#  ('employeei 10 phones', 1),
#  ('10 phones need', 1),
#  ('phones need repair', 1),
#  ('need repair water', 1),
#  ('repair water damage', 1),
#  ('water damage knock', 1),
#  ('damage knock back', 1),
#  ('knock back instantly', 1),
#  ('back instantly liquid', 1),
#  ('instantly liquid damage', 1),
#  ('liquid damage asked', 1),
#  ('damage asked damaged', 1),
#  ('asked damaged rain', 1),
#  ('damaged rain falling', 1),
#  ('rain falling would', 1),
#  ('falling would cover', 1),
#  ('would cover warranty', 1),
#  ('cover warranty said', 1),
#  ('warranty said 68', 1),
#  ('said 68 ip', 1),
#  ('68 ip ratingthe', 1),
#  ('ip ratingthe phone', 1),
#  ('ratingthe phone amazing', 1),
#  ('phone amazing water', 1),
#  ('amazing water proof', 1),
#  ('water proof resistant', 1),
#  ('proof resistant stateits', 1),
#  ('resistant stateits false', 1),
#  ('stateits false advertising', 1),
#  ('false advertising end', 1),
#  ('advertising end storythis', 1),
#  ('end storythis allowed', 1),
#  ('storythis allowed misleading', 1),
#  ('allowed misleading consumers', 1),
#  ('slow unimpressive design', 1),
#  ('unimpressive design like', 1),
#  ('design like last', 1),
#  ('like last models', 1),
#  ('last models phone', 1),
#  ('models phone seen', 1),
#  ('phone seen improvement', 1),
#  ('seen improvement actual', 1),
#  ('improvement actual device', 1),
#  ('actual device since', 1),
#  ('device since iphone', 1),
#  ('since iphone 6', 1),
#  ('iphone 6 improvement', 1),
#  ('6 improvement since', 1),
#  ('improvement since large', 1),
#  ('since large screenbattery', 1),
#  ('large screenbattery bad', 1),
#  ('screenbattery bad dies', 1),
#  ('bad dies quickterrible', 1),
#  ('dies quickterrible multitasking', 1),
#  ('quickterrible multitasking six', 1),
#  ('multitasking six cores', 1),
#  ('six cores get', 1),
#  ('cores get eight', 1),
#  ('get eight core', 1),
#  ('eight core device', 1),
#  ('core device half', 1),
#  ('device half pricelow', 1),
#  ('half pricelow storagelower', 1),
#  ('pricelow storagelower ramnot', 1),
#  ('storagelower ramnot american', 1),
#  ('ramnot american made', 1),
#  ('american made price', 1),
#  ('positives amazing photo', 1),
#  ('amazing photo quality', 1),
#  ('photo quality love', 1),
#  ('quality love portrait', 1),
#  ('portrait mode incredibly', 1),
#  ('mode incredibly clear', 1),
#  ('incredibly clear screen', 1),
#  ('clear screen apps', 1),
#  ('screen apps run', 1),
#  ('apps run beautifully', 1),
#  ('run beautifully everything', 1),
#  ('beautifully everything runs', 1),
#  ('everything runs incredibly', 1),
#  ('runs incredibly fastnegatives', 1),
#  ('incredibly fastnegatives expensive', 1),
#  ('fastnegatives expensive really', 1),
#  ('expensive really different', 1),
#  ('really different enough', 1),
#  ('different enough iphone', 1),
#  ('enough iphone 8', 1),
#  ('iphone 8 justify', 1),
#  ('8 justify price', 1),
#  ('justify price hike', 1),
#  ('price hike also', 1),
#  ('hike also feels', 1),
#  ('also feels large', 1),
#  ('feels large unnecessarily', 1),
#  ('large unnecessarily heavy', 1),
#  ('unnecessarily heavy really', 1),
#  ('heavy really disappointing', 1),
#  ('really disappointing doesnt', 1),
#  ('disappointing doesnt feel', 1),
#  ('doesnt feel like', 1),
#  ('feel like apple', 1),
#  ('like apple actually', 1),
#  ('apple actually addressed', 1),
#  ('actually addressed anyones', 1),
#  ('addressed anyones concerns', 1),
#  ('anyones concerns ie', 1),
#  ('concerns ie theyre', 1),
#  ('ie theyre getting', 1),
#  ('theyre getting larger', 1),
#  ('getting larger heavier', 1),
#  ('larger heavier expensive', 1),
#  ('heavier expensive easy', 1),
#  ('expensive easy break', 1),
#  ('build quality absolutely', 1),
#  ('quality absolutely horrid', 1),
#  ('absolutely horrid face', 1),
#  ('horrid face id', 1),
#  ('face id never', 1),
#  ('id never worked', 1),
#  ('never worked properly', 1),
#  ('worked properly new', 1),
#  ('properly new bought', 1),
#  ('new bought brand', 1),
#  ('bought brand new', 1),
#  ('brand new plan', 1),
#  ('new plan optus', 1),
#  ('plan optus hobart', 1),
#  ('optus hobart ditched', 1),
#  ('hobart ditched draw', 1),
#  ('ditched draw gone', 1),
#  ('draw gone back', 1),
#  ('gone back samsung', 1),
#  ('back samsung galaxy', 1),
#  ('samsung galaxy s7', 1),
#  ('galaxy s7 edge', 1),
#  ('s7 edge train', 1),
#  ('edge train wreckplease', 1),
#  ('train wreckplease reconsider', 1),
#  ('wreckplease reconsider buying', 1),
#  ('reconsider buying know', 1),
#  ('iphone x paid', 1),
#  ('x paid 1700', 1),
#  ('paid 1700 fell', 1),
#  ('1700 fell water', 1),
#  ('fell water less', 1),
#  ('water less second', 1),
#  ('less second took', 1),
#  ('second took dry', 1),
#  ('took dry gone', 1),
#  ('dry gone buy', 1),
#  ('gone buy lied', 1),
#  ('buy lied description', 1),
#  ('lied description water', 1),
#  ('description water proof', 1),
#  ('water proof go', 1),
#  ('proof go water', 1),
#  ('go water stay', 1),
#  ('water stay half', 1),
#  ('stay half hour', 1),
#  ('half hour hangs', 1),
#  ('hour hangs often', 1),
#  ('hangs often resetterrible', 1),
#  ('often resetterrible job', 1),
#  ('resetterrible job making', 1),
#  ('job making waste', 1),
#  ('making waste money', 1),
#  ('ongoing issues since', 1),
#  ('issues since purchaseunexpected', 1),
#  ('since purchaseunexpected shutdown', 1),
#  ('purchaseunexpected shutdown restartsface', 1),
#  ('shutdown restartsface id', 1),
#  ('restartsface id failureswireless', 1),
#  ('id failureswireless charging', 1),
#  ('failureswireless charging incompatibleghost', 1),
#  ('charging incompatibleghost touch', 1),
#  ('incompatibleghost touch issues', 1),
#  ('touch issues screen', 1),
#  ('issues screen delaysscreen', 1),
#  ('screen delaysscreen freezingcall', 1),
#  ('delaysscreen freezingcall answering', 1),
#  ('freezingcall answering delaysunexpected', 1),
#  ('answering delaysunexpected network', 1),
#  ('delaysunexpected network disconnectionsslow', 1),
#  ('network disconnectionsslow incapability', 1),
#  ('disconnectionsslow incapability rechargeiphone', 1),
#  ('incapability rechargeiphone lightning', 1),
#  ('rechargeiphone lightning port', 1),
#  ('lightning port charging', 1),
#  ('port charging cable', 1),
#  ('charging cable corroded', 1),
#  ('cable corroded dustwater', 1),
#  ('corroded dustwater resistantapple', 1),
#  ('dustwater resistantapple refuse', 1),
#  ('resistantapple refuse repair', 1),
#  ('refuse repair refund', 1),
#  ('repair refund lemon', 1),
#  ('refund lemon phone', 1),
#  ('lemon phone thats', 1),
#  ('phone thats 10', 1),
#  ('thats 10 months', 1),
#  ('10 months old', 1),
#  ('dont understand iphone', 1),
#  ('understand iphone x', 1),
#  ('iphone x every', 1),
#  ('x every one', 1),
#  ('every one talking', 1),
#  ('one talking much', 1),
#  ('talking much months', 1),
#  ('much months ago', 1),
#  ('months ago lot', 1),
#  ('ago lot changed', 1),
#  ('lot changed speed', 1),
#  ('changed speed phone', 1),
#  ('speed phone version', 1),
#  ('phone version also', 1),
#  ('version also owned', 1),
#  ('also owned felt', 1),
#  ('owned felt ripped', 1),
#  ('felt ripped paying', 1),
#  ('ripped paying three', 1),
#  ('paying three times', 1),
#  ('three times cost', 1),
#  ('times cost years', 1),
#  ('cost years ago', 1),
#  ('camera better scream', 1),
#  ('better scream sharp', 1),
#  ('scream sharp took', 1),
#  ('sharp took night', 1),
#  ('took night time', 1),
#  ('night time yellow', 1),
#  ('time yellow screen', 1),
#  ('yellow screen drop', 1),
#  ('screen drop menu', 1),
#  ('drop menu heavy', 1),
#  ('menu heavy wish', 1),
#  ('heavy wish smaller', 1),
#  ('wish smaller version', 1),
#  ('smaller version colours', 1),
#  ('version colours choices', 1),
#  ('colours choices black', 1),
#  ('choices black white', 1),
#  ('black white interesting', 1),
#  ('white interesting screen', 1),
#  ('interesting screen big', 1),
#  ('screen big wide', 1),
#  ('big wide female', 1),
#  ('wide female bit', 1),
#  ('female bit priced', 1),
#  ('take phone back', 1),
#  ('phone back twice', 1),
#  ('back twice times', 1),
#  ('twice times replaced', 1),
#  ('times replaced front', 1),
#  ('replaced front console', 1),
#  ('front console failed', 1),
#  ('console failed audio', 1),
#  ('failed audio tests', 1),
#  ('audio tests took', 1),
#  ('tests took back', 1),
#  ('took back noone', 1),
#  ('back noone could', 1),
#  ('noone could hear', 1),
#  ('could hear could', 1),
#  ('hear could hear', 1),
#  ('could hear fine', 1),
#  ('hear fine said', 1),
#  ('fine said next', 1),
#  ('said next time', 1),
#  ('next time bring', 1),
#  ('time bring back', 1),
#  ('bring back replace', 1),
#  ('back replace phonehaving', 1),
#  ('replace phonehaving issues', 1),
#  ('phonehaving issues soon', 1),
#  ('issues soon returned', 1),
#  ('soon returned 3rd', 1),
#  ('returned 3rd time', 1),
#  ('3rd time 5', 1),
#  ('time 5 monthsshame', 1),
#  ('5 monthsshame apart', 1),
#  ('monthsshame apart like', 1),
#  ('apart like phone', 1),
#  ('like phone also', 1),
#  ('phone also add', 1),
#  ('also add instore', 1),
#  ('add instore apply', 1),
#  ('instore apply service', 1),
#  ('apply service goodi', 1),
#  ('service goodi think', 1),
#  ('goodi think got', 1),
#  ('think got lemon', 1),
#  ('ok seen apple', 1),
#  ('seen apple launch', 1),
#  ('apple launch duel', 1),
#  ('launch duel simhang', 1),
#  ('duel simhang within', 1),
#  ('simhang within australia', 1),
#  ('within australia telcos', 1),
#  ('australia telcos want', 1),
#  ('telcos want esim', 1),
#  ('want esim installed', 1),
#  ('esim installed really', 1),
#  ('installed really great', 1),
#  ('really great apple', 1),
#  ('great apple doesnt', 1),
#  ('apple doesnt even', 1),
#  ('doesnt even release', 1),
#  ('even release data', 1),
#  ('release data antenna', 1),
#  ('data antenna people', 1),
#  ('antenna people left', 1),
#  ('people left shock', 1),
#  ('left shock wondering', 1),
#  ('shock wondering reception', 1),
#  ('wondering reception data', 1),
#  ('reception data release', 1),
#  ('data release weeks', 1),
#  ('release weeks mounts', 1),
#  ('weeks mounts release', 1),
#  ('mounts release phones', 1),
#  ('release phones good', 1),
#  ('phones good reception', 1),
#  ('good reception blue', 1),
#  ('reception blue tick', 1),
#  ('blue tick given', 1),
#  ('tick given telstra', 1),
#  ('given telstra classed', 1),
#  ('telstra classed good', 1),
#  ('classed good regional', 1),
#  ('good regional optus', 1),
#  ('regional optus date', 1),
#  ('optus date given', 1),
#  ('date given anything', 1),
#  ('given anything receptionpeople', 1),
#  ('anything receptionpeople iphone', 1),
#  ('receptionpeople iphone us', 1),
#  ('iphone us rural', 1),
#  ('us rural country', 1),
#  ('rural country areas', 1),
#  ('country areas even', 1),
#  ('areas even bother', 1),
#  ('even bother new', 1),
#  ('bother new model', 1),
#  ('new model iphone', 1),
#  ('model iphone x', 1),
#  ('iphone x models', 1),
#  ('x models poor', 1),
#  ('models poor reception', 1),
#  ('poor reception even', 1),
#  ('reception even people', 1),
#  ('even people city', 1),
#  ('people city telstra', 1),
#  ('city telstra gives', 1),
#  ('telstra gives blue', 1),
#  ('gives blue tick', 1),
#  ('blue tick phones', 1),
#  ('tick phones good', 1),
#  ('phones good receptionthe', 1),
#  ('good receptionthe duel', 1),
#  ('receptionthe duel sim', 1),
#  ('duel sim could', 1),
#  ('sim could helped', 1),
#  ('could helped people', 1),
#  ('helped people rural', 1),
#  ('people rural pleaces', 1),
#  ('rural pleaces limited', 1),
#  ('pleaces limited reception', 1),
#  ('limited reception one', 1),
#  ('reception one carrier', 1),
#  ('one carrier using', 1),
#  ('carrier using 2', 1),
#  ('using 2 sims', 1),
#  ('2 sims might', 1),
#  ('sims might helped', 1),
#  ('might helped using', 1),
#  ('helped using 2', 1),
#  ('using 2 different', 1),
#  ('2 different carriersduel', 1),
#  ('different carriersduel sim', 1),
#  ('carriersduel sim could', 1),
#  ('sim could even', 1),
#  ('could even helped', 1),
#  ('even helped people', 1),
#  ('helped people traveled', 1),
#  ('people traveled lot', 1),
#  ('traveled lot seas', 1),
#  ('lot seas well', 1),
#  ('seas well could', 1),
#  ('well could turn', 1),
#  ('could turn data', 1),
#  ('turn data sim', 1),
#  ('data sim put', 1),
#  ('sim put another', 1),
#  ('put another sim', 1),
#  ('another sim could', 1),
#  ('sim could use', 1),
#  ('could use data', 1),
#  ('use data area', 1),
#  ('data area country', 1),
#  ('area country traveling', 1),
#  ('country traveling inwe', 1),
#  ('traveling inwe user', 1),
#  ('inwe user customer', 1),
#  ('user customer able', 1),
#  ('customer able control', 1),
#  ('able control items', 1),
#  ('control items want', 1),
#  ('items want wish', 1),
#  ('want wish buybut', 1),
#  ('wish buybut telcos', 1),
#  ('buybut telcos controle', 1),
#  ('telcos controle things', 1),
#  ('controle things based', 1),
#  ('things based profitsso', 1),
#  ('based profitsso anyone', 1),
#  ('profitsso anyone wanting', 1),
#  ('anyone wanting buy', 1),
#  ('wanting buy iphone', 1),
#  ('buy iphone please', 1),
#  ('iphone please find', 1),
#  ('please find battery', 1),
#  ('find battery life', 1),
#  ('battery life reception', 1),
#  ('life reception poor', 1),
#  ('reception poor buy', 1),
#  ('phone almost year', 1),
#  ('almost year got', 1),
#  ('year got brand', 1),
#  ('brand new came', 1),
#  ('new came paid', 1),
#  ('came paid top', 1),
#  ('paid top dollar', 1),
#  ('top dollar iti', 1),
#  ('dollar iti many', 1),
#  ('iti many iphones', 1),
#  ('many iphones believe', 1),
#  ('iphones believe good', 1),
#  ('believe good device', 1),
#  ('good device whats', 1),
#  ('device whats happening', 1),
#  ('whats happening recently', 1),
#  ('happening recently apple', 1),
#  ('recently apple hype', 1),
#  ('apple hype disturbing', 1),
#  ('hype disturbing pushing', 1),
#  ('disturbing pushing price', 1),
#  ('pushing price high', 1),
#  ('price high ripping', 1),
#  ('high ripping people', 1),
#  ('ripping people thats', 1),
#  ('people thats device', 1),
#  ('thats device worth', 1),
#  ('device worth much', 1),
#  ('worth much money', 1),
#  ('much money brand', 1),
#  ('money brand total', 1),
#  ('brand total crap', 1),
#  ('total crap next', 1),
#  ('crap next phone', 1),
#  ('next phone chinese', 1),
#  ('phone chinese knock', 1),
#  ('chinese knock brand', 1),
#  ('knock brand costs', 1),
#  ('brand costs 15', 1),
#  ('costs 15 price', 1),
#  ('15 price similar', 1),
#  ('price similar specifications', 1),
#  ('similar specifications without', 1),
#  ('specifications without paying', 1),
#  ('without paying premium', 1),
#  ('paying premium apple', 1),
#  ('premium apple logo', 1),
#  ('apple logo apple', 1),
#  ('logo apple company', 1),
#  ('apple company ripping', 1),
#  ('company ripping people', 1),
#  ('ripping people funniest', 1),
#  ('people funniest thing', 1),
#  ('funniest thing people', 1),
#  ('thing people let', 1),
#  ('people let enjoyed', 1),
#  ('let enjoyed ripped', 1),
#  ('enjoyed ripped sad', 1),
#  ('ripped sad story', 1),
#  ('sad story everyone', 1),
#  ('story everyone wants', 1),
#  ('everyone wants special', 1),
#  ('wants special buying', 1),
#  ('special buying newest', 1),
#  ('buying newest apple', 1),
#  ...]

# %%
# galaxy negative review 3-gram

master_3grams_s =[]

df_s_n = df_s[df_s['sentiment'] == 'N']

for y in range(len(df_a_n)):
    kk=re.sub('[^A-Za-z0-9 ]+', '', df_s_n['review'].iloc[y]).lower()
    jj=[i for i in word_tokenize(kk) if i not in stopwords]

    n_grams=ngrams(jj, 3)
    qq=[ ' '.join(grams) for grams in n_grams]

    master_3grams_s = master_3grams_s + qq

# %%
Counter(master_3grams_s).most_common()
# Out:
# [('samsung galaxy s9', 10),
#  ('2 weeks ago', 5),
#  ('3 weeks ago', 5),
#  ('phone month ago', 4),
#  ('samsung s7 edge', 3),
#  ('battery life terrible', 3),
#  ('disappointed battery life', 3),
#  ('couple weeks ago', 3),
#  ('dont see much', 3),
#  ('see much difference', 3),
#  ('bought phone month', 3),
#  ('two weeks ago', 3),
#  ('phone ive ever', 3),
#  ('battery life poor', 3),
#  ('last 2 years', 3),
#  ('bought 2 weeks', 3),
#  ('upgraded s7 edge', 3),
#  ('s7 edge s9', 3),
#  ('bought week ago', 3),
#  ('s7 edge better', 2),
#  ('edge better battery', 2),
#  ('better battery life', 2),
#  ('case screen protector', 2),
#  ('back iphone soon', 2),
#  ('phone day everyday', 2),
#  ('camera battery life', 2),
#  ('tap tap tap', 2),
#  ('switch back iphone', 2),
#  ('purchased samsung galaxy', 2),
#  ('s9 2 weeks', 2),
#  ('phone dont see', 2),
#  ('new samsung galaxy', 2),
#  ('every time go', 2),
#  ('get pop adverts', 2),
#  ('super slow mo', 2),
#  ('features would work', 2),
#  ('paid full price', 2),
#  ('samsung galaxy s7', 2),
#  ('go back samsung', 2),
#  ('samsung s9 samsung', 2),
#  ('phone nice back', 2),
#  ('nice back camera', 2),
#  ('back camera easy', 2),
#  ('camera easy crack', 2),
#  ('easy crack careful', 2),
#  ('crack careful refunded', 2),
#  ('careful refunded covered', 2),
#  ('refunded covered insurance', 2),
#  ('phone gets hot', 2),
#  ('much difference old', 2),
#  ('difference old phone', 2),
#  ('dont like phone', 2),
#  ('phone week ago', 2),
#  ('doesnt last long', 2),
#  ('wish kept old', 2),
#  ('kept old phone', 2),
#  ('best phone ive', 2),
#  ('back old phone', 2),
#  ('different s8 plus', 2),
#  ('wish never got', 2),
#  ('much difference s8', 2),
#  ('better new phone', 2),
#  ('less month ago', 2),
#  ('s7 2 years', 2),
#  ('always loved samsung', 2),
#  ('bought month ago', 2),
#  ('signal could get', 2),
#  ('bought phone last', 2),
#  ('phone last week', 2),
#  ('difference s8 s9', 2),
#  ('phone wouldnt recommend', 2),
#  ('bought 3 weeks', 2),
#  ('s9 3 weeks', 2),
#  ('im really disappointed', 2),
#  ('battery life better', 2),
#  ('half screen stopped', 2),
#  ('screen stopped working', 2),
#  ('old samsung s7', 2),
#  ('battery life phone', 2),
#  ('weeks ago disappointed', 2),
#  ('battery doesnt last', 2),
#  ('battery life really', 2),
#  ('life really bad', 2),
#  ('front facing camera', 2),
#  ('phone two weeks', 2),
#  ('s9 battery life', 2),
#  ('phone less month', 2),
#  ('onto new phone', 2),
#  ('much difference s7', 2),
#  ('took phone pocket', 2),
#  ('phone 2 weeks', 2),
#  ('cant seem get', 2),
#  ('samsung s9 1', 1),
#  ('s9 1 month', 1),
#  ('1 month battery', 1),
#  ('month battery life', 1),
#  ('battery life barely', 1),
#  ('life barely last', 1),
#  ('barely last 2', 1),
#  ('last 2 days', 1),
#  ('2 days medium', 1),
#  ('days medium power', 1),
#  ('medium power saving', 1),
#  ('power saving samsung', 1),
#  ('saving samsung s7', 1),
#  ('battery life iphone', 1),
#  ('life iphone 7', 1),
#  ('iphone 7 work', 1),
#  ('7 work phone', 1),
#  ('work phone 18', 1),
#  ('phone 18 months', 1),
#  ('18 months use', 1),
#  ('months use day', 1),
#  ('use day working', 1),
#  ('day working hours', 1),
#  ('working hours last', 1),
#  ('hours last least', 1),
#  ('last least 3', 1),
#  ('least 3 days', 1),
#  ('3 days could', 1),
#  ('days could go', 1),
#  ('could go wrong', 1),
#  ('go wrong samsung', 1),
#  ('wrong samsung happy', 1),
#  ('told phone amazingthe', 1),
#  ('phone amazingthe camera', 1),
#  ('amazingthe camera never', 1),
#  ('camera never focuses', 1),
#  ('never focuses even', 1),
#  ('focuses even using', 1),
#  ('even using selective', 1),
#  ('using selective focus', 1),
#  ('selective focus setting', 1),
#  ('focus setting takes', 1),
#  ('setting takes photo', 1),
#  ('takes photo always', 1),
#  ('photo always says', 1),
#  ('always says could', 1),
#  ('says could focusthe', 1),
#  ('could focusthe battery', 1),
#  ('focusthe battery life', 1),
#  ('life terrible husband', 1),
#  ('terrible husband gets', 1),
#  ('husband gets nearly', 1),
#  ('gets nearly two', 1),
#  ('nearly two days', 1),
#  ('two days phone', 1),
#  ('days phone get', 1),
#  ('phone get day', 1),
#  ('get day hour', 1),
#  ('day hour took', 1),
#  ('hour took charge', 1),
#  ('took charge 78', 1),
#  ('charge 78 havent', 1),
#  ('78 havent watched', 1),
#  ('havent watched anything', 1),
#  ('watched anything googling', 1),
#  ('anything googling reviews', 1),
#  ('googling reviews phone', 1),
#  ('reviews phone open', 1),
#  ('phone open apps', 1),
#  ('open apps closeddont', 1),
#  ('apps closeddont like', 1),
#  ('closeddont like screen', 1),
#  ('like screen goes', 1),
#  ('screen goes around', 1),
#  ('goes around sides', 1),
#  ('around sides brought', 1),
#  ('sides brought phone', 1),
#  ('brought phone coveri', 1),
#  ('phone coveri wish', 1),
#  ('coveri wish stayed', 1),
#  ('wish stayed ohh', 1),
#  ('stayed ohh well', 1),
#  ('samsung crap cheap', 1),
#  ('crap cheap phone', 1),
#  ('cheap phone wonder', 1),
#  ('phone wonder whose', 1),
#  ('wonder whose stupid', 1),
#  ('whose stupid idiot', 1),
#  ('stupid idiot made', 1),
#  ('idiot made phone', 1),
#  ('made phone always', 1),
#  ('phone always many', 1),
#  ('always many problems', 1),
#  ('many problems whenever', 1),
#  ('problems whenever use', 1),
#  ('whenever use crap', 1),
#  ('use crap phone', 1),
#  ('crap phone iphones', 1),
#  ('phone iphones much', 1),
#  ('iphones much better', 1),
#  ('much better customer', 1),
#  ('better customer service', 1),
#  ('customer service best', 1),
#  ('service best also', 1),
#  ('best also like', 1),
#  ('also like crap', 1),
#  ('like crap samsung', 1),
#  ('screen goes way', 1),
#  ('goes way edge', 1),
#  ('way edge dont', 1),
#  ('edge dont like', 1),
#  ('dont like kept', 1),
#  ('like kept pressing', 1),
#  ('kept pressing things', 1),
#  ('pressing things accident', 1),
#  ('things accident phone', 1),
#  ('accident phone way', 1),
#  ('phone way slippery', 1),
#  ('way slippery spend', 1),
#  ('slippery spend 30', 1),
#  ('spend 30 dollars', 1),
#  ('30 dollars cover', 1),
#  ('dollars cover bixby', 1),
#  ('cover bixby joke', 1),
#  ('bixby joke stuck', 1),
#  ('joke stuck s7', 1),
#  ('stuck s7 loved', 1),
#  ('s7 loved phone', 1),
#  ('loved phone wonder', 1),
#  ('phone wonder find', 1),
#  ('wonder find another', 1),
#  ('phone protected case', 1),
#  ('protected case screen', 1),
#  ('screen protector 3', 1),
#  ('protector 3 weeks', 1),
#  ('3 weeks old', 1),
#  ('weeks old phone', 1),
#  ('old phone sadly', 1),
#  ('phone sadly dropped', 1),
#  ('sadly dropped hip', 1),
#  ('dropped hip height', 1),
#  ('hip height im', 1),
#  ('height im bfg', 1),
#  ('im bfg smash', 1),
#  ('bfg smash almost', 1),
#  ('smash almost tears', 1),
#  ('almost tears eyes', 1),
#  ('tears eyes everything', 1),
#  ('eyes everything protect', 1),
#  ('everything protect still', 1),
#  ('protect still smashed', 1),
#  ('still smashed went', 1),
#  ('smashed went repair', 1),
#  ('went repair shop', 1),
#  ('repair shop tears', 1),
#  ('shop tears let', 1),
#  ('tears let go', 1),
#  ('let go told', 1),
#  ('go told repairman', 1),
#  ('told repairman screen', 1),
#  ('repairman screen protectors', 1),
#  ('screen protectors dont', 1),
#  ('protectors dont work', 1),
#  ('dont work well', 1),
#  ('work well due', 1),
#  ('well due curved', 1),
#  ('due curved edges', 1),
#  ('curved edges cost', 1),
#  ('edges cost 490', 1),
#  ('cost 490 fix', 1),
#  ('490 fix actual', 1),
#  ('fix actual fries', 1),
#  ('actual fries nothing', 1),
#  ('fries nothing repair', 1),
#  ('nothing repair shops', 1),
#  ('repair shops price', 1),
#  ('shops price set', 1),
#  ('price set samsung', 1),
#  ('set samsung keep', 1),
#  ('samsung keep mind', 1),
#  ('keep mind purchasing', 1),
#  ('mind purchasing brand', 1),
#  ('purchasing brand owner', 1),
#  ('brand owner one', 1),
#  ('owner one kind', 1),
#  ('one kind price', 1),
#  ('kind price cracked', 1),
#  ('price cracked s9', 1),
#  ('never upset phone', 1),
#  ('upset phone coming', 1),
#  ('phone coming using', 1),
#  ('coming using iphone', 1),
#  ('using iphone 6', 1),
#  ('iphone 6 years', 1),
#  ('6 years battery', 1),
#  ('years battery horrible', 1),
#  ('battery horrible phone', 1),
#  ('horrible phone dials', 1),
#  ('phone dials people', 1),
#  ('dials people screen', 1),
#  ('people screen sometimes', 1),
#  ('screen sometimes plays', 1),
#  ('sometimes plays way', 1),
#  ('plays way expensive', 1),
#  ('way expensive fix', 1),
#  ('expensive fix samsung', 1),
#  ('fix samsung dont', 1),
#  ('samsung dont help', 1),
#  ('dont help way', 1),
#  ('help way nearly', 1),
#  ('way nearly 2', 1),
#  ('nearly 2 months', 1),
#  ('2 months screen', 1),
#  ('months screen decides', 1),
#  ('screen decides freeze', 1),
#  ('decides freeze go', 1),
#  ('freeze go yellow', 1),
#  ('hate bixby want', 1),
#  ('bixby want use', 1),
#  ('want use insists', 1),
#  ('use insists upon', 1),
#  ('insists upon waste', 1),
#  ('upon waste butyon', 1),
#  ('waste butyon grrrrrrr', 1),
#  ('butyon grrrrrrr annoying', 1),
#  ('grrrrrrr annoying also', 1),
#  ('annoying also taking', 1),
#  ('also taking screenshots', 1),
#  ('taking screenshots id', 1),
#  ('screenshots id pain', 1),
#  ('id pain butt', 1),
#  ('pain butt hard', 1),
#  ('butt hard make', 1),
#  ('hard make work', 1),
#  ('make work invokes', 1),
#  ('work invokes bixby', 1),
#  ('invokes bixby hatelost', 1),
#  ('bixby hatelost much', 1),
#  ('hatelost much functionality', 1),
#  ('much functionality camera', 1),
#  ('functionality camera last', 1),
#  ('camera last model', 1),
#  ('last model downgrade', 1),
#  ('model downgrade upgrade', 1),
#  ('downgrade upgrade portrait', 1),
#  ('upgrade portrait functionality', 1),
#  ('first glance s9', 1),
#  ('glance s9 beautiful', 1),
#  ('s9 beautiful turn', 1),
#  ('beautiful turn thing', 1),
#  ('turn thing get', 1),
#  ('thing get know', 1),
#  ('get know starts', 1),
#  ('know starts silly', 1),
#  ('starts silly things', 1),
#  ('silly things never', 1),
#  ('things never issue', 1),
#  ('never issue apple', 1),
#  ('issue apple always', 1),
#  ('apple always run', 1),
#  ('always run everything', 1),
#  ('run everything smooth', 1),
#  ('everything smooth get', 1),
#  ('smooth get pretty', 1),
#  ('get pretty much', 1),
#  ('pretty much everything', 1),
#  ('much everything backed', 1),
#  ('everything backed s9', 1),
#  ('backed s9 keyboard', 1),
#  ('s9 keyboard started', 1),
#  ('keyboard started type', 1),
#  ('started type things', 1),
#  ('type things typing', 1),
#  ('things typing took', 1),
#  ('typing took shop', 1),
#  ('took shop done', 1),
#  ('shop done software', 1),
#  ('done software reboot', 1),
#  ('software reboot lost', 1),
#  ('reboot lost 4', 1),
#  ('lost 4 months', 1),
#  ('4 months worth', 1),
#  ('months worth photos', 1),
#  ('worth photos family', 1),
#  ('photos family important', 1),
#  ('family important files', 1),
#  ('important files never', 1),
#  ('files never get', 1),
#  ('never get back', 1),
#  ('get back changing', 1),
#  ('back changing samsung', 1),
#  ('changing samsung worse', 1),
#  ('samsung worse thing', 1),
#  ('worse thing ever', 1),
#  ('thing ever done', 1),
#  ('ever done recontracted', 1),
#  ('done recontracted cant', 1),
#  ('recontracted cant much', 1),
#  ('cant much change', 1),
#  ('much change phone', 1),
#  ('change phone definitely', 1),
#  ('phone definitely go', 1),
#  ('definitely go back', 1),
#  ('go back iphone', 1),
#  ('iphone soon 1', 1),
#  ('soon 1 year', 1),
#  ('1 year samsung', 1),
#  ('year samsung phones', 1),
#  ('samsung phones tries', 1),
#  ('phones tries much', 1),
#  ('tries much everything', 1),
#  ('much everything crap', 1),
#  ('everything crap iphone', 1),
#  ('crap iphone user', 1),
#  ('iphone user friendly', 1),
#  ('user friendly dont', 1),
#  ('friendly dont know', 1),
#  ('dont know people', 1),
#  ('know people would', 1),
#  ('people would ever', 1),
#  ('would ever go', 1),
#  ('ever go samsung', 1),
#  ('go samsung idiot', 1),
#  ('samsung idiot dont', 1),
#  ('idiot dont make', 1),
#  ('dont make mistake', 1),
#  ('camera quality good', 1),
#  ('quality good although', 1),
#  ('good although find', 1),
#  ('although find hard', 1),
#  ('find hard advertised', 1),
#  ('hard advertised one', 1),
#  ('advertised one major', 1),
#  ('one major selling', 1),
#  ('major selling points', 1),
#  ('selling points phone', 1),
#  ('points phone would', 1),
#  ('phone would personally', 1),
#  ('would personally buy', 1),
#  ('personally buy phone', 1),
#  ('buy phone based', 1),
#  ('phone based camera', 1),
#  ('based camera quality', 1),
#  ('camera quality display', 1),
#  ('quality display good', 1),
#  ('display good brightness', 1),
#  ('good brightness settings', 1),
#  ('brightness settings cant', 1),
#  ('settings cant complain', 1),
#  ('cant complain biggest', 1),
#  ('complain biggest complaint', 1),
#  ('biggest complaint phone', 1),
#  ('complaint phone one', 1),
#  ('phone one latest', 1),
#  ('one latest ir', 1),
#  ('latest ir meaning', 1),
#  ('ir meaning apps', 1),
#  ('meaning apps like', 1),
#  ('apps like tv', 1),
#  ('like tv remote', 1),
#  ('tv remote work', 1),
#  ('remote work affordable', 1),
#  ('work affordable phones', 1),
#  ('affordable phones manage', 1),
#  ('phones manage feature', 1),
#  ('manage feature also', 1),
#  ('feature also phone', 1),
#  ('also phone boasts', 1),
#  ('phone boasts waterproof', 1),
#  ('boasts waterproof yet', 1),
#  ('waterproof yet speakers', 1),
#  ('yet speakers muffle', 1),
#  ('speakers muffle slightest', 1),
#  ('muffle slightest touch', 1),
#  ('slightest touch water', 1),
#  ('touch water go', 1),
#  ('water go figure', 1),
#  ('go figure phone', 1),
#  ('figure phone far', 1),
#  ('phone far living', 1),
#  ('far living expectations', 1),
#  ('omg hate hate', 1),
#  ('hate hate hate', 1),
#  ('hate hate bixbie', 1),
#  ('hate bixbie granted', 1),
#  ('bixbie granted dont', 1),
#  ('granted dont know', 1),
#  ('dont know works', 1),
#  ('know works except', 1),
#  ('works except marketing', 1),
#  ('except marketing device', 1),
#  ('marketing device gets', 1),
#  ('device gets way', 1),
#  ('gets way everytime', 1),
#  ('way everytime use', 1),
#  ('everytime use phone', 1),
#  ('use phone want', 1),
#  ('phone want advertising', 1),
#  ('want advertising phone', 1),
#  ('advertising phone managed', 1),
#  ('phone managed turn', 1),
#  ('managed turn everything', 1),
#  ('turn everything bixbie', 1),
#  ('everything bixbie horrible', 1),
#  ('bixbie horrible cant', 1),
#  ('horrible cant like', 1),
#  ('cant like phone', 1),
#  ('like phone tainted', 1),
#  ('phone tainted enjoyment', 1),
#  ('tainted enjoyment could', 1),
#  ('enjoyment could new', 1),
#  ('could new phone', 1),
#  ('new phone iphone', 1),
#  ('phone iphone user', 1),
#  ('iphone user similar', 1),
#  ('user similar different', 1),
#  ('similar different operating', 1),
#  ('different operating system', 1),
#  ('operating system annoying', 1),
#  ('system annoying get', 1),
#  ('annoying get used', 1),
#  ('get used change', 1),
#  ('used change connecting', 1),
#  ('change connecting cables', 1),
#  ('connecting cables previous', 1),
#  ('cables previous samsungs', 1),
#  ('previous samsungs annoying', 1),
#  ('samsungs annoying siri', 1),
#  ('annoying siri something', 1),
#  ('siri something used', 1),
#  ('something used least', 1),
#  ('used least could', 1),
#  ('least could choose', 1),
#  ('could choose voice', 1),
#  ('choose voice use', 1),
#  ('voice use didnt', 1),
#  ('use didnt try', 1),
#  ('didnt try sell', 1),
#  ('try sell anything', 1),
#  ('sell anything get', 1),
#  ('anything get bixbie', 1),
#  ('get bixbie samsungs', 1),
#  ('bixbie samsungs siri', 1),
#  ('samsungs siri horrible', 1),
#  ('siri horrible version', 1),
#  ('ok good phone', 1),
#  ('good phone battery', 1),
#  ('phone battery sucks', 1),
#  ('battery sucks bad', 1),
#  ('sucks bad literally', 1),
#  ('bad literally returned', 1),
#  ('literally returned brand', 1),
#  ('returned brand new', 1),
#  ('brand new s9', 1),
#  ('new s9 im', 1),
#  ('s9 im surprised', 1),
#  ('im surprised updates', 1),
#  ('surprised updates software', 1),
#  ('updates software device', 1),
#  ('software device expect', 1),
#  ('device expect battery', 1),
#  ('expect battery run', 1),
#  ('battery run quickly', 1),
#  ('run quickly easily', 1),
#  ('quickly easily nightmare', 1),
#  ('easily nightmare need', 1),
#  ('nightmare need phone', 1),
#  ('need phone day', 1),
#  ('day everyday im', 1),
#  ('everyday im used', 1),
#  ('im used using', 1),
#  ('used using phone', 1),
#  ('using phone day', 1),
#  ('day everyday without', 1),
#  ('everyday without recharging', 1),
#  ('without recharging s9', 1),
#  ('loved s8 decided', 1),
#  ('s8 decided upgrade', 1),
#  ('decided upgrade s9', 1),
#  ('upgrade s9 big', 1),
#  ('s9 big regrets', 1),
#  ('big regrets smses', 1),
#  ('regrets smses friends', 1),
#  ('smses friends delayed', 1),
#  ('friends delayed end', 1),
#  ('delayed end grouped', 1),
#  ('end grouped recieved', 1),
#  ('grouped recieved hours', 1),
#  ('recieved hours later', 1),
#  ('hours later unreliable', 1),
#  ('later unreliable sms', 1),
#  ('unreliable sms service', 1),
#  ('sms service rest', 1),
#  ('service rest phone', 1),
#  ('rest phone great', 1),
#  ('phone great sms', 1),
#  ('great sms really', 1),
#  ('sms really regret', 1),
#  ('really regret mobile', 1),
#  ('regret mobile dont', 1),
#  ('mobile dont recommend', 1),
#  ('dont recommend friend', 1),
#  ('recommend friend phone', 1),
#  ('friend phone problems', 1),
#  ('phone total 3', 1),
#  ('total 3 hours', 1),
#  ('3 hours hate', 1),
#  ('hours hate functions', 1),
#  ('hate functions close', 1),
#  ('functions close edge', 1),
#  ('close edge screen', 1),
#  ('edge screen need', 1),
#  ('screen need nearly', 1),
#  ('need nearly press', 1),
#  ('nearly press finger', 1),
#  ('press finger glass', 1),
#  ('finger glass get', 1),
#  ('glass get respond', 1),
#  ('get respond face', 1),
#  ('respond face retina', 1),
#  ('face retina fingerprint', 1),
#  ('retina fingerprint login', 1),
#  ('fingerprint login repeatedly', 1),
#  ('login repeatedly failed', 1),
#  ('repeatedly failed switched', 1),
#  ('failed switched smart', 1),
#  ('switched smart switch', 1),
#  ('smart switch transfer', 1),
#  ('switch transfer transferred', 1),
#  ('transfer transferred apps', 1),
#  ('transferred apps corrupted', 1),
#  ('apps corrupted make', 1),
#  ('corrupted make across', 1),
#  ('make across bluetooth', 1),
#  ('across bluetooth recognition', 1),
#  ('bluetooth recognition car', 1),
#  ('recognition car wont', 1),
#  ('car wont work', 1),
#  ('laptop stays connected', 1),
#  ('stays connected tablet', 1),
#  ('connected tablet phone', 1),
#  ('tablet phone cant', 1),
#  ('phone cant stay', 1),
#  ('cant stay connected', 1),
#  ('stay connected reliably', 1),
#  ('connected reliably despite', 1),
#  ('reliably despite called', 1),
#  ('despite called best', 1),
#  ('called best android', 1),
#  ('best android phone', 1),
#  ('android phone 2018', 1),
#  ('phone 2018 never', 1),
#  ('2018 never going', 1),
#  ('never going buy', 1),
#  ('going buy another', 1),
#  ('buy another samsung', 1),
#  ('another samsung product', 1),
#  ('samsung product guess', 1),
#  ('product guess specs', 1),
#  ('guess specs good', 1),
#  ('specs good looks', 1),
#  ('good looks good', 1),
#  ('looks good phone', 1),
#  ('good phone cant', 1),
#  ('phone cant something', 1),
#  ('cant something basic', 1),
#  ('something basic properly', 1),
#  ('basic properly horrible', 1),
#  ('properly horrible product', 1),
#  ('horrible product phones', 1),
#  ('product phones good', 1),
#  ('phones good cost', 1),
#  ('good cost less', 1),
#  ('cost less arent', 1),
#  ('less arent recognized', 1),
#  ('arent recognized much', 1),
#  ('recognized much samsung', 1),
#  ('much samsung feeding', 1),
#  ('samsung feeding overrated', 1),
#  ('feeding overrated brand', 1),
#  ('overrated brand name', 1),
#  ('dont like cant', 1),
#  ('like cant customize', 1),
#  ('cant customize much', 1),
#  ('customize much phone', 1),
#  ('much phone ring', 1),
#  ('phone ring tones', 1),
#  ('ring tones message', 1),
#  ('tones message notification', 1),
#  ('message notification sounds', 1),
#  ('notification sounds arent', 1),
#  ('sounds arent good', 1),
#  ('arent good background', 1),
#  ('good background themes', 1),
#  ('background themes limited', 1),
#  ('themes limited cant', 1),
#  ('limited cant change', 1),
#  ('cant change message', 1),
#  ('change message background', 1),
#  ('message background cant', 1),
#  ('background cant change', 1),
#  ('cant change keyboard', 1),
#  ('change keyboard shouldnt', 1),
#  ('keyboard shouldnt download', 1),
#  ('shouldnt download apps', 1),
#  ('download apps customize', 1),
#  ('apps customize phone', 1),
#  ('customize phone want', 1),
#  ('phone good price', 1),
#  ('good price tag', 1),
#  ('price tag suggests', 1),
#  ('tag suggests bixby', 1),
#  ('suggests bixby hardware', 1),
#  ('bixby hardware button', 1),
#  ('hardware button rubbish', 1),
#  ('button rubbish hope', 1),
#  ('rubbish hope samsungs', 1),
#  ('hope samsungs bloatware', 1),
#  ('samsungs bloatware goes', 1),
#  ('bloatware goes direction', 1),
#  ('goes direction next', 1),
#  ('direction next model', 1),
#  ('next model next', 1),
#  ('model next model', 1),
#  ('next model buyi', 1),
#  ('model buyi grabbed', 1),
#  ('buyi grabbed gear', 1),
#  ('grabbed gear vr', 1),
#  ('gear vr phone', 1),
#  ('vr phone get', 1),
#  ('phone get newer', 1),
#  ('get newer one', 1),
#  ('newer one runs', 1),
#  ('one runs note', 1),
#  ('runs note 8', 1),
#  ('note 8 fantastic', 1),
#  ('8 fantastic really', 1),
#  ('fantastic really deep', 1),
#  ('really deep vr', 1),
#  ('deep vr games', 1),
#  ('vr games pretty', 1),
#  ('games pretty fun', 1),
#  ('pretty fun 150au', 1),
#  ('fun 150au add', 1),
#  ('frustrating try sending', 1),
#  ('try sending message', 1),
#  ('sending message new', 1),
#  ('message new number', 1),
#  ('new number nightmare', 1),
#  ('number nightmare write', 1),
#  ('nightmare write new', 1),
#  ('write new message', 1),
#  ('new message button', 1),
#  ('message button loved', 1),
#  ('button loved note', 1),
#  ('loved note 4', 1),
#  ('note 4 loath', 1),
#  ('4 loath changes', 1),
#  ('loath changes s9', 1),
#  ('changes s9 keyboard', 1),
#  ('s9 keyboard changes', 1),
#  ('keyboard changes mean', 1),
#  ('changes mean dialogue', 1),
#  ('mean dialogue box', 1),
#  ('dialogue box keeps', 1),
#  ('box keeps jumping', 1),
#  ('keeps jumping arrow', 1),
#  ('jumping arrow buttons', 1),
#  ('arrow buttons close', 1),
#  ('buttons close dialogue', 1),
#  ('close dialogue box', 1),
#  ('dialogue box edges', 1),
#  ('box edges big', 1),
#  ('edges big time', 1),
#  ('big time buyers', 1),
#  ('time buyers regretbattery', 1),
#  ('buyers regretbattery life', 1),
#  ('regretbattery life soo', 1),
#  ('life soo great', 1),
#  ('soo great either', 1),
#  ('great either disappointed', 1),
#  ('phone confusing badly', 1),
#  ('confusing badly designed', 1),
#  ('badly designed always', 1),
#  ('designed always samsung', 1),
#  ('always samsung phones', 1),
#  ('samsung phones last', 1),
#  ('phones last texting', 1),
#  ('last texting nightmare', 1),
#  ('texting nightmare curved', 1),
#  ('nightmare curved screencant', 1),
#  ('curved screencant figure', 1),
#  ('screencant figure differ', 1),
#  ('figure differ ringtones', 1),
#  ('differ ringtones looking', 1),
#  ('ringtones looking new', 1),
#  ('looking new phone', 1),
#  ('new phone give', 1),
#  ('phone give one', 1),
#  ('give one missphew', 1),
#  ('one missphew thanks', 1),
#  ('missphew thanks samsung', 1),
#  ('thanks samsung activation', 1),
#  ('samsung activation caused', 1),
#  ('phone came without', 1),
#  ('came without bixby', 1),
#  ('without bixby id', 1),
#  ('bixby id give', 1),
#  ('id give item', 1),
#  ('give item 4', 1),
#  ('item 4 stars', 1),
#  ('4 stars least', 1),
#  ('stars least come', 1),
#  ('least come without', 1),
#  ('come without need', 1),
#  ('without need 3rd', 1),
#  ('need 3rd party', 1),
#  ('3rd party app', 1),
#  ('party app disablevery', 1),
#  ('app disablevery poor', 1),
#  ('disablevery poor button', 1),
#  ('poor button sizing', 1),
#  ('button sizing needs', 1),
#  ('sizing needs addressedgreat', 1),
#  ('needs addressedgreat earphonesgetting', 1),
#  ('addressedgreat earphonesgetting annoyed', 1),
#  ('earphonesgetting annoyed fifty', 1),
#  ('annoyed fifty words', 1),
#  ('fifty words requirement', 1),
#  ('words requirement describe', 1),
#  ('requirement describe accurately', 1),
#  ('describe accurately easily', 1),
#  ('bought recently great', 1),
#  ('recently great camera', 1),
#  ('great camera battery', 1),
#  ('life terrible samsung', 1),
#  ('terrible samsung really', 1),
#  ('samsung really stuffed', 1),
#  ('really stuffed seems', 1),
#  ('stuffed seems like', 1),
#  ('seems like exynos', 1),
#  ('like exynos chip', 1),
#  ('exynos chip blame', 1),
#  ('chip blame stuck', 1),
#  ('blame stuck australia', 1),
#  ('stuck australia choice', 1),
#  ('australia choice would', 1),
#  ('choice would probably', 1),
#  ('would probably wait', 1),
#  ('probably wait months', 1),
#  ('wait months get', 1),
#  ('months get next', 1),
#  ('get next gen', 1),
#  ('next gen hold', 1),
#  ('gen hold onto', 1),
#  ('hold onto old', 1),
#  ('onto old phone', 1),
#  ('1 visual aid', 1),
#  ('visual aid constantly', 1),
#  ('aid constantly turning', 1),
#  ('constantly turning needs', 1),
#  ('turning needs new', 1),
#  ('needs new access', 1),
#  ('new access mode', 1),
#  ('access mode cant', 1),
#  ('mode cant even', 1),
#  ('cant even tell', 1),
#  ('even tell many', 1),
#  ('tell many times', 1),
#  ('many times go', 1),
#  ('times go accessabillty', 1),
#  ('go accessabillty turn', 1),
#  ('accessabillty turn super', 1),
#  ('turn super annoying2', 1),
#  ('super annoying2 bixby', 1),
#  ('annoying2 bixby need', 1),
#  ('bixby need side', 1),
#  ('need side button', 1),
#  ('side button home', 1),
#  ('button home screen', 1),
#  ('home screen icon', 1),
#  ('screen icon great', 1),
#  ('icon great side', 1),
#  ('great side button', 1),
#  ('side button makes', 1),
#  ('button makes annoying', 1),
#  ('makes annoying constantly', 1),
#  ('annoying constantly swipe', 1),
#  ('constantly swipe away3', 1),
#  ('swipe away3 importantly', 1),
#  ('away3 importantly told', 1),
#  ('importantly told phone', 1),
#  ('told phone fast', 1),
#  ('phone fast heck', 1),
#  ('fast heck best', 1),
#  ('heck best phone', 1),
#  ('best phone market', 1),
#  ('phone market far', 1),
#  ('market far first', 1),
#  ('far first days', 1),
#  ('first days good', 1),
#  ('days good nothing', 1),
#  ('good nothing special', 1),
#  ('nothing special less', 1),
#  ('special less 2', 1),
#  ('less 2 weeks', 1),
#  ('2 weeks onpitiful', 1),
#  ('weeks onpitiful pretty', 1),
#  ('onpitiful pretty average', 1),
#  ('pretty average apps', 1),
#  ('average apps phone', 1),
#  ('apps phone games', 1),
#  ('phone games etc', 1),
#  ('games etc clean', 1),
#  ('etc clean privacy', 1),
#  ('clean privacy settings', 1),
#  ('privacy settings etc', 1),
#  ('settings etc slower', 1),
#  ('etc slower s6', 1),
#  ('slower s6 seems', 1),
#  ('s6 seems like', 1),
#  ('seems like went', 1),
#  ('like went kaput', 1),
#  ('went kaput going', 1),
#  ('kaput going back', 1),
#  ('going back store', 1),
#  ('back store tomorrowvery', 1),
#  ('store tomorrowvery disappointed', 1),
#  ('camera takes crappy', 1),
#  ('takes crappy pictures', 1),
#  ('crappy pictures close', 1),
#  ('pictures close phone', 1),
#  ('close phone opens', 1),
#  ('phone opens apps', 1),
#  ('opens apps bigsby', 1),
#  ('apps bigsby annoying', 1),
#  ('bigsby annoying waste', 1),
#  ('annoying waste time', 1),
#  ('waste time heshe', 1),
#  ('time heshe smart', 1),
#  ('heshe smart would', 1),
#  ('smart would kept', 1),
#  ('would kept galaxy', 1),
#  ('kept galaxy 7', 1),
#  ('galaxy 7 knew', 1),
#  ('7 knew ahead', 1),
#  ('knew ahead time', 1),
#  ('ahead time phone', 1),
#  ('time phone garbage', 1),
#  ('phone garbage next', 1),
#  ('garbage next time', 1),
#  ('next time im', 1),
#  ('time im research', 1),
#  ('im research first', 1),
#  ('dont know lemon', 1),
#  ('know lemon phone', 1),
#  ('lemon phone tap', 1),
#  ('phone tap tap', 1),
#  ('tap tap go', 1),
#  ('tap go anywhere', 1),
#  ('go anywhere example', 1),
#  ('anywhere example taken', 1),
#  ('example taken nearly', 1),
#  ('taken nearly 15', 1),
#  ('nearly 15 minutes', 1),
#  ('15 minutes write', 1),
#  ('minutes write constantly', 1),
#  ('write constantly check', 1),
#  ('constantly check go', 1),
#  ('check go back', 1),
#  ('go back see', 1),
#  ('back see function', 1),
#  ('see function im', 1),
#  ('function im trying', 1),
#  ('im trying occurring', 1),
#  ('trying occurring im', 1),
#  ('occurring im extremely', 1),
#  ('im extremely unhappy', 1),
#  ('extremely unhappy spending', 1),
#  ('unhappy spending 70000', 1),
#  ('spending 70000 plus', 1),
#  ('70000 plus poor', 1),
#  ('plus poor quality', 1),
#  ('poor quality likely', 1),
#  ('quality likely last', 1),
#  ('likely last 3', 1),
#  ('last 3 years', 1),
#  ('3 years best', 1),
#  ('years best money', 1),
#  ('best money talks', 1),
#  ('money talks shows', 1),
#  ('talks shows samsung', 1),
#  ('shows samsung apple', 1),
#  ('samsung apple control', 1),
#  ('apple control market', 1),
#  ('ive switched iphone', 1),
#  ('switched iphone samsung', 1),
#  ('iphone samsung galaxy', 1),
#  ('galaxy s9 buyers', 1),
#  ('s9 buyers remorse', 1),
#  ('buyers remorse earth', 1),
#  ('remorse earth would', 1),
#  ('earth would build', 1),
#  ('would build designated', 1),
#  ('build designated button', 1),
#  ('designated button bixby', 1),
#  ('button bixby button', 1),
#  ('bixby button always', 1),
#  ...]

# %% [markdown]
# Here are some of things we can infer from our n-gram analysis.
#
# iPhone X
#
# 1. Users are not happy about home button iPhone X.
#
# + Users are not happy about face recognition in iPhone X.
#
# + Users thinks iPhone X is expensve.
#
#
# Galaxy S9
#
# 1. A considerable amount of ngrams are substantiating that users are not happy with battery life Galaxy S9 .
#
# + Many user are writing the review 2 or 3 weeks after they bought the phone.
#
# + Buying cycle can be carefully infered. A consideralble count of review is stating that users upgraded from S7.

# %% [markdown]
# ## Similar Words
#
# - "simple_preprocess" lowercases, tokenizes. – the output are final tokens
# <br>
# <br>
# + "Word2Vec" is unsupervised natual language processing. Word2vec is a two-layer neural net that turns words into embeding (unique vectors of numbers for each word). Simply put, its input is a text corpus and its output is a set of vectors.
# <br>
# <br>
# + "most_similar" function takes these vectors and computes vector distance through linear algebra to reveal the most similar words. Fianlly, the distances are normalized and outputs the similarity socre.
#
# **How is this going to help us with our analysis?**
#
# We will input words to find out what certain words mean to consumers.

# %%
#training  iPhone X

documents_a = []

for a in range(len(df_a)):
    doc = gensim.utils.simple_preprocess(df_a['review'][a])
    documents_a.append(doc)


model_a = gensim.models.Word2Vec(documents_a, size=150, window=10, min_count=2, workers=10)
model_a.train(documents_a,total_examples=len(documents_a),epochs=10)
# Out:
# (1216138, 1775050)

# %%
#training galaxy S9

documents_s = []

for s in range(len(df_s)):
    doc = gensim.utils.simple_preprocess(df_s['review'][s])
    documents_s.append(doc)


model_s = gensim.models.Word2Vec(documents_s, size=150, window=10, min_count=2, workers=10)
model_s.train(documents_a,total_examples=len(documents_s),epochs=10)
# Out:
# (1160793, 1775050)

# %% [markdown]
# <u>NOTE: </u>
#
# The results won't be same when preprocessed tokens go through vectorization since Word2vec uses random assignment on vectorization. I tried setting the seed, but the result still wasn't exactly consistent. This seems to be a common issue in the gensim user community.
#
# <br>
# <br>
#
# Now that we trained iPhone X review and Galaxy S9 reviews separately, let's explore the similar words.
# <br>
#
# <u>**Interesting Outputs**</u>
#
# The word, "slow" is associated with "authentication", "restart", "earphones", "gps" in iPhone X.
#
# The word, "slow" is associated with "sensor", "scanner", "zoom" "loading", "selfie" in Galaxy S9.
#
# <br>
#
# The word, "terrible" is associated with "accessory", "resistant", "downloading", "cables" in iPhone X.
#
# The word, "terrible" is associated with "filming", "scanner", "loading", "audio" in Galaxy S9.

# %%
# Create text widget for output
word_output = widgets.Text()

# Create text widget for input
word_input = widgets.Text(
    placeholder="Type a word",
    description='Input: ',
    disabled=False
    )

# Define function to bind value of the input to the output variable 
def bind_input_to_output(sender):
    dd = model_s.wv.most_similar(positive= word_input.value)
    ss = model_a.wv.most_similar(positive= word_input.value)
    print('====================')
    print('input word: ',word_input.value)
    print('======================================================================================================')
    print('--------------------')
    print('iPhone X')
    print('--------------------')
    print(ss)
    print('--------------------')
    print('Galaxy S9')
    print('--------------------')
    print(dd)

    print('======================================================================================================')
# Tell the text input widget to call bind_input_to_output() on submit
word_input.on_submit(bind_input_to_output)

# Display input text box widget for input
display(word_input)
# Out:
# Text(value='', description='Input: ', placeholder='Type a word')

# %% [markdown]
# ## Model Building
#
# Let's start out with a simple OLS regression using some features we created.

# %%
#x = pd.concat([df['rating'], df['positivity'],df['num_pos'], df['negativity']], axis=1)
#y = df['rating']

train, test = train_test_split(df, test_size=0.30, random_state=42)

# %%
model1 = smf.ols('rating ~ positivity + num_pos + negativity', data = train).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     962.3
# Date:                Sat, 20 Apr 2019   Prob (F-statistic):               0.00
# Time:                        10:47:42   Log-Likelihood:                -11248.
# No. Observations:                9252   AIC:                         2.250e+04
# Df Residuals:                    9248   BIC:                         2.253e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.2187      0.021    201.504      0.000       4.178       4.260
# positivity     1.5489      0.056     27.727      0.000       1.439       1.658
# num_pos        0.0115      0.003      3.959      0.000       0.006       0.017
# negativity    -4.3954      0.143    -30.732      0.000      -4.676      -4.115
# ==============================================================================
# Omnibus:                     3086.762   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11200.234
# Skew:                          -1.660   Prob(JB):                         0.00
# Kurtosis:                       7.247   Cond. No.                         75.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred1=round(model1.predict(test))

mean_squared_error(pred1, test['rating'])
# Out:
# 0.7312153303076148

# %%
print(accuracy_score(y_true = test['rating'], y_pred = pred1))
confusion_matrix(pred1, test['rating'])
# Out:
# 0.6227937468482098
# array([[   0,    1,    0,    0,    0,    0],
#        [   3,    0,    3,    1,    0,    0],
#        [  25,   11,   26,   24,   42,    0],
#        [  88,   73,  178,  339,  716,    0],
#        [   7,   11,   28,  281, 2105,    0],
#        [   0,    0,    0,    0,    4,    0]], dtype=int64)

# %% [markdown]
# > The model has a predictive power at 56%, but it doesn't look great. The result has up to 6-stars in predicted values because we simply rounded the prediction. We can do better than this.

# %% [markdown]
# ### Classification Models
#
#
# To increase our prediction accuracy, iPhone and Galaxy reviews were trained separately.
#
# Lemmatization was performed to increase our accuracy. lancaster method worked better in our models.
#
# https://www.datacamp.com/community/tutorials/stemming-lemmatization-python
#
#
# - "CountVectorizer" converts a collection of text documents to a matrix of token counts.
#
# - "fit_transform" learns the vocabulary dictionary and it returns a Document-Term matrix.
#
# - "TfidfTransformer" transforms a count matrix to a normalized tf or tf-idf representation
#
#         TF-IDF means term-frequency times inverse document-frequency.
#         This scales down the impact of tokens that occur very frequently in a given corpus and that are less informative.
#
#
# <u>Methods used: </u>
#
# MultinomialNB (NaiveBayes)
#
# MultinomialNB via GridSearch
#
# SGDClassifier (Linear SVM) via GridSearch
# <br>
# <br>
#
# \*GridSearch is a optimization tool that tests a few parameters.

# %%
#### training Galaxy S9
#######################

# Lemmatizing



porter = PorterStemmer()
lancaster = LancasterStemmer()

X_all_s=[]

for i in range(len(df_s)):
    X_all_s.append(lancaster.stem(df_s['review'][i]))

# %%
    
X_train_s, X_test_s, Y_train_s, Y_test_s = train_test_split(X_all_s, df_s['rating'], test_size=0.30, random_state=42)

# %%
# MultinomialNB via GirdSearch

text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf', MultinomialNB()),
])

parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
             'tfidf__use_idf': (True, False),
              'clf__alpha': (1e-2, 0.0005),
}

s_text_clf = text_clf.fit(X_train_s, Y_train_s)

s_gs_clf = GridSearchCV(s_text_clf, parameters, n_jobs=-1)
s_gs_clf = s_gs_clf.fit(X_train_s, Y_train_s)

s_tr_gNB = s_gs_clf.best_score_
s_tr_gNB
# Out:
# C:\Users\thdms\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.7528221668377071

# %%
pred_GridNB_s = s_gs_clf.predict(X_test_s)

s_te_gNB = accuracy_score(y_true = Y_test_s, y_pred = pred_GridNB_s)
s_te_gNB
# Out:
# 0.7506839945280438

# %%
# SVM via GridSearch

text_clf_svm = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=1e-3, n_iter=5, random_state=42)),
])

parameters_svm = {'vect__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'clf-svm__alpha': (1e-2, 1e-3),
}

s_gs_clf_svm = GridSearchCV(text_clf_svm, parameters_svm, n_jobs=-1)
s_gs_clf_svm = s_gs_clf_svm.fit(X_train_s, Y_train_s)
s_tr_gSVM = s_gs_clf_svm.best_score_
s_tr_gSVM
#gs_clf_svm.best_params_
# Out:
# C:\Users\thdms\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\thdms\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:152: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# 0.72789913502419

# %%
pred_GridSVM_s = s_gs_clf_svm.predict(X_test_s)

s_te_gSVM = accuracy_score(y_true = Y_test_s, y_pred = pred_GridSVM_s)
s_te_gSVM
# Out:
# 0.7185362517099864

# %%
#joblib.dump(gs_clf_svm, 'model.pkl', compress = 1)

# %%
#svm_model = joblib.load('model.pkl')
#pred3=svm_model.predict(rev_test1)

# %%
ppp=s_gs_clf.predict(["don't be a sucker and fall for marketing strategies, the only reason Iphones are the most known are because of the media corporate advertising. The batteries are not designed to last in this model, and actually seem worse than previous versions of the Iphone.",
                   'I have had my iPhone X for over a year now and it is clearly the worst iPhone I have ever owned. The screen is dull, and don’t even think about using it in direct sunlight as it just turns black. Face recognition is slow, clunky and hardly ever works.  I was much happier with the standard models, and these are certainly much better value for money.'])

# %%
s_gs_clf.predict(["a waste of money"])
# Out:
# array([3], dtype=int64)

# %%
s_gs_clf.predict(["samsung is okay but not great"])
# Out:
# array([4], dtype=int64)

# %%
lancaster.stem(df_s['review'][22])
# Out:
# "my phone was protected with a case and screen protector. only 3 weeks old my phone was sadly dropped at hip height and i'm no bfg but smash! with almost tears in my eyes as i did everything to protect it and it still smashed i went to the repair shop! here the tears let go! i was told  by the repairman that the screen protectors dont work well due to curved edges and it will cost me $490 to fix. what the actual fries! nothing to do with the repair shops, price set by samsung! keep this in mind when purchasing this brand! i am now the owner of a (not a one of a kind at that price )cracked s9!"

# %%
df_a[df_s['rating']==1]
# Out:
# C:\Users\thdms\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        phone  rating sentiment  \
# 12    iphone       4         P
# 22    iphone       5         P
# 40    iphone       2         N
# 46    iphone       1         N
# 69    iphone       4         P
# 74    iphone       5         P
# 81    iphone       4         P
# 103   iphone       1         N
# 104   iphone       4         P
# 128   iphone       5         P
# 129   iphone       5         P
# 203   iphone       1         N
# 228   iphone       3         N
# 335   iphone       3         N
# 340   iphone       5         P
# 488   iphone       5         P
# 522   iphone       5         P
# 794   iphone       5         P
# 1115  iphone       5         P
# 1384  iphone       5         P
# 1423  iphone       5         P
# 1506  iphone       5         P
# 1590  iphone       5         P
# 1684  iphone       5         P
# 1827  iphone       5         P
# 1828  iphone       5         P
# 1838  iphone       5         P
# 1980  iphone       2         N
# 2012  iphone       3         N
# 2045  iphone       4         P
# ...      ...     ...       ...
# 2190  iphone       5         P
# 2221  iphone       5         P
# 2226  iphone       5         P
# 2243  iphone       5         P
# 2245  iphone       5         P
# 2306  iphone       4         P
# 2343  iphone       2         N
# 2381  iphone       5         P
# 2406  iphone       2         N
# 2489  iphone       1         N
# 2525  iphone       2         N
# 2528  iphone       4         P
# 2568  iphone       4         P
# 2578  iphone       2         N
# 2595  iphone       5         P
# 2604  iphone       3         N
# 2682  iphone       5         P
# 2756  iphone       5         P
# 2896  iphone       5         P
# 2900  iphone       5         P
# 2903  iphone       5         P
# 2920  iphone       5         P
# 2991  iphone       5         P
# 3068  iphone       5         P
# 3076  iphone       4         P
# 3107  iphone       5         P
# 3137  iphone       5         P
# 3232  iphone       5         P
# 3288  iphone       5         P
# 3401  iphone       5         P
#
#                                                  review                source  \
# 12    Simplistic but flawless design. It is simple a...  Productreview.com.au
# 22    Bought this for my 13 year old daughter who ha...  Productreview.com.au
# 40    Positives - amazing photo quality, love portra...  Productreview.com.au
# 46    Ongoing issues since purchase:•\tUnexpected sh...  Productreview.com.au
# 69    The best iPhone so far, no faults yet, except ...  Productreview.com.au
# 74    this phone is honestly incredible. the new fea...  Productreview.com.au
# 81    Love it, pretty easy to use but just too expen...  Productreview.com.au
# 103   I have this phone for almost a year. I got it ...  Productreview.com.au
# 104   This Is the perfect phone with all the feature...  Productreview.com.au
# 128   Previously I had used a lot of android mobile ...  Productreview.com.au
# 129   I am in love with my iPhone X. Ive loved all m...  Productreview.com.au
# 203   This has to be the worst phone I have ever use...  Productreview.com.au
# 228   The good bits: Face ID - love it.  Enhanced ca...  Productreview.com.au
# 335   Camera is great, there’s plenty of options to ...  Productreview.com.au
# 340   I love this phone so much. It is so great and ...  Productreview.com.au
# 488   Using my iPhone X for several months now and I...  Productreview.com.au
# 522   everything about the iPhone X is top notched. ...  Productreview.com.au
# 794   great product because i very like it . i see m...           influenster
# 1115  It camera cwality is great its not slow its th...           influenster
# 1384  My husband has gifted me iPhone X and I love i...           influenster
# 1423  The iPhone X was a huge gamble from Apple, but...           influenster
# 1506  The iPhone X was a huge gamble from Apple, but...           influenster
# 1590  quiero un iphone x gratis porfavor lo quiero m...           influenster
# 1684  i am passionate about the iPhone x,and even mo...           influenster
# 1827  Easy order, delivered on time and excellent se...            Very.co.uk
# 1828  Slightly different user experience but a great...            Very.co.uk
# 1838  Upgraded from iPhone SE the iPhone X took a wh...            Very.co.uk
# 1980  I GOT THE ORDER FAST HOWEVER, THE DEVICE WASN'...            Very.co.uk
# 2012  Does not play the full ringtone and cuts out t...            Very.co.uk
# 2045  Battery life is really good, picture quality i...            Very.co.uk
# ...                                                 ...                   ...
# 2190  I'm not the type of person who writes a review...                    vw
# 2221  I had a choice between 8 and X. I want with th...                    vw
# 2226  I just recently purchased my Apple IPhoneX ove...                    vw
# 2243  Great phone. Much better than my wife’s 7. Bat...                    vw
# 2245  I upgraded from a 5c and am so glad I did! The...                    vw
# 2306  Very nice phone indeed, only thing is if the m...                    vw
# 2343  Overall, it is disappointing. I received the p...                    vw
# 2381  Having had every iphone since the first, ands ...               att.com
# 2406  Don’t get me wrong the phone is beautiful but ...               att.com
# 2489  I phone x has nice camera in front and back, b...               att.com
# 2525  I should have know better. Been buying iPhones...               att.com
# 2528  I went from Samsung to the new iPhone 8 and lo...               att.com
# 2568  I was like most people when the design was fir...               att.com
# 2578  I do not like that the finger scan is no longe...               att.com
# 2595  I do not write reviews often but I do read the...               att.com
# 2604         I think way to much money for just o phone               att.com
# 2682  The iPhone X is great. I loved my iPhone 7 and...               att.com
# 2756  Didn’t really hear much about the phone but fi...               att.com
# 2896  For my daughter for Christmas, she loves it. S...               att.com
# 2900  I did a lot of tests with the phone and juggle...               att.com
# 2903  The pictures are great and much more clear tha...               att.com
# 2920  been meaning to try the I phone for a few year...               att.com
# 2991  I will never own anything but an Apple product...               att.com
# 3068  I’m in love with this phone. Easy to navigate,...               att.com
# 3076  For the most part I like my new iPhone X, the ...               att.com
# 3107  I just got my new iPhone X and love all the ne...               att.com
# 3137  The best cellphone in the market for now for t...               att.com
# 3232  Love the phone- taken a little getting use to ...               att.com
# 3288  its a awesome phone the only thing its alittle...               att.com
# 3401                Upgraded from a 6 plus and love it!               att.com
#
#                                                 cleaned  \
# 12    Simplistic but flawless design. It is simple a...
# 22    Bought this for my 13 year old daughter who ha...
# 40    Positives - amazing photo quality, love portra...
# 46    Ongoing issues since purchase:\tUnexpected shu...
# 69    The best iPhone so far, no faults yet, except ...
# 74    this phone is honestly incredible. the new fea...
# 81    Love it, pretty easy to use but just too expen...
# 103   I have this phone for almost a year. I got it ...
# 104   This Is the perfect phone with all the feature...
# 128   Previously I had used a lot of android mobile ...
# 129   I am in love with my iPhone X. Ive loved all m...
# 203   This has to be the worst phone I have ever use...
# 228   The good bits: Face ID - love it.  Enhanced ca...
# 335   Camera is great, theres plenty of options to e...
# 340   I love this phone so much. It is so great and ...
# 488   Using my iPhone X for several months now and I...
# 522   everything about the iPhone X is top notched. ...
# 794   great product because i very like it . i see m...
# 1115  It camera cwality is great its not slow its th...
# 1384  My husband has gifted me iPhone X and I love i...
# 1423  The iPhone X was a huge gamble from Apple, but...
# 1506  The iPhone X was a huge gamble from Apple, but...
# 1590  quiero un iphone x gratis porfavor lo quiero m...
# 1684  i am passionate about the iPhone x,and even mo...
# 1827  Easy order, delivered on time and excellent se...
# 1828  Slightly different user experience but a great...
# 1838  Upgraded from iPhone SE the iPhone X took a wh...
# 1980  I GOT THE ORDER FAST HOWEVER, THE DEVICE WASN'...
# 2012  Does not play the full ringtone and cuts out t...
# 2045  Battery life is really good, picture quality i...
# ...                                                 ...
# 2190  I'm not the type of person who writes a review...
# 2221  I had a choice between 8 and X. I want with th...
# 2226  I just recently purchased my Apple IPhoneX ove...
# 2243  Great phone. Much better than my wifes 7. Batt...
# 2245  I upgraded from a 5c and am so glad I did! The...
# 2306  Very nice phone indeed, only thing is if the m...
# 2343  Overall, it is disappointing. I received the p...
# 2381  Having had every iphone since the first, ands ...
# 2406  Dont get me wrong the phone is beautiful but t...
# 2489  I phone x has nice camera in front and back, b...
# 2525  I should have know better. Been buying iPhones...
# 2528  I went from Samsung to the new iPhone 8 and lo...
# 2568  I was like most people when the design was fir...
# 2578  I do not like that the finger scan is no longe...
# 2595  I do not write reviews often but I do read the...
# 2604         I think way to much money for just o phone
# 2682  The iPhone X is great. I loved my iPhone 7 and...
# 2756  Didnt really hear much about the phone but fig...
# 2896  For my daughter for Christmas, she loves it. S...
# 2900  I did a lot of tests with the phone and juggle...
# 2903  The pictures are great and much more clear tha...
# 2920  been meaning to try the I phone for a few year...
# 2991  I will never own anything but an Apple product...
# 3068  Im in love with this phone. Easy to navigate, ...
# 3076  For the most part I like my new iPhone X, the ...
# 3107  I just got my new iPhone X and love all the ne...
# 3137  The best cellphone in the market for now for t...
# 3232  Love the phone- taken a little getting use to ...
# 3288  its a awesome phone the only thing its alittle...
# 3401                Upgraded from a 6 plus and love it!
#
#                                                filtered  negativity  \
# 12    Simplistic flawless design . It simple easy us...       0.000
# 22    Bought 13 year old daughter hassling . She lov...       0.000
# 40    Positives - amazing photo quality , love portr...       0.068
# 46    Ongoing issues since purchase : Unexpected shu...       0.045
# 69    The best iPhone far , faults yet , except pric...       0.103
# 74    phone honestly incredible . new features ad sp...       0.000
# 81    Love , pretty easy use expensive . Was using A...       0.000
# 103   I phone almost year . I got brand new came I p...       0.112
# 104   This Is perfect phone feature required smartph...       0.000
# 128   Previously I used lot android mobile nothing c...       0.023
# 129   I love iPhone X. Ive loved previous iPhones pr...       0.000
# 203   This worst phone I ever used , I hard reset ph...       0.116
# 228   The good bits : Face ID - love . Enhanced came...       0.124
# 335   Camera great , theres plenty options edit pict...       0.023
# 340   I love phone much . It great easy use . The ca...       0.000
# 488   Using iPhone X several months Im loving . The ...       0.000
# 522   everything iPhone X top notched . There flaw E...       0.034
# 794   great product like . see many people use iphon...       0.000
# 1115  It camera cwality great slow beat phone ojt I ...       0.000
# 1384  My husband gifted iPhone X I love . It 's best...       0.000
# 1423  The iPhone X huge gamble Apple , one really pa...       0.073
# 1506  The iPhone X huge gamble Apple , one really pa...       0.080
# 1590  quiero un iphone x gratis porfavor lo quiero l...       0.000
# 1684  passionate iPhone x , even taking pictures lan...       0.081
# 1827    Easy order , delivered time excellent service .       0.000
# 1828  Slightly different user experience great phone...       0.000
# 1838  Upgraded iPhone SE iPhone X took getting use u...       0.076
# 1980  I GOT THE ORDER FAST HOWEVER , THE DEVICE WAS ...       0.056
# 2012                  Does play full ringtone cuts soon       0.320
# 2045  Battery life really good , picture quality ama...       0.075
# ...                                                 ...         ...
# 2190  I 'm type person writes review product using w...       0.029
# 2221  I choice 8 X. I want IPhone X Im glad I ! ! I ...       0.000
# 2226  I recently purchased Apple IPhoneX week ago , ...       0.000
# 2243  Great phone . Much better wifes 7 . Battery la...       0.000
# 2245  I upgraded 5c glad I ! The facial recognition ...       0.023
# 2306  Very nice phone indeed , thing manufacturer gi...       0.000
# 2343  Overall , disappointing . I received phone yes...       0.242
# 2381  Having every iphone since first , ands Galaxy ...       0.024
# 2406  Dont get wrong phone beautiful thats good part...       0.130
# 2489  I phone x nice camera front back , face identi...       0.139
# 2525  I know better . Been buying iPhones since day ...       0.051
# 2528  I went Samsung new iPhone 8 loved enough oldes...       0.051
# 2568  I like people design first released . I worrie...       0.026
# 2578  I like finger scan longer option . The facial ...       0.069
# 2595  I write reviews often I read . I iPhone user s...       0.032
# 2604                       I think way much money phone       0.000
# 2682  The iPhone X great . I loved iPhone 7 served w...       0.087
# 2756  Didnt really hear much phone figured Id enjoy ...       0.034
# 2896  For daughter Christmas , loves . She especiall...       0.000
# 2900  I lot tests phone juggled 8 X ! I made right c...       0.000
# 2903  The pictures great much clear phones . I love ...       0.055
# 2920  meaning try I phone years , finally decided ma...       0.000
# 2991  I never anything Apple product ! I always buy ...       0.000
# 3068  Im love phone . Easy navigate , fantastic came...       0.000
# 3076  For part I like new iPhone X , thing I n't car...       0.184
# 3107  I got new iPhone X love new features still lea...       0.000
# 3137  The best cellphone market smart phone well def...       0.000
# 3232  Love phone- taken little getting use overall h...       0.000
# 3288              awesome phone thing alittle expensive       0.000
# 3401                             Upgraded 6 plus love !       0.000
#
#       positivity  compound  len_org  len_adj  len_ch  num_pos  num_neg  \
# 12         0.394    0.9578        0        4     159        4        1
# 22         0.288    0.9569        2        3     275        4        0
# 40         0.264    0.9529        2        4     450       11        5
# 46         0.033   -0.1788        5        3     416        3        1
# 69         0.115    0.3877        2        3     292        5        0
# 74         0.335    0.9690        0        5     255       11        0
# 81         0.257    0.9319        3        2     298        4        1
# 103        0.112   -0.2613        8        4     832       11        4
# 104        0.169    0.8553        1        5     316        8        1
# 128        0.106    0.7776        3        4     359        3        1
# 129        0.154    0.9104        4        3     394        4        2
# 203        0.034   -0.8639        4        4     596        4        4
# 228        0.118    0.1424        3       10     471        4        6
# 335        0.167    0.9079        3       11     407        4        2
# 340        0.426    0.9868        5        5     297        8        1
# 488        0.158    0.9062        5       10     344        6        1
# 522        0.235    0.9167        1        4     308        7        1
# 794        0.333    0.8992        0        4     164        4        0
# 1115       0.250    0.7693        0        3     112        2        1
# 1384       0.324    0.9595        2        3     234        6        0
# 1423       0.233    0.9601        5        7     494        7        2
# 1506       0.204    0.9225        5        7     466        6        2
# 1590       0.059    0.0516        0        9     121        0        0
# 1684       0.294    0.8481        2       10     167        1        1
# 1827       0.524    0.7650        0        9      52        2        0
# 1828       0.569    0.9824        2        5     169        4        1
# 1838       0.075    0.5927       10        7     761        7        3
# 1980       0.113    0.5845        2        2     361        3        3
# 2012       0.000   -0.5000        0        4      52        1        0
# 2045       0.240    0.6997        1        8     138        4        1
# ...          ...       ...      ...      ...     ...      ...      ...
# 2190       0.088    0.5093        3        9     300        1        1
# 2221       0.461    0.9721        2        5     194        6        0
# 2226       0.086    0.5702        2        8     298        3        2
# 2243       0.359    0.9617        3        9     239        7        1
# 2245       0.235    0.9284        2        4     297        3        0
# 2306       0.265    0.8877        0        4     187        3        1
# 2343       0.060   -0.8070        3       12     224        0        3
# 2381       0.076    0.6611        4        3     553        7        3
# 2406       0.106   -0.0811        5        5     469        4        2
# 2489       0.275    0.8943        3       11     291        4        3
# 2525       0.165    0.9557        9        6     773        9        4
# 2528       0.137    0.7964        4        5     271        3        2
# 2568       0.173    0.9884       10        4    1148       12        5
# 2578       0.050   -0.1705        3        9     471        0        3
# 2595       0.172    0.9392        5        7     466        3        1
# 2604       0.000    0.0000        0        4      42        1        0
# 2682       0.226    0.8525        4        5     368        3        0
# 2756       0.224    0.9149        2        8     290        5        0
# 2896       0.271    0.9100        1        7     189        2        0
# 2900       0.243    0.8390        0        4     184        2        0
# 2903       0.257    0.8685        0        4     187        5        0
# 2920       0.080    0.4215        1        3     177        2        0
# 2991       0.285    0.8796        2        4     137        1        0
# 3068       0.559    0.9638        2        5     112        5        0
# 3076       0.100   -0.3291        1        9     110        1        1
# 3107       0.342    0.8519        1        5     102        4        0
# 3137       0.482    0.9022        0        5      93        2        0
# 3232       0.447    0.8438        0        5      68        2        1
# 3288       0.339    0.6249        0        9      56        1        1
# 3401       0.473    0.6696        1        4      35        1        0
#
#       polarity_filtered
# 12             0.272222
# 22             0.333333
# 40             0.118730
# 46             0.006250
# 69             0.314545
# 74             0.455303
# 81             0.147222
# 103            0.080532
# 104            0.430278
# 128            0.146667
# 129            0.204762
# 203           -0.142708
# 228            0.023810
# 335            0.320000
# 340            0.463542
# 488            0.299074
# 522            0.275744
# 794            0.625000
# 1115           0.220000
# 1384           0.533333
# 1423           0.263333
# 1506           0.181481
# 1590           0.000000
# 1684           0.225000
# 1827           0.716667
# 1828           0.580000
# 1838           0.129978
# 1980           0.061667
# 2012           0.350000
# 2045           0.308333
# ...                 ...
# 2190           0.033333
# 2221           0.522917
# 2226           0.142100
# 2243           0.365000
# 2245           0.556250
# 2306           0.510000
# 2343          -0.587500
# 2381           0.227083
# 2406           0.138095
# 2489           0.101042
# 2525           0.113462
# 2528           0.199838
# 2568           0.181863
# 2578          -0.354167
# 2595           0.100000
# 2604           0.200000
# 2682           0.316667
# 2756           0.292857
# 2896           0.386667
# 2900           0.580357
# 2903           0.475000
# 2920           0.200000
# 2991           1.000000
# 3068           0.626667
# 3076          -0.181818
# 3107           0.393182
# 3137           0.404762
# 3232           0.278125
# 3288           0.250000
# 3401           0.625000
#
# [64 rows x 16 columns]

# %%
#### training iPhone X
#######################

porter = PorterStemmer()
lancaster = LancasterStemmer()

X_all=[]

for i in range(len(df_a)):
    X_all.append(lancaster.stem(df_a['review'][i]))
    
    
X_train, X_test, Y_train, Y_test = train_test_split(X_all, df_a['rating'], test_size=0.30, random_state=42)

# MutinomialNB

vect = CountVectorizer(max_features=100, binary=True)
X_train_tr = vect.fit_transform(X_train)
X_test_tr = vect.fit_transform(X_test)

tfidf_transformer = TfidfTransformer()
X_train_tr = tfidf_transformer.fit_transform(X_train_tr)
X_test_tr = tfidf_transformer.fit_transform(X_test_tr)


nb = MultinomialNB()
nb.fit(X_train_tr, Y_train)
a_tr_NB = nb.score(X_train_tr, Y_train) ###

pred_nb = nb.predict(X_test_tr)
a_te_NB = accuracy_score(y_true = Y_test, y_pred = pred_nb) ###


# MultinomialNB via GirdSearch

text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf', MultinomialNB()),
])

parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
             'tfidf__use_idf': (True, False),
              'clf__alpha': (1e-2, 0.0005),
}

text_clf = text_clf.fit(X_train, Y_train)

gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1)
gs_clf = gs_clf.fit(X_train, Y_train)

a_tr_gNB = gs_clf.best_score_   ###

a_pred_GridNB = gs_clf.predict(X_test)
a_te_gNB = accuracy_score(y_true = Y_test, y_pred = a_pred_GridNB)   ###


# SVM via GridSearch

text_clf_svm = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=1e-3, n_iter=5, random_state=42)),
])

parameters_svm = {'vect__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'clf-svm__alpha': (1e-2, 1e-3),
}

gs_clf_svm_a = GridSearchCV(text_clf_svm, parameters_svm, n_jobs=-1)
gs_clf_svm_a = gs_clf_svm_a.fit(X_train, Y_train)
a_tr_gSVM = gs_clf_svm_a.best_score_    ###

pred_GridSVM_a = gs_clf_svm_a.predict(X_test)
a_te_gSVM = accuracy_score(y_true = Y_test, y_pred = pred_GridSVM_a)  ###
# Out:
# C:\Users\thdms\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\thdms\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\thdms\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:152: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)

# %% [markdown]
# ### Accuracy

# %%
# Model accuracies

pd.DataFrame({'iPhoneX' : [a_tr_NB, a_te_NB, a_tr_gNB, a_te_gNB, a_tr_gSVM, a_te_gSVM], 
              'GalaxyS9' : [s_tr_NB, s_te_NB, s_tr_gNB, s_te_gNB, s_tr_gSVM, s_te_gSVM]},
            index = ['NB-Train', 'NB-Test', 'GridNB-Train', 'GridNB-Test', 'GridSVM-Train', 'GridSVM-Test'])
# Out:
#                 iPhoneX  GalaxyS9
# NB-Train       0.743316  0.726580
# NB-Test        0.734165  0.715800
# GridNB-Train   0.753599  0.752822
# GridNB-Test    0.731286  0.750684
# GridSVM-Train  0.749074  0.727899
# GridSVM-Test   0.740883  0.718536

# %% [markdown]
# ### Prediction
#
# Because we scraped a far more Samsung S9 review, we will use the prediction model for Galaxy S9 to build rating system. Simply, type a possible Galaxy S9 review in the below input box.

# %%
###### GalaxyS9 ###############

word_output1 = widgets.Text()

word_input1 = widgets.Text(
    placeholder="Type a review",
    description='Input: ',
    disabled=False
    )

def bind_input_to_output1(sender):
    print('================================')
    sss=lancaster.stem(word_input1.value)
    ss=s_gs_clf.predict([sss])[0]
    print('Input :', word_input1.value)
    print('Predicted Rating is: ', ss)
    print('================================================================================================================')

word_input1.on_submit(bind_input_to_output1)

display(word_input1)
# Out:
# Text(value='', description='Input: ', placeholder='Type a review')
# ================================
# Input : it's legit
# Predicted Rating is:  5
# ================================================================================================================
# ================================
# Input : freaking aweesome
# Predicted Rating is:  5
# ================================================================================================================
# ================================
# Input : this is shit
# Predicted Rating is:  5
# ================================================================================================================
# ================================
# Input : terribly good and satisfied with it
# Predicted Rating is:  5
# ================================================================================================================
# ================================
# Input : i am going to return it i don't like this phone and it's giving me a lot of trouble
# Predicted Rating is:  5
# ================================================================================================================
# ================================
# Input : not a good phone
# Predicted Rating is:  4
# ================================================================================================================

# %% [markdown]
# ## Conclusion and Limitation
#
#
# #### Apple Inc.
#
# - Starting iPhone X generation, Apple got rid of a home button which was considered a bold move in the industry.
#
# - It is evident that users miss home button. It will be intereting to see if users have gotten used to not having a home button in the later generation (more scraping).
#
# - Face recognition needs to be more responsive and sensitive.
#
# - The consensus is that iPhones are priced high.
#
# #### Samsung Electronics
#
# - battery drainage should be fixed.
#
# - sensors (authentication - fingerprint scanner and face recognition) needs to be more responsive.
#
# - camera needs to be improved.
#
# - Since many users upgraded from S7 to S9 (two years), focus on ?????
#
#          (release date of S7 is March 11, 2016)
#          (release date of S9 is March 16, 2018)

# %% [markdown]
#
# #### More data
#
# As we saw in our prediction model, only 9745 reviews were used to train and test. In order to increase our prediction accuracy, we need far more reviews. It will be interesting to see how these products evolve from generation to generation.
#
# #### Language is Less Intuitive and messy
#
# Consider following reviews.

# %%
print(df['review'][8098])
print(df['review'][9368])
# Out:
# I bought this a month ago and I'm really happy with the product
# Great all round phone. Looks great, feels great, and works well. Can't see me wanting to let this one go.

# %% [markdown]
# The first review is a 5-star rating and this sentence is straightforward and easy to understand.
#
# The second review is also a 5-star review. The last sentence is starting with a negative word "Can't". And you won't know whether this is a positive or negative sentence until you see the word, "go".

# %% [markdown]
# **Lastly, which product is the winner? iPhone X or Galaxy S9?**

# %%
print('iPhone X average positivity: ', round(np.mean(df_a['positivity']), 2))
print('\n vs \n')
print('Galaxy S9 average positivity: ', round(np.mean(df_s['positivity']), 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d442c3c0dc2c> in <module>
# ----> 1 print('iPhone X average positivity: ', round(np.mean(df_a['positivity']), 2))
#       2 print('\n vs \n')
#       3 print('Galaxy S9 average positivity: ', round(np.mean(df_s['positivity']), 2))
#
# NameError: name 'np' is not defined
